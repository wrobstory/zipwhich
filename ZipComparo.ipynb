# %%
import pandas as pd

# Import, lowercase city/state name to attempt join later

# Schema: http://download.geonames.org/export/zip/readme.txt
col_names = ['country_code',
             'postal_code',
             'place_name',
             'admin_name1',
             'admin_code1',
             'admin_name2',
             'admin_code2',
             'admin_name3',
             'admin_code3',
             'latitude',
             'longitude',
             'accuracy']
geonames = pd.read_table('GeoNamesZip.txt', header=None, names=col_names, dtype={'postal_code': str})
geonames['place_name'] = geonames['place_name'].str.lower()
geonames['admin_code1'] = geonames['admin_code1'].str.lower()
geonames_set = set(geonames['postal_code'])

free_zip_db = pd.read_csv('free-zipcode-database-Primary.csv', dtype={'Zipcode': str})
free_zip_db['City'] = free_zip_db['City'].str.lower()
free_zip_db['State'] = free_zip_db['State'].str.lower()
freezip_set = set(free_zip_city_state['Zipcode'])

noncensus = pd.read_csv('noncensus_zip.csv', dtype={'zip': str})
noncensus['city'] = noncensus['city'].str.lower()
noncensus['state'] = noncensus['state'].str.lower()
noncensus_set = set(noncensus['zip'])

# %%
# Given that freezip has the most rows (zip codes), what's the set difference between it and geonames?
free_diff_geo = list(freezip_set.difference(geonames_set))
free_diff_geo_df = free_zip_db[free_zip_db['Zipcode'].isin(free_diff_geo)]
free_diff_geo_df
# Out:
#       Zipcode ZipCodeType          City State LocationType    Lat    Long  \
# 0       00705    STANDARD      aibonito    pr      PRIMARY  18.14  -66.26
# 1       00610    STANDARD        anasco    pr      PRIMARY  18.28  -67.14
# 2       00611      PO BOX       angeles    pr      PRIMARY  18.28  -66.79
# 3       00612    STANDARD       arecibo    pr      PRIMARY  18.45  -66.73
# 4       00601    STANDARD      adjuntas    pr      PRIMARY  18.16  -66.72
# 5       00631      PO BOX      castaner    pr      PRIMARY  18.19  -66.82
# 6       00602    STANDARD        aguada    pr      PRIMARY  18.38  -67.18
# 7       00603    STANDARD     aguadilla    pr      PRIMARY  18.43  -67.15
# 8       00604      PO BOX     aguadilla    pr      PRIMARY  18.43  -67.15
# 9       00605      PO BOX     aguadilla    pr      PRIMARY  18.43  -67.15
# 10      00703    STANDARD  aguas buenas    pr      PRIMARY  18.25  -66.10
# 11      00704    STANDARD       aguirre    pr      PRIMARY  17.96  -66.22
# 80      00613      PO BOX       arecibo    pr      PRIMARY  18.45  -66.73
# 81      00614      PO BOX       arecibo    pr      PRIMARY  18.45  -66.73
# 82      00714    STANDARD        arroyo    pr      PRIMARY  17.97  -66.06
# 83      00616    STANDARD      bajadero    pr      PRIMARY  18.40  -66.66
# 84      00617    STANDARD   barceloneta    pr      PRIMARY  18.45  -66.53
# 85      00794    STANDARD  barranquitas    pr      PRIMARY  18.18  -66.30
# 86      00622    STANDARD      boqueron    pr      PRIMARY  17.99  -67.15
# 87      00623    STANDARD     cabo rojo    pr      PRIMARY  18.08  -67.14
# 88      00627    STANDARD         camuy    pr      PRIMARY  18.48  -66.84
# 89      00729    STANDARD     canovanas    pr      PRIMARY  18.37  -65.90
# 90      00979    STANDARD      carolina    pr      PRIMARY  18.40  -65.98
# 91      00981      PO BOX      carolina    pr      PRIMARY  18.40  -65.98
# 92      00982    STANDARD      carolina    pr      PRIMARY  18.40  -65.98
# 93      00983    STANDARD      carolina    pr      PRIMARY  18.40  -65.98
# 94      00984      PO BOX      carolina    pr      PRIMARY  18.40  -65.98
# 95      00985    STANDARD      carolina    pr      PRIMARY  18.40  -65.98
# 96      00986      PO BOX      carolina    pr      PRIMARY  18.40  -65.98
# 97      00987    STANDARD      carolina    pr      PRIMARY  18.40  -65.98
# ...       ...         ...           ...   ...          ...    ...     ...
# 42318   85245      PO BOX      red rock    az      PRIMARY  32.62 -111.37
# 42320   85272    STANDARD     stanfield    az      PRIMARY  32.85 -111.97
# 42321   85273    STANDARD      superior    az      PRIMARY  33.28 -111.11
# 42323   85279    STANDARD      florence    az      PRIMARY  32.79 -111.21
# 42394   60597      UNIQUE    fox valley    il      PRIMARY  41.76  -88.22
# 42399   76545      UNIQUE       killeen    tx      PRIMARY  31.11  -97.72
# 42400   76546      UNIQUE       killeen    tx      PRIMARY  31.11  -97.72
# 42417   85292    STANDARD     winkelman    az      PRIMARY  32.94 -110.72
# 42418   85293    STANDARD   casa grande    az      PRIMARY  32.85 -111.79
# 42419   85294    STANDARD   casa grande    az      PRIMARY  32.92 -111.61
# 42423   86555    STANDARD       douglas    az      PRIMARY  31.38 -109.55
# 42424   87165      PO BOX   albuquerque    nm      PRIMARY  35.08 -106.64
# 42470   96212    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42471   96215    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42472   96217    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42473   96219    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42474   96221    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42475   96297    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42476   96311    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42477   96313    MILITARY           fpo    ap      PRIMARY    NaN     NaN
# 42479   96634    MILITARY           fpo    ap      PRIMARY    NaN     NaN
# 42512   09300    MILITARY           apo    ae      PRIMARY    NaN     NaN
# 42513   09303    MILITARY           apo    ae      PRIMARY    NaN     NaN
# 42514   09379    MILITARY           fpo    ae      PRIMARY    NaN     NaN
# 42515   96400    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42516   96547    MILITARY           apo    ap      PRIMARY    NaN     NaN
# 42517   34009    MILITARY           apo    aa      PRIMARY    NaN     NaN
# 42518   34010    MILITARY           apo    aa      PRIMARY    NaN     NaN
# 42519   34001    MILITARY           apo    aa      PRIMARY    NaN     NaN
# 42520   34071    MILITARY           apo    aa      PRIMARY    NaN     NaN
#
#                                       Location Decommisioned  TaxReturnsFiled  \
# 0                            NA-US-PR-AIBONITO         False              NaN
# 1                              NA-US-PR-ANASCO         False              NaN
# 2                             NA-US-PR-ANGELES         False              NaN
# 3                             NA-US-PR-ARECIBO         False              NaN
# 4                            NA-US-PR-ADJUNTAS         False              NaN
# 5                            NA-US-PR-CASTANER         False              NaN
# 6                              NA-US-PR-AGUADA         False              NaN
# 7                           NA-US-PR-AGUADILLA         False              NaN
# 8                           NA-US-PR-AGUADILLA         False              NaN
# 9                           NA-US-PR-AGUADILLA         False              NaN
# 10                       NA-US-PR-AGUAS BUENAS         False              NaN
# 11                            NA-US-PR-AGUIRRE         False              NaN
# 80                            NA-US-PR-ARECIBO         False              NaN
# 81                            NA-US-PR-ARECIBO         False              NaN
# 82                             NA-US-PR-ARROYO         False              NaN
# 83                           NA-US-PR-BAJADERO         False              NaN
# 84                        NA-US-PR-BARCELONETA         False              NaN
# 85                       NA-US-PR-BARRANQUITAS         False              NaN
# 86                           NA-US-PR-BOQUERON         False              NaN
# 87                          NA-US-PR-CABO ROJO         False              NaN
# 88                              NA-US-PR-CAMUY         False              NaN
# 89                          NA-US-PR-CANOVANAS         False              NaN
# 90                           NA-US-PR-CAROLINA         False              NaN
# 91                           NA-US-PR-CAROLINA         False              NaN
# 92                           NA-US-PR-CAROLINA         False              NaN
# 93                           NA-US-PR-CAROLINA         False              NaN
# 94                           NA-US-PR-CAROLINA         False              NaN
# 95                           NA-US-PR-CAROLINA         False              NaN
# 96                           NA-US-PR-CAROLINA         False              NaN
# 97                           NA-US-PR-CAROLINA         False              NaN
# ...                                        ...           ...              ...
# 42318                        NA-US-AZ-RED ROCK          True              NaN
# 42320                       NA-US-AZ-STANFIELD          True              NaN
# 42321                        NA-US-AZ-SUPERIOR          True              NaN
# 42323                        NA-US-AZ-FLORENCE          True              NaN
# 42394                      NA-US-IL-FOX VALLEY          True              NaN
# 42399                         NA-US-TX-KILLEEN          True              NaN
# 42400                         NA-US-TX-KILLEEN          True              NaN
# 42417                       NA-US-AZ-WINKELMAN          True              NaN
# 42418                     NA-US-AZ-CASA GRANDE          True              NaN
# 42419                     NA-US-AZ-CASA GRANDE          True              NaN
# 42423                         NA-US-AZ-DOUGLAS          True              NaN
# 42424                     NA-US-NM-ALBUQUERQUE          True              NaN
# 42470                                   NA-US-          True              NaN
# 42471                                   NA-US-          True              NaN
# 42472                                   NA-US-          True              NaN
# 42473                                   NA-US-          True              NaN
# 42474                                   NA-US-          True              NaN
# 42475                          AS-KR-CAMP LONG          True              NaN
# 42476                                   NA-US-          True              NaN
# 42477                                   NA-US-          True              NaN
# 42479                                   NA-US-          True              NaN
# 42512                         ME-IQ-CAMP BUCCA          True              NaN
# 42513                        ME-BH-MCA BAHRAIN          True              NaN
# 42514       ME-BH-FMC BAH CONTINGENCY - MANAMA          True              NaN
# 42515                 AS-TH-COBRA GOLD BANGKOK          True              NaN
# 42516                            AS-TH-BANGKOK          True              NaN
# 42517                 SA-GY-NEW HORIZON-GUYANA          True              NaN
# 42518  CA-HN-NEW HORIZON  LA CEIBA - COMAYAGUA          True              NaN
# 42519      CA-NI-JTF JUNTOS  PODEMOS BASE CAMP          True              NaN
# 42520         SA-PY-JTF NEW HORIZON-CONCEPCION          True              NaN
#
#        EstimatedPopulation  TotalWages
# 0                      NaN         NaN
# 1                      NaN         NaN
# 2                      NaN         NaN
# 3                      NaN         NaN
# 4                      NaN         NaN
# 5                      NaN         NaN
# 6                      NaN         NaN
# 7                      NaN         NaN
# 8                      NaN         NaN
# 9                      NaN         NaN
# 10                     NaN         NaN
# 11                     NaN         NaN
# 80                     NaN         NaN
# 81                     NaN         NaN
# 82                     NaN         NaN
# 83                     NaN         NaN
# 84                     NaN         NaN
# 85                     NaN         NaN
# 86                     NaN         NaN
# 87                     NaN         NaN
# 88                     NaN         NaN
# 89                     NaN         NaN
# 90                     NaN         NaN
# 91                     NaN         NaN
# 92                     NaN         NaN
# 93                     NaN         NaN
# 94                     NaN         NaN
# 95                     NaN         NaN
# 96                     NaN         NaN
# 97                     NaN         NaN
# ...                    ...         ...
# 42318                  NaN         NaN
# 42320                  NaN         NaN
# 42321                  NaN         NaN
# 42323                  NaN         NaN
# 42394                  NaN         NaN
# 42399                  NaN         NaN
# 42400                  NaN         NaN
# 42417                  NaN         NaN
# 42418                  NaN         NaN
# 42419                  NaN         NaN
# 42423                  NaN         NaN
# 42424                  NaN         NaN
# 42470                  NaN         NaN
# 42471                  NaN         NaN
# 42472                  NaN         NaN
# 42473                  NaN         NaN
# 42474                  NaN         NaN
# 42475                  NaN         NaN
# 42476                  NaN         NaN
# 42477                  NaN         NaN
# 42479                  NaN         NaN
# 42512                  NaN         NaN
# 42513                  NaN         NaN
# 42514                  NaN         NaN
# 42515                  NaN         NaN
# 42516                  NaN         NaN
# 42517                  NaN         NaN
# 42518                  NaN         NaN
# 42519                  NaN         NaN
# 42520                  NaN         NaN
#
# [913 rows x 12 columns]

# %%
# Columns of interest
geo_zip_city_state = geonames[['postal_code', 'place_name', 'admin_code1']]
free_zip_city_state = free_zip_db[['Zipcode', 'City', 'State']]
noncensus_city_state = noncensus[['zip', 'city', 'state']]

# %%
# free-zip vs geonames
merged_zip = pd.merge(free_zip_city_state, geo_zip_city_state, 
                      left_on='Zipcode', right_on='postal_code')
merged_zip_city = pd.merge(free_zip_city_state, geo_zip_city_state, 
                           left_on=['Zipcode', 'City'], 
                           right_on=['postal_code', 'place_name'])
merged_zip_city_state = pd.merge(free_zip_city_state, geo_zip_city_state, 
                                 left_on=['Zipcode', 'City', 'State'], 
                                 right_on=['postal_code', 'place_name', 'admin_code1'])
lengths_free_geo = {
    'merged_zip': len(merged_zip),
    'merged_zip_city': len(merged_zip_city),
    'merged_zip_city_state': len(merged_zip_city_state)
}
lengths_free_geo
# Out:
# {'merged_zip': 41651, 'merged_zip_city': 41147, 'merged_zip_city_state': 41147}

# %%
# What are we missing by joining on zip and city?
# Things like new york vs new york city, winston-salem vs winston salem
conflicting_free_geo = merged_zip[~merged_zip['Zipcode'].isin(merged_zip_city['Zipcode'])]
conflicting_free_geo
# Out:
#       Zipcode                   City State postal_code        place_name  \
# 35      10001               new york    ny       10001     new york city
# 36      10002               new york    ny       10002     new york city
# 37      10003               new york    ny       10003     new york city
# 38      10004               new york    ny       10004     new york city
# 39      10005               new york    ny       10005     new york city
# 40      10006               new york    ny       10006     new york city
# 41      10007               new york    ny       10007     new york city
# 42      10008               new york    ny       10008     new york city
# 43      10009               new york    ny       10009     new york city
# 44      10010               new york    ny       10010     new york city
# 45      10011               new york    ny       10011     new york city
# 46      10012               new york    ny       10012     new york city
# 47      10013               new york    ny       10013     new york city
# 48      10014               new york    ny       10014     new york city
# 49      10016               new york    ny       10016     new york city
# 50      10017               new york    ny       10017     new york city
# 51      10018               new york    ny       10018     new york city
# 52      10019               new york    ny       10019     new york city
# 53      10020               new york    ny       10020     new york city
# 54      10021               new york    ny       10021     new york city
# 55      10022               new york    ny       10022     new york city
# 56      10023               new york    ny       10023     new york city
# 57      10024               new york    ny       10024     new york city
# 58      10025               new york    ny       10025     new york city
# 59      10026               new york    ny       10026     new york city
# 60      10027               new york    ny       10027     new york city
# 61      10028               new york    ny       10028     new york city
# 62      10029               new york    ny       10029     new york city
# 63      10030               new york    ny       10030     new york city
# 64      10031               new york    ny       10031     new york city
# ...       ...                    ...   ...         ...               ...
# 41185   10196               new york    ny       10196     new york city
# 41186   10197               new york    ny       10197     new york city
# 41203   11592       rockville center    ny       11592  rockville centre
# 41235   27151          winston-salem    nc       27151     winston salem
# 41236   27156          winston-salem    nc       27156     winston salem
# 41277   33439            canal point    fl       33439            bryant
# 41343   47864               sullivan    in       47864       new lebanon
# 41346   48769                 vassar    mi       48769           tuscola
# 41348   48863                 howell    mi       48863         oak grove
# 41352   49790               eckerman    mi       49790           strongs
# 41388   64447              maysville    mo       64447          fairport
# 41389   64789                osceola    mo       64789             vista
# 41404   71768              el dorado    ar       71768            urbana
# 41458   81134               san luis    co       81134            garcia
# 41482   17091                lebanon    pa       17091         camp hill
# 41485   17738             north bend    pa       17738             hyner
# 41526   24961  white sulphur springs    wv       24961             neola
# 41527   25429            martinsburg    wv       25429     kearneysville
# 41528   25926                beckley    wv       25926           sprague
# 41530   36501                jackson    al       36501              alma
# 41545   60049            lake zurich    il       60049        long grove
# 41567   85290        apache junction    az       85290     tortilla flat
# 41571   86330               prescott    az       86330      iron springs
# 41583   91363          thousand oaks    ca       91363  westlake village
# 41615   95250            san andreas    ca       95250       sheep ranch
# 41616   95314              pinecrest    ca       95314        dardanelle
# 41634   97472          cottage grove    or       97472           saginaw
# 41645   98492                 tacoma    wa       98492          lakewood
# 41647   98929                 naches    wa       98929     goose prairie
# 41649   99779                    tok    ak       99779            tetlin
#
#       admin_code1
# 35             ny
# 36             ny
# 37             ny
# 38             ny
# 39             ny
# 40             ny
# 41             ny
# 42             ny
# 43             ny
# 44             ny
# 45             ny
# 46             ny
# 47             ny
# 48             ny
# 49             ny
# 50             ny
# 51             ny
# 52             ny
# 53             ny
# 54             ny
# 55             ny
# 56             ny
# 57             ny
# 58             ny
# 59             ny
# 60             ny
# 61             ny
# 62             ny
# 63             ny
# 64             ny
# ...           ...
# 41185          ny
# 41186          ny
# 41203          ny
# 41235          nc
# 41236          nc
# 41277          fl
# 41343          in
# 41346          mi
# 41348          mi
# 41352          mi
# 41388          mo
# 41389          mo
# 41404          ar
# 41458          co
# 41482          pa
# 41485          pa
# 41526          wv
# 41527          wv
# 41528          wv
# 41530          al
# 41545          il
# 41567          az
# 41571          az
# 41583          ca
# 41615          ca
# 41616          ca
# 41634          or
# 41645          wa
# 41647          wa
# 41649          ak
#
# [464 rows x 6 columns]

# %%
# noncensus vs free zip
merged_non_free_zip = pd.merge(noncensus_city_state, free_zip_city_state, 
                               left_on=['zip'], right_on=['Zipcode'])
merged_non_free_zip_city = pd.merge(noncensus_city_state, free_zip_city_state, 
                                    left_on=['zip', 'city'], right_on=['Zipcode', 'City'])
merged_non_free_zip_city_state = pd.merge(noncensus_city_state, free_zip_city_state, 
                                          left_on=['zip', 'city', 'state'], right_on=['Zipcode', 'City', 'State'])
lengths_noncensus_free = {
    'merged_zip': len(merged_non_free_zip),
    'merged_zip_city': len(merged_non_free_zip_city),
    'merged_zip_city_state': len(merged_non_free_zip_city_state)
}
lengths_noncensus_free
# Out:
# {'merged_zip': 41719, 'merged_zip_city': 41218, 'merged_zip_city_state': 41192}

# %%
conflicting_non_free = merged_non_free_zip[~merged_non_free_zip['Zipcode'].isin(merged_non_free_zip_city['Zipcode'])]
conflicting_non_free
# Out:
#          zip                  city state Zipcode                    City State
# 184    00978               st just    pr   00978              saint just    pr
# 326    01354            northfield    ma   01354                    gill    ma
# 339    01349         turners falls    ma   01349           millers falls    ma
# 363    01441               gardner    ma   01441             westminster    ma
# 596    02348            middleboro    ma   02348               lakeville    ma
# 667    02119                boston    ma   02119                 roxbury    ma
# 668    02120                boston    ma   02120        roxbury crossing    ma
# 669    02121                boston    ma   02121              dorchester    ma
# 670    02122                boston    ma   02122              dorchester    ma
# 671    02124                boston    ma   02124       dorchester center    ma
# 672    02125                boston    ma   02125              dorchester    ma
# 706    02189              weymouth    ma   02189           east weymouth    ma
# 707    02190              weymouth    ma   02190          south weymouth    ma
# 708    02191              weymouth    ma   02191          north weymouth    ma
# 780    02494               needham    ma   02494         needham heights    ma
# 796    02573        vineyard haven    ma   02573               west chop    ma
# 1060   03244             hillsboro    nh   03244            hillsborough    nh
# 1064   03249               laconia    nh   03249                 gilford    nh
# 1123   03457           munsonville    nh   03457                  nelson    nh
# 1192   03805           rollinsford    nh   03805               newington    nh
# 1255   03882       south effingham    nh   03882               effingham    nh
# 1308   04028      east parsonfield    me   04028       east parsonsfield    me
# 1355   04093           west buxton    me   04093                  buxton    me
# 1400   04255           locke mills    me   04255               greenwood    me
# 1471   04418             cardville    me   04418               greenbush    me
# 1656   04776         sherman mills    me   04776                 sherman    me
# 1657   04777       sherman station    me   04777              stacyville    me
# 1660   04781          soldier pond    me   04781              wallagrass    me
# 1700   04926                 china    me   04926           china village    me
# 1727   04961    north new portland    me   04961            new portland    me
# ...      ...                   ...   ...     ...                     ...   ...
# 38515  92518  march air force base    ca   92518  march air reserve base    ca
# 38692  93222          frazier park    ca   93222      pine mountain club    ca
# 38714  93250             mcfarland    ca   93250              mc farland    ca
# 38715  93251            mckittrick    ca   93251             mc kittrick    ca
# 38960  93652                raisin    ca   93652             raisin city    ca
# 39008  93921                carmel    ca   93921       carmel by the sea    ca
# 39396  94926                cotati    ca   94926            rohnert park    ca
# 39524  95296                 lyoth    ca   95296                stockton    ca
# 39526  95304                 banta    ca   95304                   tracy    ca
# 39558  95250           sheep ranch    ca   95250             san andreas    ca
# 39576  95314            dardanelle    ca   95314               pinecrest    ca
# 39687  95456           littleriver    ca   95456            little river    ca
# 39786  95618             el macero    ca   95618                   davis    ca
# 39817  95652         mcclellan afb    ca   95652               mcclellan    ca
# 39931  95923             canyondam    ca   95923              canyon dam    ca
# 39980  95977            smartville    ca   95977             smartsville    ca
# 40126  96373   hawaiian ocean view    hi   96373                     fpo    ap
# 40508  97472               saginaw    or   97472           cottage grove    or
# 40732  98082               bothell    wa   98082              mill creek    wa
# 40817  98113             shoreline    wa   98113                 seattle    wa
# 40913  98282                camano    wa   98282           camano island    wa
# 40979  98492              lakewood    wa   98492                  tacoma    wa
# 41041  98438                tacoma    wa   98438             mcchord afb    wa
# 41048  98448              parkland    wa   98448                  tacoma    wa
# 41256  98929         goose prairie    wa   98929                  naches    wa
# 41449  99505       fort richardson    ak   99505                    jber    ak
# 41450  99506         elmendorf afb    ak   99506                    jber    ak
# 41536  99627               mcgrath    ak   99627                mc grath    ak
# 41573  99666         sheldon point    ak   99666              nunam iqua    ak
# 41674  99779                tetlin    ak   99779                     tok    ak
#
# [501 rows x 6 columns]

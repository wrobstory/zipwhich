# %%
from math import radians, cos, sin, asin, sqrt
import pandas as pd
import numpy as np
import requests

# Import, lowercase city/state name to attempt join later

# Geonames is ~1:1 City/Place names to Zip Codes
# Schema: http://download.geonames.org/export/zip/readme.txt
col_names = ['country_code',
             'postal_code',
             'place_name',
             'admin_name1',
             'admin_code1',
             'admin_name2',
             'admin_code2',
             'admin_name3',
             'admin_code3',
             'latitude',
             'longitude',
             'accuracy']
geonames = pd.read_table('GeoNamesZip.txt', header=None, names=col_names, dtype={'postal_code': str})
geonames['place_name'] = geonames['place_name'].str.lower()
geonames['admin_code1'] = geonames['admin_code1'].str.lower()
geonames_set = set(geonames['postal_code'])

# Free-zip 1 is 1:1 City to Zip Code
free_zip_db = pd.read_csv('free-zipcode-database-Primary.csv', dtype={'Zipcode': str})
free_zip_db['City'] = free_zip_db['City'].str.lower()
free_zip_db['State'] = free_zip_db['State'].str.lower()
freezip_set = set(free_zip_db['Zipcode'])

# Free-zip all is Many:1 City to Zip Code
free_zip_all = pd.read_csv('free-zipcode-database-all-places.csv', dtype={'Zipcode': str})
# We only want Primary/Acceptable locs. There is some junk here.
free_zip_all = free_zip_all[free_zip_all['LocationType'].isin(['ACCEPTABLE', 'PRIMARY'])]
free_zip_all['City'] = free_zip_all['City'].str.lower()
free_zip_all['State'] = free_zip_all['State'].str.lower()
freezip_all_set = set(free_zip_all['Zipcode'])

# Noncensus is ~1:1 City to Zip Code
noncensus = pd.read_csv('noncensus_zip.csv', dtype={'zip': str})
noncensus['city'] = noncensus['city'].str.lower()
noncensus['state'] = noncensus['state'].str.lower()
noncensus_set = set(noncensus['zip'])

# How many unique zip codes do we have in each dataset?
set_lengths = {
    'noncensus_set': len(noncensus_set),
    'free_zip_set': len(freezip_set),
    'free_zip_all_set': len(freezip_all_set),
    'geonames_set': len(geonames_set)
    }
set_lengths
# Out:
# {'free_zip_all_set': 42522,
#  'free_zip_set': 42522,
#  'geonames_set': 43586,
#  'noncensus_set': 43524}

# %%
# How many total rows do we have (including duplicate zips)
len(geonames), len(free_zip_db), len(free_zip_all), len(noncensus)
# Out:
# (43629, 42522, 56725, 43524)

# %%
# Just use columns of interest, rename for specificity
geo_zip_place_loc = geonames[['postal_code', 'place_name', 'admin_code1',
                              'latitude', 'longitude']]
geo_zip_place_loc = geo_zip_place_loc.rename(columns={'postal_code': 'Zip_geo',
                                                      'latitude': 'Lat_geo', 
                                                      'longitude': 'Lon_geo',
                                                      'place_name': 'City_geo',
                                                      'admin_code1': 'State_geo'})

free_zip_all_place_loc = free_zip_all[['Zipcode', 'City', 'State', 'Lat', 'Long']]
free_zip_all_place_loc = free_zip_all_place_loc.rename(columns={'Zipcode': 'Zip_free',
                                                                'Lat': 'Lat_free',
                                                                'Long': 'Lon_free',
                                                                'City': 'City_free',
                                                                'State': 'State_free'})
noncensus_place_loc = noncensus[['zip', 'city', 'state', 'latitude', 'longitude']]
noncensus_place_loc = noncensus_place_loc.rename(columns={'zip': 'Zip_non',
                                                          'latitude': 'Lat_non', 
                                                          'longitude': 'Lon_non',
                                                          'city': 'City_non',
                                                          'state': 'State_non'})

# %% [markdown]
# Given that geonames contains the most unique zip codes, we're going to use it as the common join table between the other two.

# %%
# Join free-zip and geonames, right outer because we trust geonames a bit more
merged_free_geo_zip = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                               left_on='Zip_free', right_on='Zip_geo',
                               how='right')
merged_free_geo_zip_city = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                    left_on=['Zip_free', 'City_free'], 
                                    right_on=['Zip_geo', 'City_geo'],
                                    how='right')
merged_free_geo_zip_state = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                     left_on=['Zip_free', 'State_free'], 
                                     right_on=['Zip_geo', 'State_geo'],
                                     how='right')
merged_free_geo_zip_city_state = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                          left_on=['Zip_free', 'City_free', 'State_free'], 
                                          right_on=['Zip_geo', 'City_geo', 'State_geo'],
                                          how='right')
# Based on the join keys, how many resulting rows do we have? 
lengths_free_geo = {
    'merged_zip': len(merged_free_geo_zip),
    'merged_zip_city': len(merged_free_geo_zip_city),
    'merged_zip_state': len(merged_free_geo_zip_state),
    'merged_zip_city_state': len(merged_free_geo_zip_city_state)
}
lengths_free_geo
# Out:
# {'merged_zip': 57755,
#  'merged_zip_city': 43629,
#  'merged_zip_city_state': 43629,
#  'merged_zip_state': 57755}

# %%
merged_free_geo_zip.head()
# Out:
#   Zip_free       City_free State_free  Lat_free  Lon_free Zip_geo  \
# 0    07675        westwood         nj     40.98    -74.03   07675
# 1    07675      old tappan         nj     40.98    -74.03   07675
# 2    07675      river vale         nj     40.98    -74.03   07675
# 3    07675       rivervale         nj     40.98    -74.03   07675
# 4    07677  woodcliff lake         nj     41.02    -74.05   07677
#
#          City_geo State_geo  Lat_geo  Lon_geo
# 0        westwood        nj  41.0092 -74.0041
# 1        westwood        nj  41.0092 -74.0041
# 2        westwood        nj  41.0092 -74.0041
# 3        westwood        nj  41.0092 -74.0041
# 4  woodcliff lake        nj  41.0234 -74.0603

# %%
# Join geonames and noncensus, right outer on noncensus because we trust it more
merged_non_geo_zip = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                              left_on=['Zip_geo'], right_on=['Zip_non'],
                              how='left')
merged_non_geo_zip_city = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                                   left_on=['Zip_geo', 'City_geo'], 
                                   right_on=['Zip_non', 'City_non'],
                                   how='left')
merged_non_geo_zip_state = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                                    left_on=['Zip_geo', 'State_geo'], 
                                    right_on=['Zip_non', 'State_non'],
                                    how='left')
merged_non_geo_zip_city_state = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                                         left_on=['Zip_geo', 'City_geo', 'State_geo'], 
                                         right_on=['Zip_non', 'City_non', 'State_non'],
                                         how='left')
lengths_non_geo = {
    'merged_zip': len(merged_non_geo_zip),
    'merged_zip_city': len(merged_non_geo_zip_city),
    'merged_zip_state': len(merged_non_geo_zip_state),
    'merged_zip_city_state': len(merged_non_geo_zip_city_state)
}
lengths_non_geo
# Out:
# {'merged_zip': 43629,
#  'merged_zip_city': 43629,
#  'merged_zip_city_state': 43629,
#  'merged_zip_state': 43629}

# %%
merged_non_geo_zip.head()
# Out:
#   Zip_geo    City_geo State_geo  Lat_geo   Lon_geo Zip_non    City_non  \
# 0   34050         fpo        aa  41.0375 -111.6789     NaN         NaN
# 1   34034         apo        aa  33.0364  -82.2493     NaN         NaN
# 2   99553      akutan        ak  54.1430 -165.7854   99553      akutan
# 3   99571    cold bay        ak  55.3976 -162.4206   99571    cold bay
# 4   99583  false pass        ak  54.8410 -163.4368   99583  false pass
#
#   State_non    Lat_non    Lon_non
# 0       NaN        NaN        NaN
# 1       NaN        NaN        NaN
# 2        ak  54.098693 -165.88176
# 3        ak  55.315003 -162.63400
# 4        ak  54.849999 -163.42011

# %%
# Join the previous two joins into one another
merged_all = pd.merge(merged_free_geo_zip, merged_non_geo_zip,
                      how='inner',
                      left_on=['Zip_geo','State_geo'], 
                      right_on=['Zip_geo', 'State_geo'])
merged_all
# Out:
#       Zip_free           City_free State_free  Lat_free  Lon_free Zip_geo  \
# 0        07675            westwood         nj     40.98    -74.03   07675
# 1        07675          old tappan         nj     40.98    -74.03   07675
# 2        07675          river vale         nj     40.98    -74.03   07675
# 3        07675           rivervale         nj     40.98    -74.03   07675
# 4        07677      woodcliff lake         nj     41.02    -74.05   07677
# 5        07677            westwood         nj     41.02    -74.05   07677
# 6        07677        woodcliff lk         nj     41.02    -74.05   07677
# 7        07885             wharton         nj     40.89    -74.58   07885
# 8        07981            whippany         nj     40.82    -74.41   07981
# 9        07999            whippany         nj     40.82    -74.41   07999
# 10       08888          whitehouse         nj     40.62    -74.76   08888
# 11       08889  whitehouse station         nj     40.60    -74.76   08889
# 12       08889       white hse sta         nj     40.60    -74.76   08889
# 13       07095          woodbridge         nj     40.55    -74.28   07095
# 14       07481             wyckoff         nj     40.99    -74.16   07481
# 15       10451               bronx         ny     40.84    -73.87   10451
# 16       10452               bronx         ny     40.84    -73.87   10452
# 17       10453               bronx         ny     40.84    -73.87   10453
# 18       10454               bronx         ny     40.84    -73.87   10454
# 19       10455               bronx         ny     40.84    -73.87   10455
# 20       10456               bronx         ny     40.84    -73.87   10456
# 21       10457               bronx         ny     40.84    -73.87   10457
# 22       10458               bronx         ny     40.84    -73.87   10458
# 23       10459               bronx         ny     40.84    -73.87   10459
# 24       10460               bronx         ny     40.84    -73.87   10460
# 25       10461               bronx         ny     40.84    -73.87   10461
# 26       10462               bronx         ny     40.84    -73.87   10462
# 27       10463               bronx         ny     40.84    -73.87   10463
# 28       10464               bronx         ny     40.84    -73.87   10464
# 29       10465               bronx         ny     40.84    -73.87   10465
# ...        ...                 ...        ...       ...       ...     ...
# 57959      NaN                 NaN        NaN       NaN       NaN   25847
# 57960      NaN                 NaN        NaN       NaN       NaN   25856
# 57961      NaN                 NaN        NaN       NaN       NaN   25934
# 57962      NaN                 NaN        NaN       NaN       NaN   26145
# 57963      NaN                 NaN        NaN       NaN       NaN   26367
# 57964      NaN                 NaN        NaN       NaN       NaN   26407
# 57965      NaN                 NaN        NaN       NaN       NaN   25046
# 57966      NaN                 NaN        NaN       NaN       NaN   25246
# 57967      NaN                 NaN        NaN       NaN       NaN   25256
# 57968      NaN                 NaN        NaN       NaN       NaN   25281
# 57969      NaN                 NaN        NaN       NaN       NaN   24919
# 57970      NaN                 NaN        NaN       NaN       NaN   25973
# 57971      NaN                 NaN        NaN       NaN       NaN   25988
# 57972      NaN                 NaN        NaN       NaN       NaN   26290
# 57973      NaN                 NaN        NaN       NaN       NaN   26135
# 57974      NaN                 NaN        NaN       NaN       NaN   25519
# 57975      NaN                 NaN        NaN       NaN       NaN   26299
# 57976      NaN                 NaN        NaN       NaN       NaN   26186
# 57977      NaN                 NaN        NaN       NaN       NaN   25255
# 57978      NaN                 NaN        NaN       NaN       NaN   26185
# 57979      NaN                 NaN        NaN       NaN       NaN   24896
# 57980      NaN                 NaN        NaN       NaN       NaN   82057
# 57981      NaN                 NaN        NaN       NaN       NaN   82080
# 57982      NaN                 NaN        NaN       NaN       NaN   82631
# 57983      NaN                 NaN        NaN       NaN       NaN   82713
# 57984      NaN                 NaN        NaN       NaN       NaN   82724
# 57985      NaN                 NaN        NaN       NaN       NaN   82427
# 57986      NaN                 NaN        NaN       NaN       NaN   82220
# 57987      NaN                 NaN        NaN       NaN       NaN   82228
# 57988      NaN                 NaN        NaN       NaN       NaN   82926
#
#                City_geo_x State_geo  Lat_geo_x  Lon_geo_x          City_geo_y  \
# 0                westwood        nj    41.0092   -74.0041            westwood
# 1                westwood        nj    41.0092   -74.0041            westwood
# 2                westwood        nj    41.0092   -74.0041            westwood
# 3                westwood        nj    41.0092   -74.0041            westwood
# 4          woodcliff lake        nj    41.0234   -74.0603      woodcliff lake
# 5          woodcliff lake        nj    41.0234   -74.0603      woodcliff lake
# 6          woodcliff lake        nj    41.0234   -74.0603      woodcliff lake
# 7                 wharton        nj    40.9139   -74.5863             wharton
# 8                whippany        nj    40.8219   -74.4200            whippany
# 9                whippany        nj    40.8673   -74.5783            whippany
# 10             whitehouse        nj    40.6194   -74.7406          whitehouse
# 11     whitehouse station        nj    40.6156   -74.7724  whitehouse station
# 12     whitehouse station        nj    40.6156   -74.7724  whitehouse station
# 13             woodbridge        nj    40.5560   -74.2845          woodbridge
# 14                wyckoff        nj    40.9978   -74.1660             wyckoff
# 15                  bronx        ny    40.8222   -73.9217               bronx
# 16                  bronx        ny    40.8376   -73.9216               bronx
# 17                  bronx        ny    40.8520   -73.9129               bronx
# 18                  bronx        ny    40.8085   -73.9198               bronx
# 19                  bronx        ny    40.8153   -73.9072               bronx
# 20                  bronx        ny    40.8316   -73.9099               bronx
# 21                  bronx        ny    40.8486   -73.8999               bronx
# 22                  bronx        ny    40.8633   -73.8895               bronx
# 23                  bronx        ny    40.8247   -73.8940               bronx
# 24                  bronx        ny    40.8409   -73.8794               bronx
# 25                  bronx        ny    40.8465   -73.8410               bronx
# 26                  bronx        ny    40.8434   -73.8602               bronx
# 27                  bronx        ny    40.8798   -73.9067               bronx
# 28                  bronx        ny    40.8469   -73.7874               bronx
# 29                  bronx        ny    40.8261   -73.8196               bronx
# ...                   ...       ...        ...        ...                 ...
# 57959         glen morgan        wv    37.7134   -81.1788         glen morgan
# 57960              jonben        wv    37.6479   -81.1906              jonben
# 57961               terry        wv    37.8490   -81.0937               terry
# 57962          five forks        wv    38.9751   -81.0847          five forks
# 57963          hazelgreen        wv    39.0631   -80.9806          hazelgreen
# 57964            mountain        wv    39.1985   -81.0689            mountain
# 57965                clio        wv    38.7317   -81.3146                clio
# 57966             harmony        wv    38.6921   -81.5076             harmony
# 57967              linden        wv    38.7317   -81.3146              linden
# 57968              tariff        wv    38.7317   -81.3146              tariff
# 57969           ballengee        wv    37.6748   -80.8900           ballengee
# 57970          lockbridge        wv    37.8274   -80.8451          lockbridge
# 57971                true        wv    37.6485   -80.8774                true
# 57972        saint george        wv    39.1666   -79.7024        saint george
# 57973            bens run        wv    39.4506   -80.8701            bens run
# 57974           glenhayes        wv    38.1321   -82.4183           glenhayes
# 57975               boggs        wv    38.4821   -80.6074               boggs
# 57976          wileyville        wv    39.5755   -80.6667          wileyville
# 57977          letter gap        wv    38.9079   -80.9027          letter gap
# 57978                wick        wv    39.4217   -80.9680                wick
# 57979            wolf pen        wv    37.6033   -81.5400            wolf pen
# 57980             laramie        wy    41.1095  -106.2190             laramie
# 57981            mcfadden        wy    41.6327  -106.1379            mcfadden
# 57982                bill        wy    42.8942  -105.4852                bill
# 57983             carlile        wy    44.5259  -104.7678             carlile
# 57984              oshoto        wy    44.5887  -104.9832              oshoto
# 57985       hamilton dome        wy    43.7698  -108.4541       hamilton dome
# 57986             keeline        wy    42.8391  -104.7203             keeline
# 57987                node        wy    42.7478  -104.2963                node
# 57988        rock springs        wy    42.0508  -109.4363        rock springs
#
#        Lat_geo_y  Lon_geo_y Zip_non            City_non State_non    Lat_non  \
# 0        41.0092   -74.0041   07675            westwood        nj  40.999040
# 1        41.0092   -74.0041   07675            westwood        nj  40.999040
# 2        41.0092   -74.0041   07675            westwood        nj  40.999040
# 3        41.0092   -74.0041   07675            westwood        nj  40.999040
# 4        41.0234   -74.0603   07677      woodcliff lake        nj  41.025101
# 5        41.0234   -74.0603   07677      woodcliff lake        nj  41.025101
# 6        41.0234   -74.0603   07677      woodcliff lake        nj  41.025101
# 7        40.9139   -74.5863   07885             wharton        nj  40.913298
# 8        40.8219   -74.4200   07981            whippany        nj  40.821482
# 9        40.8673   -74.5783   07999            whippany        nj  40.867331
# 10       40.6194   -74.7406   08888          whitehouse        nj  40.619412
# 11       40.6156   -74.7724   08889  whitehouse station        nj  40.612851
# 12       40.6156   -74.7724   08889  whitehouse station        nj  40.612851
# 13       40.5560   -74.2845   07095          woodbridge        nj  40.557104
# 14       40.9978   -74.1660   07481             wyckoff        nj  40.998583
# 15       40.8222   -73.9217   10451               bronx        ny  40.819729
# 16       40.8376   -73.9216   10452               bronx        ny  40.838745
# 17       40.8520   -73.9129   10453               bronx        ny  40.853017
# 18       40.8085   -73.9198   10454               bronx        ny  40.805968
# 19       40.8153   -73.9072   10455               bronx        ny  40.815559
# 20       40.8316   -73.9099   10456               bronx        ny  40.829676
# 21       40.8486   -73.8999   10457               bronx        ny  40.846745
# 22       40.8633   -73.8895   10458               bronx        ny  40.864166
# 23       40.8247   -73.8940   10459               bronx        ny  40.825432
# 24       40.8409   -73.8794   10460               bronx        ny  40.840950
# 25       40.8465   -73.8410   10461               bronx        ny  40.842917
# 26       40.8434   -73.8602   10462               bronx        ny  40.842173
# 27       40.8798   -73.9067   10463               bronx        ny  40.881086
# 28       40.8469   -73.7874   10464               bronx        ny  40.857017
# 29       40.8261   -73.8196   10465               bronx        ny  40.825727
# ...          ...        ...     ...                 ...       ...        ...
# 57959    37.7134   -81.1788   25847         glen morgan        wv  37.723290
# 57960    37.6479   -81.1906   25856              jonben        wv  37.653792
# 57961    37.8490   -81.0937   25934               terry        wv  37.848955
# 57962    38.9751   -81.0847   26145           pennsboro        wv  39.288336
# 57963    39.0631   -80.9806     NaN                 NaN       NaN        NaN
# 57964    39.1985   -81.0689   26407            mountain        wv  39.198501
# 57965    38.7317   -81.3146   25046                clio        wv  38.731737
# 57966    38.6921   -81.5076     NaN                 NaN       NaN        NaN
# 57967    38.7317   -81.3146   25256              linden        wv  38.731737
# 57968    38.7317   -81.3146   25281              tariff        wv  38.682668
# 57969    37.6748   -80.8900   24919           ballengee        wv  37.620418
# 57970    37.8274   -80.8451     NaN                 NaN       NaN        NaN
# 57971    37.6485   -80.8774   25988                true        wv  37.648541
# 57972    39.1666   -79.7024     NaN                 NaN       NaN        NaN
# 57973    39.4506   -80.8701   26135            bens run        wv  39.450612
# 57974    38.1321   -82.4183   25519           glenhayes        wv  38.132114
# 57975    38.4821   -80.6074     NaN                 NaN       NaN        NaN
# 57976    39.5755   -80.6667   26186          wileyville        wv  39.619007
# 57977    38.9079   -80.9027     NaN                 NaN       NaN        NaN
# 57978    39.4217   -80.9680     NaN                 NaN       NaN        NaN
# 57979    37.6033   -81.5400   24896            wolf pen        wv  37.603344
# 57980    41.1095  -106.2190     NaN                 NaN       NaN        NaN
# 57981    41.6327  -106.1379     NaN                 NaN       NaN        NaN
# 57982    42.8942  -105.4852   82631                bill        wy  42.894249
# 57983    44.5259  -104.7678   82713             carlile        wy  44.525891
# 57984    44.5887  -104.9832     NaN                 NaN       NaN        NaN
# 57985    43.7698  -108.4541   82427       hamilton dome        wy  43.769760
# 57986    42.8391  -104.7203     NaN                 NaN       NaN        NaN
# 57987    42.7478  -104.2963     NaN                 NaN       NaN        NaN
# 57988    42.0508  -109.4363     NaN                 NaN       NaN        NaN
#
#           Lon_non
# 0      -74.032910
# 1      -74.032910
# 2      -74.032910
# 3      -74.032910
# 4      -74.059762
# 5      -74.059762
# 6      -74.059762
# 7      -74.582460
# 8      -74.426480
# 9      -74.578269
# 10     -74.740597
# 11     -74.766820
# 12     -74.766820
# 13     -74.283160
# 14     -74.167100
# 15     -73.922300
# 16     -73.922340
# 17     -73.912140
# 18     -73.916280
# 19     -73.907710
# 20     -73.908560
# 21     -73.898610
# 22     -73.888810
# 23     -73.893270
# 24     -73.880360
# 25     -73.838190
# 26     -73.858620
# 27     -73.907490
# 28     -73.789030
# 29     -73.817520
# ...           ...
# 57959  -81.174440
# 57960  -81.188330
# 57961  -81.093678
# 57962  -80.968967
# 57963         NaN
# 57964  -81.068913
# 57965  -81.314633
# 57966         NaN
# 57967  -81.314633
# 57968  -81.188460
# 57969  -80.716360
# 57970         NaN
# 57971  -80.877395
# 57972         NaN
# 57973  -80.870081
# 57974  -82.418277
# 57975         NaN
# 57976  -80.612250
# 57977         NaN
# 57978         NaN
# 57979  -81.539980
# 57980         NaN
# 57981         NaN
# 57982 -105.485243
# 57983 -104.767846
# 57984         NaN
# 57985 -108.454106
# 57986         NaN
# 57987         NaN
# 57988         NaN
#
# [57989 rows x 18 columns]

# %%
# Reorder, and we only want to keep one of the Geo join key columns
master_zips = merged_all[['Zip_free', 'Zip_geo', 'Zip_non',
                          'City_free', 'City_geo_x', 'City_non',
                          'State_free', 'State_geo', 'State_non',
                          'Lat_free', 'Lat_geo_x', 'Lat_non',
                          'Lon_free', 'Lon_geo_x', 'Lon_non']]
master_zips = master_zips.rename(columns={'City_geo_x': 'City_geo',
                                          'Lon_geo_x': 'Lon_geo', 
                                          'Lat_geo_x': 'Lat_geo'})
master_zips.head()
# Out:
#   Zip_free Zip_geo Zip_non       City_free        City_geo        City_non  \
# 0    07675   07675   07675        westwood        westwood        westwood
# 1    07675   07675   07675      old tappan        westwood        westwood
# 2    07675   07675   07675      river vale        westwood        westwood
# 3    07675   07675   07675       rivervale        westwood        westwood
# 4    07677   07677   07677  woodcliff lake  woodcliff lake  woodcliff lake
#
#   State_free State_geo State_non  Lat_free  Lat_geo    Lat_non  Lon_free  \
# 0         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 1         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 2         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 3         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 4         nj        nj        nj     41.02  41.0234  41.025101    -74.05
#
#    Lon_geo    Lon_non
# 0 -74.0041 -74.032910
# 1 -74.0041 -74.032910
# 2 -74.0041 -74.032910
# 3 -74.0041 -74.032910
# 4 -74.0603 -74.059762

# %%
# Get a Primary City/State based on dataset agreement. Default to noncensus as "most trusted"
abbrev_to_full = {"AA": "US Armed Forces (Americas)",
                  "AE": "US Armed Forces (Europe)",
                  "AP": "US Armed Forces (Pacific)",
                  "AL": "Alabama",
                  "AK": "Alaska",
                  "AS": "American Samoa",
                  "AZ": "Arizona",
                  "AR": "Arkansas",
                  "CA": "California",
                  "CO": "Colorado",
                  "CT": "Connecticut",
                  "DE": "Delaware",
                  "DC": "District Of Columbia",
                  "FM": "Federated States Of Micronesia",
                  "FL": "Florida",
                  "GA": "Georgia",
                  "GU": "Guam",
                  "HI": "Hawaii",
                  "ID": "Idaho",
                  "IL": "Illinois",
                  "IN": "Indiana",
                  "IA": "Iowa",
                  "KS": "Kansas",
                  "KY": "Kentucky",
                  "LA": "Louisiana",
                  "ME": "Maine",
                  "MH": "Marshall Islands",
                  "MD": "Maryland",
                  "MA": "Massachusetts",
                  "MI": "Michigan",
                  "MN": "Minnesota",
                  "MS": "Mississippi",
                  "MO": "Missouri",
                  "MT": "Montana",
                  "NE": "Nebraska",
                  "NV": "Nevada",
                  "NH": "New Hampshire",
                  "NJ": "New Jersey",
                  "NM": "New Mexico",
                  "NY": "New York",
                  "NC": "North Carolina",
                  "ND": "North Dakota",
                  "MP": "Northern Mariana Islands",
                  "OH": "Ohio",
                  "OK": "Oklahoma",
                  "OR": "Oregon",
                  "PW": "Palau",
                  "PA": "Pennsylvania",
                  "PR": "Puerto Rico",
                  "RI": "Rhode Island",
                  "SC": "South Carolina",
                  "SD": "South Dakota",
                  "TN": "Tennessee",
                  "TX": "Texas",
                  "UT": "Utah",
                  "VT": "Vermont",
                  "VI": "Virgin Islands",
                  "VA": "Virginia",
                  "WA": "Washington",
                  "WV": "West Virginia",
                  "WI": "Wisconsin",
                  "WY": "Wyoming"}
def get_primary(r):
    cities = filter(lambda x: isinstance(x, str),
                    [r['City_free'], r['City_geo'], r['City_non']])
    states = filter(lambda x: isinstance(x, str),
                    [r['State_free'], r['State_geo'], r['State_non']])
    
    def get_most_common(lst):
        cet = set(lst)
        write_val = None
        if len(cet) == 1:
            # If they all agree, use that value
            write_val = cet.pop()
        elif len(cet) == 2:
            # If 2/3 agree, go with it
            write_val = max(cet, key=lst.count)
        else:
            # Default to noncensus for now
            write_val = r['City_non']
        return write_val
    
    r['Primary_City'] = get_most_common(cities)
    r['Primary_State'] = get_most_common(states)
    full_name = abbrev_to_full.get(r['Primary_State'].upper())
    if not full_name:
        import pdb;pdb.set_trace()
    r['Primary_State_Full'] = full_name
    return r
master_zips_primary = master_zips.apply(get_primary, axis=1)
master_zips_primary.head()
# Out:
#   Zip_free Zip_geo Zip_non       City_free        City_geo        City_non  \
# 0    07675   07675   07675        westwood        westwood        westwood
# 1    07675   07675   07675      old tappan        westwood        westwood
# 2    07675   07675   07675      river vale        westwood        westwood
# 3    07675   07675   07675       rivervale        westwood        westwood
# 4    07677   07677   07677  woodcliff lake  woodcliff lake  woodcliff lake
#
#   State_free State_geo State_non  Lat_free  Lat_geo    Lat_non  Lon_free  \
# 0         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 1         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 2         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 3         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 4         nj        nj        nj     41.02  41.0234  41.025101    -74.05
#
#    Lon_geo    Lon_non    Primary_City Primary_State Primary_State_Full
# 0 -74.0041 -74.032910        westwood            nj         New Jersey
# 1 -74.0041 -74.032910        westwood            nj         New Jersey
# 2 -74.0041 -74.032910        westwood            nj         New Jersey
# 3 -74.0041 -74.032910        westwood            nj         New Jersey
# 4 -74.0603 -74.059762  woodcliff lake            nj         New Jersey

# %%
# Using the TwoFishes geocoder (http://twofishes.net/), try to get better geo accuracy
# In related news, this is a nice way to stress test a geocoder
def get_twofishes(row):
    twofishes_url = 'http://localhost:8081/search/geocode'
    city, state = row['Primary_City'], row['Primary_State_Full']
    if city and state:
        query = '{{"query": "{}, {}"}}'.format(city, state)
        tf_resp = requests.get(twofishes_url, params={'json': query})
        jsond = tf_resp.json()
        if not jsond['interpretations']:
            center = {'lat': np.nan, 'lng': np.nan}
        else:
            center = jsond['interpretations'][0]['feature']['geometry']['center']
        row['Lat_TwoFishes'] = center['lat']
        row['Lon_TwoFishes'] = center['lng']
    else:
        row['Lat_TwoFishes'] = np.nan
        row['Lon_TwoFishes'] = np.nan
    return row

master_zips_twofishes = master_zips_primary.apply(get_twofishes, axis=1)

# %%
master_zips_twofishes.head(20)
# Out:
#    Zip_free Zip_geo Zip_non           City_free            City_geo  \
# 0     07675   07675   07675            westwood            westwood
# 1     07675   07675   07675          old tappan            westwood
# 2     07675   07675   07675          river vale            westwood
# 3     07675   07675   07675           rivervale            westwood
# 4     07677   07677   07677      woodcliff lake      woodcliff lake
# 5     07677   07677   07677            westwood      woodcliff lake
# 6     07677   07677   07677        woodcliff lk      woodcliff lake
# 7     07885   07885   07885             wharton             wharton
# 8     07981   07981   07981            whippany            whippany
# 9     07999   07999   07999            whippany            whippany
# 10    08888   08888   08888          whitehouse          whitehouse
# 11    08889   08889   08889  whitehouse station  whitehouse station
# 12    08889   08889   08889       white hse sta  whitehouse station
# 13    07095   07095   07095          woodbridge          woodbridge
# 14    07481   07481   07481             wyckoff             wyckoff
# 15    10451   10451   10451               bronx               bronx
# 16    10452   10452   10452               bronx               bronx
# 17    10453   10453   10453               bronx               bronx
# 18    10454   10454   10454               bronx               bronx
# 19    10455   10455   10455               bronx               bronx
#
#               City_non State_free State_geo State_non  Lat_free  Lat_geo  \
# 0             westwood         nj        nj        nj     40.98  41.0092
# 1             westwood         nj        nj        nj     40.98  41.0092
# 2             westwood         nj        nj        nj     40.98  41.0092
# 3             westwood         nj        nj        nj     40.98  41.0092
# 4       woodcliff lake         nj        nj        nj     41.02  41.0234
# 5       woodcliff lake         nj        nj        nj     41.02  41.0234
# 6       woodcliff lake         nj        nj        nj     41.02  41.0234
# 7              wharton         nj        nj        nj     40.89  40.9139
# 8             whippany         nj        nj        nj     40.82  40.8219
# 9             whippany         nj        nj        nj     40.82  40.8673
# 10          whitehouse         nj        nj        nj     40.62  40.6194
# 11  whitehouse station         nj        nj        nj     40.60  40.6156
# 12  whitehouse station         nj        nj        nj     40.60  40.6156
# 13          woodbridge         nj        nj        nj     40.55  40.5560
# 14             wyckoff         nj        nj        nj     40.99  40.9978
# 15               bronx         ny        ny        ny     40.84  40.8222
# 16               bronx         ny        ny        ny     40.84  40.8376
# 17               bronx         ny        ny        ny     40.84  40.8520
# 18               bronx         ny        ny        ny     40.84  40.8085
# 19               bronx         ny        ny        ny     40.84  40.8153
#
#       Lat_non  Lon_free  Lon_geo    Lon_non        Primary_City Primary_State  \
# 0   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 1   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 2   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 3   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 4   41.025101    -74.05 -74.0603 -74.059762      woodcliff lake            nj
# 5   41.025101    -74.05 -74.0603 -74.059762      woodcliff lake            nj
# 6   41.025101    -74.05 -74.0603 -74.059762      woodcliff lake            nj
# 7   40.913298    -74.58 -74.5863 -74.582460             wharton            nj
# 8   40.821482    -74.41 -74.4200 -74.426480            whippany            nj
# 9   40.867331    -74.41 -74.5783 -74.578269            whippany            nj
# 10  40.619412    -74.76 -74.7406 -74.740597          whitehouse            nj
# 11  40.612851    -74.76 -74.7724 -74.766820  whitehouse station            nj
# 12  40.612851    -74.76 -74.7724 -74.766820  whitehouse station            nj
# 13  40.557104    -74.28 -74.2845 -74.283160          woodbridge            nj
# 14  40.998583    -74.16 -74.1660 -74.167100             wyckoff            nj
# 15  40.819729    -73.87 -73.9217 -73.922300               bronx            ny
# 16  40.838745    -73.87 -73.9216 -73.922340               bronx            ny
# 17  40.853017    -73.87 -73.9129 -73.912140               bronx            ny
# 18  40.805968    -73.87 -73.9198 -73.916280               bronx            ny
# 19  40.815559    -73.87 -73.9072 -73.907710               bronx            ny
#
#    Primary_State_Full  Lat_TwoFishes  Lon_TwoFishes
# 0          New Jersey       40.99121      -74.03264
# 1          New Jersey       40.99121      -74.03264
# 2          New Jersey       40.99121      -74.03264
# 3          New Jersey       40.99121      -74.03264
# 4          New Jersey       41.02343      -74.06653
# 5          New Jersey       41.02343      -74.06653
# 6          New Jersey       41.02343      -74.06653
# 7          New Jersey       40.89315      -74.58183
# 8          New Jersey       40.82454      -74.41710
# 9          New Jersey       40.82454      -74.41710
# 10         New Jersey       40.61844      -74.74433
# 11         New Jersey       40.61538      -74.77044
# 12         New Jersey       40.61538      -74.77044
# 13         New Jersey       40.55760      -74.28459
# 14         New Jersey       41.00954      -74.17292
# 15           New York       40.84985      -73.86641
# 16           New York       40.84985      -73.86641
# 17           New York       40.84985      -73.86641
# 18           New York       40.84985      -73.86641
# 19           New York       40.84985      -73.86641

# %%
# Let's check the max Haversine distance between points
def check_haversine(row):
    """
    Great circle distance between our Lat/Lon points (dec degrees)
    """
    # Ranking in order of "most trusted" to "least trusted"
    ranks = {1: "TwoFishes", 2: "non", 3: "geo", 4: "free"}
    
    # Convert to Radians   
                           
    rad_lat_1, rad_lon_1 = map(radians, [row['Lat_TwoFishes'], row['Lon_TwoFishes']])
    rad_lat_2, rad_lon_2 = map(radians, [row['Lat_non'], row['Lon_non']])
    rad_lat_3, rad_lon_3 = map(radians, [row['Lat_geo'], row['Lon_geo']])
    rad_lat_4, rad_lon_4 = map(radians, [row['Lat_free'], row['Lon_free']])
    
    
    # 1 vs 2, 1 vs 3, 1 vs 4, 2 vs 3, 2 vs 4, 3 vs 4
    pairs = [{'Pair': 'TwoFishes vs Non',
              'Ranks': [1, 2],
              'Data': (rad_lat_1, rad_lon_1, rad_lat_2, rad_lon_2)},
             {'Pair': 'TwoFishes vs Geo', 
              'Ranks': [1, 3],
              'Data': (rad_lat_1, rad_lon_1, rad_lat_3, rad_lon_3)},
             {'Pair': 'TwoFishes vs. Free',
              'Ranks': [1, 4],
              'Data': (rad_lat_1, rad_lon_1, rad_lat_4, rad_lon_4)},
             {'Pair': 'Non vs. Geo', 
              'Ranks': [2, 3],
              'Data': (rad_lat_2, rad_lon_2, rad_lat_3, rad_lon_3)},
             {'Pair': 'Non vs Free',
              'Ranks': [2, 4],
              'Data': (rad_lat_2, rad_lon_2, rad_lat_4, rad_lon_4)},
             {'Pair': 'Geo vs Free', 
              'Ranks': [3, 4],
              'Data': (rad_lat_3, rad_lon_3, rad_lat_4, rad_lon_4)}]
    
    # Only get pairs that don't have nan vals
    filtered_pairs = filter(lambda x: not any(map(np.isnan, x['Data'])), pairs)

    def get_dist(lat_1, lon_1, lat_2, lon_2):
        under_root = (sin((lat_2 - lat_1)/2)**2 + 
                      cos(lat_1) * cos(lat_2) * sin((lon_2 - lon_1)/2)**2)
        # 6367 = Earth radius in kilometers
        return 6367 * 2 * asin(sqrt(under_root)) 
        
    distanced_pairs = [{'Pair': p['Pair'],
                        'Best_Rank': min(p['Ranks']),
                        'Dist': get_dist(*p['Data'])} for p in filtered_pairs]
    
    # What if we have zero pairs?
    if not distanced_pairs:
        max_dist = {'Dist': np.nan, 'Pair': 'No Pair Found', 'Best_Rank': 1}
        min_dist = {'Dist': np.nan, 'Pair': 'No Pair Found', 'Best_Rank': 1}
    else:
        max_dist = max(distanced_pairs, key=lambda x: x['Dist'])
        min_dist = min(distanced_pairs, key=lambda x: x['Dist'])
    
    row['Max_Haversine_Dist'] = max_dist['Dist']
    row['Max_Dist_Pair'] = max_dist['Pair']
    
    row['Min_Haversine_Dist'] = min_dist['Dist']
    row['Min_Dist_Pair'] = min_dist['Pair']
    # If TwoFishes and Non agree closely, go with that data point
    # Otherwise, given the minimum distance set of points, which one of the two points is most trusted?
    fish_non = filter(lambda x: x['Pair'] == 'TwoFishes vs Non', distanced_pairs)
    if fish_non and fish_non[0]['Dist'] < 1.0:
        chosen = fish_non[0]
    else:
        chosen = min_dist
    trusted = ranks[chosen['Best_Rank']]
    trust_lat_nm, trust_lon_nm = 'Lat_' + trusted, 'Lon_' + trusted
    row['Primary_Geo_Source'] = trusted.capitalize()
    row['Lat_primary'] = row[trust_lat_nm]
    row['Lon_primary'] = row[trust_lon_nm]
    return row

master_zips_haversine = master_zips_twofishes.apply(check_haversine, axis=1)

# %%
# What are our worst-case distance errors?
master_zips_haversine.sort('Min_Haversine_Dist', ascending=False).head(50)
# Out:
#       Zip_free Zip_geo Zip_non    City_free              City_geo   City_non  \
# 57987      NaN   82228     NaN          NaN                  node        NaN
# 56216      NaN   96045     NaN          NaN           horse creek        NaN
# 57020      NaN   49909     NaN          NaN             beechwood        NaN
# 57147      NaN   59017     NaN          NaN             cat creek        NaN
# 57604      NaN   79489     NaN          NaN  reese air force base        NaN
# 56241      NaN   81333     NaN          NaN            slick rock        NaN
# 56776      NaN   40465     NaN          NaN                parrot        NaN
# 57126      NaN   39055     NaN          NaN           church hill        NaN
# 57000      NaN   49843     NaN          NaN      k i sawyer a f b        NaN
# 56743      NaN   42155     NaN          NaN                  lamb        NaN
# 57416      NaN   73849     NaN          NaN                 logan        NaN
# 56544      NaN   60799     NaN          NaN           chicago bmc        NaN
# 57278      NaN   10951     NaN          NaN        rockland m p c        NaN
# 57139      NaN   38779     NaN          NaN              tribbett        NaN
# 57736      NaN   23935     NaN          NaN    darlington heights        NaN
# 56749      NaN   40970     NaN          NaN                 mills        NaN
# 57307      NaN   14474     NaN          NaN              industry        NaN
# 57363      NaN   14584     NaN          NaN      webster crossing        NaN
# 57940      NaN   26360     NaN          NaN             greenwood        NaN
# 56825      NaN   41570     NaN          NaN          turkey creek        NaN
# 33446    96898   96898     NaN  wake island           wake island        NaN
# 56667      NaN   41369     NaN          NaN                saldee        NaN
# 56071      NaN   72378     NaN          NaN            round pond        NaN
# 56021      NaN   36419     NaN          NaN                 allen        NaN
# 56443      NaN   30158     NaN          NaN           north metro        NaN
# 56501      NaN   52725     NaN          NaN              big rock        NaN
# 56783      NaN   41443     NaN          NaN                 insko        NaN
# 57538      NaN   37358     NaN          NaN          mount vernon        NaN
# 56234      NaN   80806     NaN          NaN                boyero        NaN
# 57065      NaN   55754     NaN          NaN            kelly lake        NaN
# 56805      NaN   41474     NaN          NaN             white oak        NaN
# 57274      NaN   12753     NaN          NaN             lew beach        NaN
# 57534      NaN   57527     NaN          NaN            cedarbutte        NaN
# 57884      NaN   25272     NaN          NaN           rock castle        NaN
# 57947      NaN   26322     NaN          NaN                  alvy        NaN
# 57948      NaN   26383     NaN          NaN                  lima        NaN
# 57735      NaN   23137     NaN          NaN            plain view        NaN
# 57842      NaN   25274     NaN          NaN            sand ridge        NaN
# 57890      NaN   25105     NaN          NaN              harrison        NaN
# 56621      NaN   66262     NaN          NaN       shawnee mission        NaN
# 57152      NaN   28648     NaN          NaN            longisland        NaN
# 57711      NaN   23080     NaN          NaN           james store        NaN
# 56849      NaN   41328     NaN          NaN            green hall        NaN
# 56813      NaN   41720     NaN          NaN           browns fork        NaN
# 56808      NaN   42358     NaN          NaN               narrows        NaN
# 56854      NaN   71318     NaN          NaN              big bend        NaN
# 56883      NaN   01539     NaN          NaN               oakdale        NaN
# 57676      NaN   22559     NaN          NaN                supply        NaN
# 56061      NaN   72844     NaN          NaN                  hunt        NaN
# 57508      NaN   57628   57628          NaN             firesteel  firesteel
#
#       State_free State_geo State_non  Lat_free     ...       \
# 57987        NaN        wy       NaN       NaN     ...
# 56216        NaN        ca       NaN       NaN     ...
# 57020        NaN        mi       NaN       NaN     ...
# 57147        NaN        mt       NaN       NaN     ...
# 57604        NaN        tx       NaN       NaN     ...
# 56241        NaN        co       NaN       NaN     ...
# 56776        NaN        ky       NaN       NaN     ...
# 57126        NaN        ms       NaN       NaN     ...
# 57000        NaN        mi       NaN       NaN     ...
# 56743        NaN        ky       NaN       NaN     ...
# 57416        NaN        ok       NaN       NaN     ...
# 56544        NaN        il       NaN       NaN     ...
# 57278        NaN        ny       NaN       NaN     ...
# 57139        NaN        ms       NaN       NaN     ...
# 57736        NaN        va       NaN       NaN     ...
# 56749        NaN        ky       NaN       NaN     ...
# 57307        NaN        ny       NaN       NaN     ...
# 57363        NaN        ny       NaN       NaN     ...
# 57940        NaN        wv       NaN       NaN     ...
# 56825        NaN        ky       NaN       NaN     ...
# 33446         hi        hi       NaN     21.32     ...
# 56667        NaN        ky       NaN       NaN     ...
# 56071        NaN        ar       NaN       NaN     ...
# 56021        NaN        al       NaN       NaN     ...
# 56443        NaN        ga       NaN       NaN     ...
# 56501        NaN        ia       NaN       NaN     ...
# 56783        NaN        ky       NaN       NaN     ...
# 57538        NaN        tn       NaN       NaN     ...
# 56234        NaN        co       NaN       NaN     ...
# 57065        NaN        mn       NaN       NaN     ...
# 56805        NaN        ky       NaN       NaN     ...
# 57274        NaN        ny       NaN       NaN     ...
# 57534        NaN        sd       NaN       NaN     ...
# 57884        NaN        wv       NaN       NaN     ...
# 57947        NaN        wv       NaN       NaN     ...
# 57948        NaN        wv       NaN       NaN     ...
# 57735        NaN        va       NaN       NaN     ...
# 57842        NaN        wv       NaN       NaN     ...
# 57890        NaN        wv       NaN       NaN     ...
# 56621        NaN        ks       NaN       NaN     ...
# 57152        NaN        nc       NaN       NaN     ...
# 57711        NaN        va       NaN       NaN     ...
# 56849        NaN        ky       NaN       NaN     ...
# 56813        NaN        ky       NaN       NaN     ...
# 56808        NaN        ky       NaN       NaN     ...
# 56854        NaN        la       NaN       NaN     ...
# 56883        NaN        ma       NaN       NaN     ...
# 57676        NaN        va       NaN       NaN     ...
# 56061        NaN        ar       NaN       NaN     ...
# 57508        NaN        sd        sd       NaN     ...
#
#        Primary_State_Full  Lat_TwoFishes  Lon_TwoFishes  Max_Haversine_Dist  \
# 57987             Wyoming       42.91336      -85.70531         1512.104821
# 56216          California       38.41463     -120.91355          419.736210
# 57020            Michigan       42.79697      -86.12588          417.020318
# 57147             Montana       45.34298     -112.94476          411.398003
# 57604               Texas       31.25044      -99.25061          368.379699
# 56241            Colorado       39.00027     -105.50083          313.096135
# 56776            Kentucky       37.31925      -84.05854          311.335389
# 57126         Mississippi       33.55151      -89.28729          275.433971
# 57000            Michigan       44.25029      -85.50033          273.038086
# 56743            Kentucky       38.95617      -84.44800          270.760720
# 57416            Oklahoma       35.91934      -97.44332          257.961721
# 56544            Illinois       40.00032      -89.25037          255.672620
# 57278            New York       43.00035      -75.49990          240.191041
# 57139         Mississippi       33.35151      -90.79843          214.564886
# 57736            Virginia       37.20015      -78.60417          193.211509
# 56749            Kentucky       38.20042      -84.87762          179.331839
# 57307            New York       43.00035      -75.49990          178.520355
# 57363            New York       43.00035      -75.49990          177.844551
# 57940       West Virginia       37.85539      -81.63067          171.946837
# 56825            Kentucky       36.77397      -83.73297          158.556276
# 33446              Hawaii       20.75028     -156.50028         3843.650817
# 56667            Kentucky       38.20042      -84.87762          155.820093
# 56071            Arkansas       33.76039      -91.16122          153.632587
# 56021             Alabama       32.75041      -86.75026          152.269775
# 56443             Georgia       32.75042      -83.50018          151.762001
# 56501                Iowa       42.55165      -92.29796          149.121839
# 56783            Kentucky       38.20042      -84.87762          146.610329
# 57538           Tennessee       36.17645      -85.52220          134.603897
# 56234            Colorado       38.94277     -103.27911          133.563495
# 57065           Minnesota       46.37717      -93.74067          128.354392
# 56805            Kentucky       37.73786      -84.64300          127.098865
# 57274            New York       43.00035      -75.49990          126.187551
# 57534        South Dakota       44.50026     -100.25069          118.025768
# 57884       West Virginia       38.50038      -80.50009          112.763106
# 57947       West Virginia       38.50038      -80.50009          107.028784
# 57948       West Virginia       38.50038      -80.50009          106.949708
# 57735            Virginia       37.53820      -77.88833          103.945441
# 57842       West Virginia       39.11288      -79.93341           98.459100
# 57890       West Virginia       39.28353      -80.37988           98.452058
# 56621              Kansas       39.00278      -95.79299           97.415897
# 57152      North Carolina       35.50069      -80.00032           91.339644
# 57711            Virginia       37.54812      -77.44675           86.920933
# 56849            Kentucky       37.78397      -84.61689           86.801847
# 56813            Kentucky       37.91426      -82.75571           86.448398
# 56808            Kentucky       36.97171      -87.16055           78.997241
# 56854           Louisiana       31.61462      -92.37097           77.841825
# 56883       Massachusetts       42.20426      -72.62453           71.251822
# 57676            Virginia       37.54812      -77.44675           66.346284
# 56061            Arkansas       34.96267      -93.75900           63.578665
# 57508        South Dakota       43.80444      -98.50502          288.921034
#
#           Max_Dist_Pair Min_Haversine_Dist       Min_Dist_Pair  \
# 57987  TwoFishes vs Geo        1512.104821    TwoFishes vs Geo
# 56216  TwoFishes vs Geo         419.736210    TwoFishes vs Geo
# 57020  TwoFishes vs Geo         417.020318    TwoFishes vs Geo
# 57147  TwoFishes vs Geo         411.398003    TwoFishes vs Geo
# 57604  TwoFishes vs Geo         368.379699    TwoFishes vs Geo
# 56241  TwoFishes vs Geo         313.096135    TwoFishes vs Geo
# 56776  TwoFishes vs Geo         311.335389    TwoFishes vs Geo
# 57126  TwoFishes vs Geo         275.433971    TwoFishes vs Geo
# 57000  TwoFishes vs Geo         273.038086    TwoFishes vs Geo
# 56743  TwoFishes vs Geo         270.760720    TwoFishes vs Geo
# 57416  TwoFishes vs Geo         257.961721    TwoFishes vs Geo
# 56544  TwoFishes vs Geo         255.672620    TwoFishes vs Geo
# 57278  TwoFishes vs Geo         240.191041    TwoFishes vs Geo
# 57139  TwoFishes vs Geo         214.564886    TwoFishes vs Geo
# 57736  TwoFishes vs Geo         193.211509    TwoFishes vs Geo
# 56749  TwoFishes vs Geo         179.331839    TwoFishes vs Geo
# 57307  TwoFishes vs Geo         178.520355    TwoFishes vs Geo
# 57363  TwoFishes vs Geo         177.844551    TwoFishes vs Geo
# 57940  TwoFishes vs Geo         171.946837    TwoFishes vs Geo
# 56825  TwoFishes vs Geo         158.556276    TwoFishes vs Geo
# 33446  TwoFishes vs Geo         157.431141  TwoFishes vs. Free
# 56667  TwoFishes vs Geo         155.820093    TwoFishes vs Geo
# 56071  TwoFishes vs Geo         153.632587    TwoFishes vs Geo
# 56021  TwoFishes vs Geo         152.269775    TwoFishes vs Geo
# 56443  TwoFishes vs Geo         151.762001    TwoFishes vs Geo
# 56501  TwoFishes vs Geo         149.121839    TwoFishes vs Geo
# 56783  TwoFishes vs Geo         146.610329    TwoFishes vs Geo
# 57538  TwoFishes vs Geo         134.603897    TwoFishes vs Geo
# 56234  TwoFishes vs Geo         133.563495    TwoFishes vs Geo
# 57065  TwoFishes vs Geo         128.354392    TwoFishes vs Geo
# 56805  TwoFishes vs Geo         127.098865    TwoFishes vs Geo
# 57274  TwoFishes vs Geo         126.187551    TwoFishes vs Geo
# 57534  TwoFishes vs Geo         118.025768    TwoFishes vs Geo
# 57884  TwoFishes vs Geo         112.763106    TwoFishes vs Geo
# 57947  TwoFishes vs Geo         107.028784    TwoFishes vs Geo
# 57948  TwoFishes vs Geo         106.949708    TwoFishes vs Geo
# 57735  TwoFishes vs Geo         103.945441    TwoFishes vs Geo
# 57842  TwoFishes vs Geo          98.459100    TwoFishes vs Geo
# 57890  TwoFishes vs Geo          98.452058    TwoFishes vs Geo
# 56621  TwoFishes vs Geo          97.415897    TwoFishes vs Geo
# 57152  TwoFishes vs Geo          91.339644    TwoFishes vs Geo
# 57711  TwoFishes vs Geo          86.920933    TwoFishes vs Geo
# 56849  TwoFishes vs Geo          86.801847    TwoFishes vs Geo
# 56813  TwoFishes vs Geo          86.448398    TwoFishes vs Geo
# 56808  TwoFishes vs Geo          78.997241    TwoFishes vs Geo
# 56854  TwoFishes vs Geo          77.841825    TwoFishes vs Geo
# 56883  TwoFishes vs Geo          71.251822    TwoFishes vs Geo
# 57676  TwoFishes vs Geo          66.346284    TwoFishes vs Geo
# 56061  TwoFishes vs Geo          63.578665    TwoFishes vs Geo
# 57508  TwoFishes vs Non          57.135579         Non vs. Geo
#
#       Primary_Geo_Source  Lat_primary  Lon_primary
# 57987          Twofishes     42.91336    -85.70531
# 56216          Twofishes     38.41463   -120.91355
# 57020          Twofishes     42.79697    -86.12588
# 57147          Twofishes     45.34298   -112.94476
# 57604          Twofishes     31.25044    -99.25061
# 56241          Twofishes     39.00027   -105.50083
# 56776          Twofishes     37.31925    -84.05854
# 57126          Twofishes     33.55151    -89.28729
# 57000          Twofishes     44.25029    -85.50033
# 56743          Twofishes     38.95617    -84.44800
# 57416          Twofishes     35.91934    -97.44332
# 56544          Twofishes     40.00032    -89.25037
# 57278          Twofishes     43.00035    -75.49990
# 57139          Twofishes     33.35151    -90.79843
# 57736          Twofishes     37.20015    -78.60417
# 56749          Twofishes     38.20042    -84.87762
# 57307          Twofishes     43.00035    -75.49990
# 57363          Twofishes     43.00035    -75.49990
# 57940          Twofishes     37.85539    -81.63067
# 56825          Twofishes     36.77397    -83.73297
# 33446          Twofishes     20.75028   -156.50028
# 56667          Twofishes     38.20042    -84.87762
# 56071          Twofishes     33.76039    -91.16122
# 56021          Twofishes     32.75041    -86.75026
# 56443          Twofishes     32.75042    -83.50018
# 56501          Twofishes     42.55165    -92.29796
# 56783          Twofishes     38.20042    -84.87762
# 57538          Twofishes     36.17645    -85.52220
# 56234          Twofishes     38.94277   -103.27911
# 57065          Twofishes     46.37717    -93.74067
# 56805          Twofishes     37.73786    -84.64300
# 57274          Twofishes     43.00035    -75.49990
# 57534          Twofishes     44.50026   -100.25069
# 57884          Twofishes     38.50038    -80.50009
# 57947          Twofishes     38.50038    -80.50009
# 57948          Twofishes     38.50038    -80.50009
# 57735          Twofishes     37.53820    -77.88833
# 57842          Twofishes     39.11288    -79.93341
# 57890          Twofishes     39.28353    -80.37988
# 56621          Twofishes     39.00278    -95.79299
# 57152          Twofishes     35.50069    -80.00032
# 57711          Twofishes     37.54812    -77.44675
# 56849          Twofishes     37.78397    -84.61689
# 56813          Twofishes     37.91426    -82.75571
# 56808          Twofishes     36.97171    -87.16055
# 56854          Twofishes     31.61462    -92.37097
# 56883          Twofishes     42.20426    -72.62453
# 57676          Twofishes     37.54812    -77.44675
# 56061          Twofishes     34.96267    -93.75900
# 57508                Non     45.55964   -101.20322
#
# [50 rows x 27 columns]

# %%
# How close are our distances, and do we have any points with no pairs?
print(len(master_zips_haversine[master_zips_haversine['Min_Haversine_Dist'] > 5]))
print(len(master_zips_haversine[master_zips_haversine['Max_Dist_Pair'] == 'No Pair Found']))
master_zips_haversine[master_zips_haversine['Max_Dist_Pair'] == 'No Pair Found']
# Out:
# 778
# 7
#       Zip_free Zip_geo Zip_non City_free City_geo City_non State_free  \
# 55289    34034   34034     NaN       dpo      apo      NaN         aa
# 55290    34050   34050     NaN       fpo      fpo      NaN         aa
# 55291    96337   96337     NaN       apo      apo      NaN         ap
# 55293    96507   96507     NaN       dpo      fpo      NaN         ap
# 55963    96536   96536     NaN       fpo      fpo      NaN         ap
# 56045      NaN   96644     NaN       NaN      fpo      NaN        NaN
# 56046      NaN   96208     NaN       NaN      apo      NaN        NaN
#
#       State_geo State_non  Lat_free     ...               Primary_State_Full  \
# 55289        aa       NaN       NaN     ...       US Armed Forces (Americas)
# 55290        aa       NaN       NaN     ...       US Armed Forces (Americas)
# 55291        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 55293        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 55963        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 56045        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 56046        ap       NaN       NaN     ...        US Armed Forces (Pacific)
#
#        Lat_TwoFishes  Lon_TwoFishes  Max_Haversine_Dist  Max_Dist_Pair  \
# 55289            NaN            NaN                 NaN  No Pair Found
# 55290            NaN            NaN                 NaN  No Pair Found
# 55291            NaN            NaN                 NaN  No Pair Found
# 55293            NaN            NaN                 NaN  No Pair Found
# 55963            NaN            NaN                 NaN  No Pair Found
# 56045            NaN            NaN                 NaN  No Pair Found
# 56046            NaN            NaN                 NaN  No Pair Found
#
#       Min_Haversine_Dist  Min_Dist_Pair Primary_Geo_Source  Lat_primary  \
# 55289                NaN  No Pair Found          Twofishes          NaN
# 55290                NaN  No Pair Found          Twofishes          NaN
# 55291                NaN  No Pair Found          Twofishes          NaN
# 55293                NaN  No Pair Found          Twofishes          NaN
# 55963                NaN  No Pair Found          Twofishes          NaN
# 56045                NaN  No Pair Found          Twofishes          NaN
# 56046                NaN  No Pair Found          Twofishes          NaN
#
#        Lon_primary
# 55289          NaN
# 55290          NaN
# 55291          NaN
# 55293          NaN
# 55963          NaN
# 56045          NaN
# 56046          NaN
#
# [7 rows x 27 columns]

# %%
# Let's default all apo and fpo to Washington, DC zip code.
def update_apo_fpo(row):
    if row['Min_Dist_Pair'] == 'No Pair Found':
        row['Lat_primary'] = 38.895110
        row['Lon_primary'] = -77.036370
    return row
master_zips_apo = master_zips_haversine.apply(update_apo_fpo, axis=1)
# Out:
#       Zip_free Zip_geo Zip_non City_free City_geo City_non State_free  \
# 55289    34034   34034     NaN       dpo      apo      NaN         aa
# 55290    34050   34050     NaN       fpo      fpo      NaN         aa
# 55291    96337   96337     NaN       apo      apo      NaN         ap
# 55293    96507   96507     NaN       dpo      fpo      NaN         ap
# 55963    96536   96536     NaN       fpo      fpo      NaN         ap
# 56045      NaN   96644     NaN       NaN      fpo      NaN        NaN
# 56046      NaN   96208     NaN       NaN      apo      NaN        NaN
#
#       State_geo State_non  Lat_free     ...               Primary_State_Full  \
# 55289        aa       NaN       NaN     ...       US Armed Forces (Americas)
# 55290        aa       NaN       NaN     ...       US Armed Forces (Americas)
# 55291        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 55293        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 55963        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 56045        ap       NaN       NaN     ...        US Armed Forces (Pacific)
# 56046        ap       NaN       NaN     ...        US Armed Forces (Pacific)
#
#        Lat_TwoFishes  Lon_TwoFishes  Max_Haversine_Dist  Max_Dist_Pair  \
# 55289            NaN            NaN                 NaN  No Pair Found
# 55290            NaN            NaN                 NaN  No Pair Found
# 55291            NaN            NaN                 NaN  No Pair Found
# 55293            NaN            NaN                 NaN  No Pair Found
# 55963            NaN            NaN                 NaN  No Pair Found
# 56045            NaN            NaN                 NaN  No Pair Found
# 56046            NaN            NaN                 NaN  No Pair Found
#
#       Min_Haversine_Dist  Min_Dist_Pair Primary_Geo_Source  Lat_primary  \
# 55289                NaN  No Pair Found          Twofishes     38.89511
# 55290                NaN  No Pair Found          Twofishes     38.89511
# 55291                NaN  No Pair Found          Twofishes     38.89511
# 55293                NaN  No Pair Found          Twofishes     38.89511
# 55963                NaN  No Pair Found          Twofishes     38.89511
# 56045                NaN  No Pair Found          Twofishes     38.89511
# 56046                NaN  No Pair Found          Twofishes     38.89511
#
#        Lon_primary
# 55289    -77.03637
# 55290    -77.03637
# 55291    -77.03637
# 55293    -77.03637
# 55963    -77.03637
# 56045    -77.03637
# 56046    -77.03637
#
# [7 rows x 27 columns]

# %%
final_cols = master_zips_apo[['Zip_geo', 'Primary_City', 'Primary_State',
                              'Lat_primary', 'Lon_primary']]
len(final_cols)
# Out:
# 57989

# %%
renamed_final = final_cols.rename(columns={'Zip_geo': 'Zipcode',
                                           'Primary_City': 'City',
                                           'Primary_State': 'State',
                                           'Lat_primary': 'Latitude',
                                           'Lon_primary': 'Longitude'})

# %%
# Version with unique cities, and version with unique zips
distinct_cities = renamed_final.drop_duplicates('City')
distinct_zips = renamed_final.drop_duplicates('Zipcode')

# %%
distinct_zips.head(50)
# Out:
#    Zipcode                City State   Latitude  Longitude
# 0    07675            westwood    nj  40.991210 -74.032640
# 4    07677      woodcliff lake    nj  41.023430 -74.066530
# 7    07885             wharton    nj  40.913298 -74.582460
# 8    07981            whippany    nj  40.824540 -74.417100
# 9    07999            whippany    nj  40.867331 -74.578269
# 10   08888          whitehouse    nj  40.618440 -74.744330
# 11   08889  whitehouse station    nj  40.615380 -74.770440
# 13   07095          woodbridge    nj  40.557600 -74.284590
# 14   07481             wyckoff    nj  40.998583 -74.167100
# 15   10451               bronx    ny  40.819729 -73.922300
# 16   10452               bronx    ny  40.838745 -73.922340
# 17   10453               bronx    ny  40.853017 -73.912140
# 18   10454               bronx    ny  40.805968 -73.916280
# 19   10455               bronx    ny  40.815559 -73.907710
# 20   10456               bronx    ny  40.829676 -73.908560
# 21   10457               bronx    ny  40.846745 -73.898610
# 22   10458               bronx    ny  40.864166 -73.888810
# 23   10459               bronx    ny  40.825432 -73.893270
# 24   10460               bronx    ny  40.840950 -73.880360
# 25   10461               bronx    ny  40.842917 -73.838190
# 26   10462               bronx    ny  40.842173 -73.858620
# 27   10463               bronx    ny  40.881086 -73.907490
# 28   10464               bronx    ny  40.857017 -73.789030
# 29   10465               bronx    ny  40.825727 -73.817520
# 30   10466               bronx    ny  40.890950 -73.847020
# 31   10467               bronx    ny  40.872265 -73.869370
# 32   10468               bronx    ny  40.867107 -73.899160
# 33   10469               bronx    ny  40.868643 -73.847350
# 34   10470               bronx    ny  40.900629 -73.860720
# 35   10471               bronx    ny  40.900819 -73.903470
# 36   10472               bronx    ny  40.830409 -73.868450
# 37   10473               bronx    ny  40.818514 -73.858930
# 38   10474               bronx    ny  40.813210 -73.887550
# 39   10475               bronx    ny  40.878522 -73.825410
# 40   10499               bronx    ny  40.851549 -73.840908
# 41   10001            new york    ny  40.750742 -73.996530
# 42   10002            new york    ny  40.717040 -73.987000
# 44   10003            new york    ny  40.732509 -73.989350
# 45   10004            new york    ny  40.699226 -74.041180
# 47   10005            new york    ny  40.706019 -74.008580
# 49   10006            new york    ny  40.707904 -74.013420
# 51   10007            new york    ny  40.714754 -74.007210
# 52   10008            new york    ny  40.780751 -73.977182
# 53   10009            new york    ny  40.727093 -73.978640
# 54   10010            new york    ny  40.742185 -73.992602
# 55   10011            new york    ny  40.742185 -73.992602
# 56   10012            new york    ny  40.725960 -73.998340
# 58   10013            new york    ny  40.720666 -74.005260
# 61   10014            new york    ny  40.734718 -74.005320
# 62   10016            new york    ny  40.746180 -73.977590

# %%
distinct_zips.to_csv("distinct_zips.csv")
distinct_cities.to_csv("distinct_cities.csv")

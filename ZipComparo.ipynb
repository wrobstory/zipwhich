# %%
from math import radians, cos, sin, asin, sqrt
import pandas as pd
import numpy as np
import requests

# Import, lowercase city/state name to attempt join later

# Geonames is ~1:1 City/Place names to Zip Codes
# Schema: http://download.geonames.org/export/zip/readme.txt
col_names = ['country_code',
             'postal_code',
             'place_name',
             'admin_name1',
             'admin_code1',
             'admin_name2',
             'admin_code2',
             'admin_name3',
             'admin_code3',
             'latitude',
             'longitude',
             'accuracy']
geonames = pd.read_table('GeoNamesZip.txt', header=None, names=col_names, dtype={'postal_code': str})
geonames['place_name'] = geonames['place_name'].str.lower()
geonames['admin_code1'] = geonames['admin_code1'].str.lower()
geonames_set = set(geonames['postal_code'])

# Free-zip 1 is 1:1 City to Zip Code
free_zip_db = pd.read_csv('free-zipcode-database-Primary.csv', dtype={'Zipcode': str})
free_zip_db['City'] = free_zip_db['City'].str.lower()
free_zip_db['State'] = free_zip_db['State'].str.lower()
freezip_set = set(free_zip_db['Zipcode'])

# Free-zip all is Many:1 City to Zip Code
free_zip_all = pd.read_csv('free-zipcode-database-all-places.csv', dtype={'Zipcode': str})
# We only want Primary/Acceptable locs. There is some junk here.
free_zip_all = free_zip_all[free_zip_all['LocationType'].isin(['ACCEPTABLE', 'PRIMARY'])]
free_zip_all['City'] = free_zip_all['City'].str.lower()
free_zip_all['State'] = free_zip_all['State'].str.lower()
freezip_all_set = set(free_zip_all['Zipcode'])

# Noncensus is ~1:1 City to Zip Code
noncensus = pd.read_csv('noncensus_zip.csv', dtype={'zip': str})
noncensus['city'] = noncensus['city'].str.lower()
noncensus['state'] = noncensus['state'].str.lower()
noncensus_set = set(noncensus['zip'])

# How many unique zip codes do we have in each dataset?
set_lengths = {
    'noncensus_set': len(noncensus_set),
    'free_zip_set': len(freezip_set),
    'free_zip_all_set': len(freezip_all_set),
    'geonames_set': len(geonames_set)
    }
set_lengths
# Out:
# {'free_zip_all_set': 42522,
#  'free_zip_set': 42522,
#  'geonames_set': 43586,
#  'noncensus_set': 43524}

# %%
# How many total rows do we have (including duplicate zips)
len(geonames), len(free_zip_db), len(free_zip_all), len(noncensus)
# Out:
# (43629, 42522, 56725, 43524)

# %%
# Just use columns of interest, rename for specificity
geo_zip_place_loc = geonames[['postal_code', 'place_name', 'admin_code1',
                              'latitude', 'longitude']]
geo_zip_place_loc = geo_zip_place_loc.rename(columns={'postal_code': 'Zip_geo',
                                                      'latitude': 'Lat_geo', 
                                                      'longitude': 'Lon_geo',
                                                      'place_name': 'City_geo',
                                                      'admin_code1': 'State_geo'})

free_zip_all_place_loc = free_zip_all[['Zipcode', 'City', 'State', 'Lat', 'Long']]
free_zip_all_place_loc = free_zip_all_place_loc.rename(columns={'Zipcode': 'Zip_free',
                                                                'Lat': 'Lat_free',
                                                                'Long': 'Lon_free',
                                                                'City': 'City_free',
                                                                'State': 'State_free'})
noncensus_place_loc = noncensus[['zip', 'city', 'state', 'latitude', 'longitude']]
noncensus_place_loc = noncensus_place_loc.rename(columns={'zip': 'Zip_non',
                                                          'latitude': 'Lat_non', 
                                                          'longitude': 'Lon_non',
                                                          'city': 'City_non',
                                                          'state': 'State_non'})

# %% [markdown]
# Given that geonames contains the most unique zip codes, we're going to use it as the common join table between the other two.

# %%
# Join free-zip and geonames, right outer because we trust geonames a bit more
merged_free_geo_zip = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                               left_on='Zip_free', right_on='Zip_geo',
                               how='right')
merged_free_geo_zip_city = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                    left_on=['Zip_free', 'City_free'], 
                                    right_on=['Zip_geo', 'City_geo'],
                                    how='right')
merged_free_geo_zip_state = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                     left_on=['Zip_free', 'State_free'], 
                                     right_on=['Zip_geo', 'State_geo'],
                                     how='right')
merged_free_geo_zip_city_state = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                          left_on=['Zip_free', 'City_free', 'State_free'], 
                                          right_on=['Zip_geo', 'City_geo', 'State_geo'],
                                          how='right')
# Based on the join keys, how many resulting rows do we have? 
lengths_free_geo = {
    'merged_zip': len(merged_free_geo_zip),
    'merged_zip_city': len(merged_free_geo_zip_city),
    'merged_zip_state': len(merged_free_geo_zip_state),
    'merged_zip_city_state': len(merged_free_geo_zip_city_state)
}
lengths_free_geo
# Out:
# {'merged_zip': 57755,
#  'merged_zip_city': 43629,
#  'merged_zip_city_state': 43629,
#  'merged_zip_state': 57755}

# %%
merged_free_geo_zip.head()
# Out:
#   Zip_free       City_free State_free  Lat_free  Lon_free Zip_geo  \
# 0    07675        westwood         nj     40.98    -74.03   07675
# 1    07675      old tappan         nj     40.98    -74.03   07675
# 2    07675      river vale         nj     40.98    -74.03   07675
# 3    07675       rivervale         nj     40.98    -74.03   07675
# 4    07677  woodcliff lake         nj     41.02    -74.05   07677
#
#          City_geo State_geo  Lat_geo  Lon_geo
# 0        westwood        nj  41.0092 -74.0041
# 1        westwood        nj  41.0092 -74.0041
# 2        westwood        nj  41.0092 -74.0041
# 3        westwood        nj  41.0092 -74.0041
# 4  woodcliff lake        nj  41.0234 -74.0603

# %%
# Join geonames and noncensus, right outer on noncensus because we trust it more
merged_non_geo_zip = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                              left_on=['Zip_geo'], right_on=['Zip_non'],
                              how='left')
merged_non_geo_zip_city = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                                   left_on=['Zip_geo', 'City_geo'], 
                                   right_on=['Zip_non', 'City_non'],
                                   how='left')
merged_non_geo_zip_state = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                                    left_on=['Zip_geo', 'State_geo'], 
                                    right_on=['Zip_non', 'State_non'],
                                    how='left')
merged_non_geo_zip_city_state = pd.merge(geo_zip_place_loc, noncensus_place_loc,
                                         left_on=['Zip_geo', 'City_geo', 'State_geo'], 
                                         right_on=['Zip_non', 'City_non', 'State_non'],
                                         how='left')
lengths_non_geo = {
    'merged_zip': len(merged_non_geo_zip),
    'merged_zip_city': len(merged_non_geo_zip_city),
    'merged_zip_state': len(merged_non_geo_zip_state),
    'merged_zip_city_state': len(merged_non_geo_zip_city_state)
}
lengths_non_geo
# Out:
# {'merged_zip': 43629,
#  'merged_zip_city': 43629,
#  'merged_zip_city_state': 43629,
#  'merged_zip_state': 43629}

# %%
merged_non_free_zip.head()
# Out:
#   Zip_geo    City_geo State_geo  Lat_geo   Lon_geo Zip_non    City_non  \
# 0   34050         fpo        aa  41.0375 -111.6789     NaN         NaN
# 1   34034         apo        aa  33.0364  -82.2493     NaN         NaN
# 2   99553      akutan        ak  54.1430 -165.7854   99553      akutan
# 3   99571    cold bay        ak  55.3976 -162.4206   99571    cold bay
# 4   99583  false pass        ak  54.8410 -163.4368   99583  false pass
#
#   State_non    Lat_non    Lon_non
# 0       NaN        NaN        NaN
# 1       NaN        NaN        NaN
# 2        ak  54.098693 -165.88176
# 3        ak  55.315003 -162.63400
# 4        ak  54.849999 -163.42011

# %%
# Join the previous two joins into one another
merged_all = pd.merge(merged_free_geo_zip, merged_non_geo_zip,
                      how='inner',
                      left_on=['Zip_geo','State_geo'], 
                      right_on=['Zip_geo', 'State_geo'])
merged_all
# Out:
#       Zip_free           City_free State_free  Lat_free  Lon_free Zip_geo  \
# 0        07675            westwood         nj     40.98    -74.03   07675
# 1        07675          old tappan         nj     40.98    -74.03   07675
# 2        07675          river vale         nj     40.98    -74.03   07675
# 3        07675           rivervale         nj     40.98    -74.03   07675
# 4        07677      woodcliff lake         nj     41.02    -74.05   07677
# 5        07677            westwood         nj     41.02    -74.05   07677
# 6        07677        woodcliff lk         nj     41.02    -74.05   07677
# 7        07885             wharton         nj     40.89    -74.58   07885
# 8        07981            whippany         nj     40.82    -74.41   07981
# 9        07999            whippany         nj     40.82    -74.41   07999
# 10       08888          whitehouse         nj     40.62    -74.76   08888
# 11       08889  whitehouse station         nj     40.60    -74.76   08889
# 12       08889       white hse sta         nj     40.60    -74.76   08889
# 13       07095          woodbridge         nj     40.55    -74.28   07095
# 14       07481             wyckoff         nj     40.99    -74.16   07481
# 15       10451               bronx         ny     40.84    -73.87   10451
# 16       10452               bronx         ny     40.84    -73.87   10452
# 17       10453               bronx         ny     40.84    -73.87   10453
# 18       10454               bronx         ny     40.84    -73.87   10454
# 19       10455               bronx         ny     40.84    -73.87   10455
# 20       10456               bronx         ny     40.84    -73.87   10456
# 21       10457               bronx         ny     40.84    -73.87   10457
# 22       10458               bronx         ny     40.84    -73.87   10458
# 23       10459               bronx         ny     40.84    -73.87   10459
# 24       10460               bronx         ny     40.84    -73.87   10460
# 25       10461               bronx         ny     40.84    -73.87   10461
# 26       10462               bronx         ny     40.84    -73.87   10462
# 27       10463               bronx         ny     40.84    -73.87   10463
# 28       10464               bronx         ny     40.84    -73.87   10464
# 29       10465               bronx         ny     40.84    -73.87   10465
# ...        ...                 ...        ...       ...       ...     ...
# 57959      NaN                 NaN        NaN       NaN       NaN   25847
# 57960      NaN                 NaN        NaN       NaN       NaN   25856
# 57961      NaN                 NaN        NaN       NaN       NaN   25934
# 57962      NaN                 NaN        NaN       NaN       NaN   26145
# 57963      NaN                 NaN        NaN       NaN       NaN   26367
# 57964      NaN                 NaN        NaN       NaN       NaN   26407
# 57965      NaN                 NaN        NaN       NaN       NaN   25046
# 57966      NaN                 NaN        NaN       NaN       NaN   25246
# 57967      NaN                 NaN        NaN       NaN       NaN   25256
# 57968      NaN                 NaN        NaN       NaN       NaN   25281
# 57969      NaN                 NaN        NaN       NaN       NaN   24919
# 57970      NaN                 NaN        NaN       NaN       NaN   25973
# 57971      NaN                 NaN        NaN       NaN       NaN   25988
# 57972      NaN                 NaN        NaN       NaN       NaN   26290
# 57973      NaN                 NaN        NaN       NaN       NaN   26135
# 57974      NaN                 NaN        NaN       NaN       NaN   25519
# 57975      NaN                 NaN        NaN       NaN       NaN   26299
# 57976      NaN                 NaN        NaN       NaN       NaN   26186
# 57977      NaN                 NaN        NaN       NaN       NaN   25255
# 57978      NaN                 NaN        NaN       NaN       NaN   26185
# 57979      NaN                 NaN        NaN       NaN       NaN   24896
# 57980      NaN                 NaN        NaN       NaN       NaN   82057
# 57981      NaN                 NaN        NaN       NaN       NaN   82080
# 57982      NaN                 NaN        NaN       NaN       NaN   82631
# 57983      NaN                 NaN        NaN       NaN       NaN   82713
# 57984      NaN                 NaN        NaN       NaN       NaN   82724
# 57985      NaN                 NaN        NaN       NaN       NaN   82427
# 57986      NaN                 NaN        NaN       NaN       NaN   82220
# 57987      NaN                 NaN        NaN       NaN       NaN   82228
# 57988      NaN                 NaN        NaN       NaN       NaN   82926
#
#                City_geo_x State_geo  Lat_geo_x  Lon_geo_x          City_geo_y  \
# 0                westwood        nj    41.0092   -74.0041            westwood
# 1                westwood        nj    41.0092   -74.0041            westwood
# 2                westwood        nj    41.0092   -74.0041            westwood
# 3                westwood        nj    41.0092   -74.0041            westwood
# 4          woodcliff lake        nj    41.0234   -74.0603      woodcliff lake
# 5          woodcliff lake        nj    41.0234   -74.0603      woodcliff lake
# 6          woodcliff lake        nj    41.0234   -74.0603      woodcliff lake
# 7                 wharton        nj    40.9139   -74.5863             wharton
# 8                whippany        nj    40.8219   -74.4200            whippany
# 9                whippany        nj    40.8673   -74.5783            whippany
# 10             whitehouse        nj    40.6194   -74.7406          whitehouse
# 11     whitehouse station        nj    40.6156   -74.7724  whitehouse station
# 12     whitehouse station        nj    40.6156   -74.7724  whitehouse station
# 13             woodbridge        nj    40.5560   -74.2845          woodbridge
# 14                wyckoff        nj    40.9978   -74.1660             wyckoff
# 15                  bronx        ny    40.8222   -73.9217               bronx
# 16                  bronx        ny    40.8376   -73.9216               bronx
# 17                  bronx        ny    40.8520   -73.9129               bronx
# 18                  bronx        ny    40.8085   -73.9198               bronx
# 19                  bronx        ny    40.8153   -73.9072               bronx
# 20                  bronx        ny    40.8316   -73.9099               bronx
# 21                  bronx        ny    40.8486   -73.8999               bronx
# 22                  bronx        ny    40.8633   -73.8895               bronx
# 23                  bronx        ny    40.8247   -73.8940               bronx
# 24                  bronx        ny    40.8409   -73.8794               bronx
# 25                  bronx        ny    40.8465   -73.8410               bronx
# 26                  bronx        ny    40.8434   -73.8602               bronx
# 27                  bronx        ny    40.8798   -73.9067               bronx
# 28                  bronx        ny    40.8469   -73.7874               bronx
# 29                  bronx        ny    40.8261   -73.8196               bronx
# ...                   ...       ...        ...        ...                 ...
# 57959         glen morgan        wv    37.7134   -81.1788         glen morgan
# 57960              jonben        wv    37.6479   -81.1906              jonben
# 57961               terry        wv    37.8490   -81.0937               terry
# 57962          five forks        wv    38.9751   -81.0847          five forks
# 57963          hazelgreen        wv    39.0631   -80.9806          hazelgreen
# 57964            mountain        wv    39.1985   -81.0689            mountain
# 57965                clio        wv    38.7317   -81.3146                clio
# 57966             harmony        wv    38.6921   -81.5076             harmony
# 57967              linden        wv    38.7317   -81.3146              linden
# 57968              tariff        wv    38.7317   -81.3146              tariff
# 57969           ballengee        wv    37.6748   -80.8900           ballengee
# 57970          lockbridge        wv    37.8274   -80.8451          lockbridge
# 57971                true        wv    37.6485   -80.8774                true
# 57972        saint george        wv    39.1666   -79.7024        saint george
# 57973            bens run        wv    39.4506   -80.8701            bens run
# 57974           glenhayes        wv    38.1321   -82.4183           glenhayes
# 57975               boggs        wv    38.4821   -80.6074               boggs
# 57976          wileyville        wv    39.5755   -80.6667          wileyville
# 57977          letter gap        wv    38.9079   -80.9027          letter gap
# 57978                wick        wv    39.4217   -80.9680                wick
# 57979            wolf pen        wv    37.6033   -81.5400            wolf pen
# 57980             laramie        wy    41.1095  -106.2190             laramie
# 57981            mcfadden        wy    41.6327  -106.1379            mcfadden
# 57982                bill        wy    42.8942  -105.4852                bill
# 57983             carlile        wy    44.5259  -104.7678             carlile
# 57984              oshoto        wy    44.5887  -104.9832              oshoto
# 57985       hamilton dome        wy    43.7698  -108.4541       hamilton dome
# 57986             keeline        wy    42.8391  -104.7203             keeline
# 57987                node        wy    42.7478  -104.2963                node
# 57988        rock springs        wy    42.0508  -109.4363        rock springs
#
#        Lat_geo_y  Lon_geo_y Zip_non            City_non State_non    Lat_non  \
# 0        41.0092   -74.0041   07675            westwood        nj  40.999040
# 1        41.0092   -74.0041   07675            westwood        nj  40.999040
# 2        41.0092   -74.0041   07675            westwood        nj  40.999040
# 3        41.0092   -74.0041   07675            westwood        nj  40.999040
# 4        41.0234   -74.0603   07677      woodcliff lake        nj  41.025101
# 5        41.0234   -74.0603   07677      woodcliff lake        nj  41.025101
# 6        41.0234   -74.0603   07677      woodcliff lake        nj  41.025101
# 7        40.9139   -74.5863   07885             wharton        nj  40.913298
# 8        40.8219   -74.4200   07981            whippany        nj  40.821482
# 9        40.8673   -74.5783   07999            whippany        nj  40.867331
# 10       40.6194   -74.7406   08888          whitehouse        nj  40.619412
# 11       40.6156   -74.7724   08889  whitehouse station        nj  40.612851
# 12       40.6156   -74.7724   08889  whitehouse station        nj  40.612851
# 13       40.5560   -74.2845   07095          woodbridge        nj  40.557104
# 14       40.9978   -74.1660   07481             wyckoff        nj  40.998583
# 15       40.8222   -73.9217   10451               bronx        ny  40.819729
# 16       40.8376   -73.9216   10452               bronx        ny  40.838745
# 17       40.8520   -73.9129   10453               bronx        ny  40.853017
# 18       40.8085   -73.9198   10454               bronx        ny  40.805968
# 19       40.8153   -73.9072   10455               bronx        ny  40.815559
# 20       40.8316   -73.9099   10456               bronx        ny  40.829676
# 21       40.8486   -73.8999   10457               bronx        ny  40.846745
# 22       40.8633   -73.8895   10458               bronx        ny  40.864166
# 23       40.8247   -73.8940   10459               bronx        ny  40.825432
# 24       40.8409   -73.8794   10460               bronx        ny  40.840950
# 25       40.8465   -73.8410   10461               bronx        ny  40.842917
# 26       40.8434   -73.8602   10462               bronx        ny  40.842173
# 27       40.8798   -73.9067   10463               bronx        ny  40.881086
# 28       40.8469   -73.7874   10464               bronx        ny  40.857017
# 29       40.8261   -73.8196   10465               bronx        ny  40.825727
# ...          ...        ...     ...                 ...       ...        ...
# 57959    37.7134   -81.1788   25847         glen morgan        wv  37.723290
# 57960    37.6479   -81.1906   25856              jonben        wv  37.653792
# 57961    37.8490   -81.0937   25934               terry        wv  37.848955
# 57962    38.9751   -81.0847   26145           pennsboro        wv  39.288336
# 57963    39.0631   -80.9806     NaN                 NaN       NaN        NaN
# 57964    39.1985   -81.0689   26407            mountain        wv  39.198501
# 57965    38.7317   -81.3146   25046                clio        wv  38.731737
# 57966    38.6921   -81.5076     NaN                 NaN       NaN        NaN
# 57967    38.7317   -81.3146   25256              linden        wv  38.731737
# 57968    38.7317   -81.3146   25281              tariff        wv  38.682668
# 57969    37.6748   -80.8900   24919           ballengee        wv  37.620418
# 57970    37.8274   -80.8451     NaN                 NaN       NaN        NaN
# 57971    37.6485   -80.8774   25988                true        wv  37.648541
# 57972    39.1666   -79.7024     NaN                 NaN       NaN        NaN
# 57973    39.4506   -80.8701   26135            bens run        wv  39.450612
# 57974    38.1321   -82.4183   25519           glenhayes        wv  38.132114
# 57975    38.4821   -80.6074     NaN                 NaN       NaN        NaN
# 57976    39.5755   -80.6667   26186          wileyville        wv  39.619007
# 57977    38.9079   -80.9027     NaN                 NaN       NaN        NaN
# 57978    39.4217   -80.9680     NaN                 NaN       NaN        NaN
# 57979    37.6033   -81.5400   24896            wolf pen        wv  37.603344
# 57980    41.1095  -106.2190     NaN                 NaN       NaN        NaN
# 57981    41.6327  -106.1379     NaN                 NaN       NaN        NaN
# 57982    42.8942  -105.4852   82631                bill        wy  42.894249
# 57983    44.5259  -104.7678   82713             carlile        wy  44.525891
# 57984    44.5887  -104.9832     NaN                 NaN       NaN        NaN
# 57985    43.7698  -108.4541   82427       hamilton dome        wy  43.769760
# 57986    42.8391  -104.7203     NaN                 NaN       NaN        NaN
# 57987    42.7478  -104.2963     NaN                 NaN       NaN        NaN
# 57988    42.0508  -109.4363     NaN                 NaN       NaN        NaN
#
#           Lon_non
# 0      -74.032910
# 1      -74.032910
# 2      -74.032910
# 3      -74.032910
# 4      -74.059762
# 5      -74.059762
# 6      -74.059762
# 7      -74.582460
# 8      -74.426480
# 9      -74.578269
# 10     -74.740597
# 11     -74.766820
# 12     -74.766820
# 13     -74.283160
# 14     -74.167100
# 15     -73.922300
# 16     -73.922340
# 17     -73.912140
# 18     -73.916280
# 19     -73.907710
# 20     -73.908560
# 21     -73.898610
# 22     -73.888810
# 23     -73.893270
# 24     -73.880360
# 25     -73.838190
# 26     -73.858620
# 27     -73.907490
# 28     -73.789030
# 29     -73.817520
# ...           ...
# 57959  -81.174440
# 57960  -81.188330
# 57961  -81.093678
# 57962  -80.968967
# 57963         NaN
# 57964  -81.068913
# 57965  -81.314633
# 57966         NaN
# 57967  -81.314633
# 57968  -81.188460
# 57969  -80.716360
# 57970         NaN
# 57971  -80.877395
# 57972         NaN
# 57973  -80.870081
# 57974  -82.418277
# 57975         NaN
# 57976  -80.612250
# 57977         NaN
# 57978         NaN
# 57979  -81.539980
# 57980         NaN
# 57981         NaN
# 57982 -105.485243
# 57983 -104.767846
# 57984         NaN
# 57985 -108.454106
# 57986         NaN
# 57987         NaN
# 57988         NaN
#
# [57989 rows x 18 columns]

# %%
# Reorder, and we only want to keep one of the Geo join key columns
master_zips = merged_all[['Zip_free', 'Zip_geo', 'Zip_non',
                          'City_free', 'City_geo_x', 'City_non',
                          'State_free', 'State_geo', 'State_non',
                          'Lat_free', 'Lat_geo_x', 'Lat_non',
                          'Lon_free', 'Lon_geo_x', 'Lon_non']]
master_zips = master_zips.rename(columns={'City_geo_x': 'City_geo',
                                          'Lon_geo_x': 'Lon_geo', 
                                          'Lat_geo_x': 'Lat_geo'})
master_zips
# Out:
#       Zip_free Zip_geo Zip_non           City_free            City_geo  \
# 0        07675   07675   07675            westwood            westwood
# 1        07675   07675   07675          old tappan            westwood
# 2        07675   07675   07675          river vale            westwood
# 3        07675   07675   07675           rivervale            westwood
# 4        07677   07677   07677      woodcliff lake      woodcliff lake
# 5        07677   07677   07677            westwood      woodcliff lake
# 6        07677   07677   07677        woodcliff lk      woodcliff lake
# 7        07885   07885   07885             wharton             wharton
# 8        07981   07981   07981            whippany            whippany
# 9        07999   07999   07999            whippany            whippany
# 10       08888   08888   08888          whitehouse          whitehouse
# 11       08889   08889   08889  whitehouse station  whitehouse station
# 12       08889   08889   08889       white hse sta  whitehouse station
# 13       07095   07095   07095          woodbridge          woodbridge
# 14       07481   07481   07481             wyckoff             wyckoff
# 15       10451   10451   10451               bronx               bronx
# 16       10452   10452   10452               bronx               bronx
# 17       10453   10453   10453               bronx               bronx
# 18       10454   10454   10454               bronx               bronx
# 19       10455   10455   10455               bronx               bronx
# 20       10456   10456   10456               bronx               bronx
# 21       10457   10457   10457               bronx               bronx
# 22       10458   10458   10458               bronx               bronx
# 23       10459   10459   10459               bronx               bronx
# 24       10460   10460   10460               bronx               bronx
# 25       10461   10461   10461               bronx               bronx
# 26       10462   10462   10462               bronx               bronx
# 27       10463   10463   10463               bronx               bronx
# 28       10464   10464   10464               bronx               bronx
# 29       10465   10465   10465               bronx               bronx
# ...        ...     ...     ...                 ...                 ...
# 57959      NaN   25847   25847                 NaN         glen morgan
# 57960      NaN   25856   25856                 NaN              jonben
# 57961      NaN   25934   25934                 NaN               terry
# 57962      NaN   26145   26145                 NaN          five forks
# 57963      NaN   26367     NaN                 NaN          hazelgreen
# 57964      NaN   26407   26407                 NaN            mountain
# 57965      NaN   25046   25046                 NaN                clio
# 57966      NaN   25246     NaN                 NaN             harmony
# 57967      NaN   25256   25256                 NaN              linden
# 57968      NaN   25281   25281                 NaN              tariff
# 57969      NaN   24919   24919                 NaN           ballengee
# 57970      NaN   25973     NaN                 NaN          lockbridge
# 57971      NaN   25988   25988                 NaN                true
# 57972      NaN   26290     NaN                 NaN        saint george
# 57973      NaN   26135   26135                 NaN            bens run
# 57974      NaN   25519   25519                 NaN           glenhayes
# 57975      NaN   26299     NaN                 NaN               boggs
# 57976      NaN   26186   26186                 NaN          wileyville
# 57977      NaN   25255     NaN                 NaN          letter gap
# 57978      NaN   26185     NaN                 NaN                wick
# 57979      NaN   24896   24896                 NaN            wolf pen
# 57980      NaN   82057     NaN                 NaN             laramie
# 57981      NaN   82080     NaN                 NaN            mcfadden
# 57982      NaN   82631   82631                 NaN                bill
# 57983      NaN   82713   82713                 NaN             carlile
# 57984      NaN   82724     NaN                 NaN              oshoto
# 57985      NaN   82427   82427                 NaN       hamilton dome
# 57986      NaN   82220     NaN                 NaN             keeline
# 57987      NaN   82228     NaN                 NaN                node
# 57988      NaN   82926     NaN                 NaN        rock springs
#
#                  City_non State_free State_geo State_non  Lat_free  Lat_geo  \
# 0                westwood         nj        nj        nj     40.98  41.0092
# 1                westwood         nj        nj        nj     40.98  41.0092
# 2                westwood         nj        nj        nj     40.98  41.0092
# 3                westwood         nj        nj        nj     40.98  41.0092
# 4          woodcliff lake         nj        nj        nj     41.02  41.0234
# 5          woodcliff lake         nj        nj        nj     41.02  41.0234
# 6          woodcliff lake         nj        nj        nj     41.02  41.0234
# 7                 wharton         nj        nj        nj     40.89  40.9139
# 8                whippany         nj        nj        nj     40.82  40.8219
# 9                whippany         nj        nj        nj     40.82  40.8673
# 10             whitehouse         nj        nj        nj     40.62  40.6194
# 11     whitehouse station         nj        nj        nj     40.60  40.6156
# 12     whitehouse station         nj        nj        nj     40.60  40.6156
# 13             woodbridge         nj        nj        nj     40.55  40.5560
# 14                wyckoff         nj        nj        nj     40.99  40.9978
# 15                  bronx         ny        ny        ny     40.84  40.8222
# 16                  bronx         ny        ny        ny     40.84  40.8376
# 17                  bronx         ny        ny        ny     40.84  40.8520
# 18                  bronx         ny        ny        ny     40.84  40.8085
# 19                  bronx         ny        ny        ny     40.84  40.8153
# 20                  bronx         ny        ny        ny     40.84  40.8316
# 21                  bronx         ny        ny        ny     40.84  40.8486
# 22                  bronx         ny        ny        ny     40.84  40.8633
# 23                  bronx         ny        ny        ny     40.84  40.8247
# 24                  bronx         ny        ny        ny     40.84  40.8409
# 25                  bronx         ny        ny        ny     40.84  40.8465
# 26                  bronx         ny        ny        ny     40.84  40.8434
# 27                  bronx         ny        ny        ny     40.84  40.8798
# 28                  bronx         ny        ny        ny     40.84  40.8469
# 29                  bronx         ny        ny        ny     40.84  40.8261
# ...                   ...        ...       ...       ...       ...      ...
# 57959         glen morgan        NaN        wv        wv       NaN  37.7134
# 57960              jonben        NaN        wv        wv       NaN  37.6479
# 57961               terry        NaN        wv        wv       NaN  37.8490
# 57962           pennsboro        NaN        wv        wv       NaN  38.9751
# 57963                 NaN        NaN        wv       NaN       NaN  39.0631
# 57964            mountain        NaN        wv        wv       NaN  39.1985
# 57965                clio        NaN        wv        wv       NaN  38.7317
# 57966                 NaN        NaN        wv       NaN       NaN  38.6921
# 57967              linden        NaN        wv        wv       NaN  38.7317
# 57968              tariff        NaN        wv        wv       NaN  38.7317
# 57969           ballengee        NaN        wv        wv       NaN  37.6748
# 57970                 NaN        NaN        wv       NaN       NaN  37.8274
# 57971                true        NaN        wv        wv       NaN  37.6485
# 57972                 NaN        NaN        wv       NaN       NaN  39.1666
# 57973            bens run        NaN        wv        wv       NaN  39.4506
# 57974           glenhayes        NaN        wv        wv       NaN  38.1321
# 57975                 NaN        NaN        wv       NaN       NaN  38.4821
# 57976          wileyville        NaN        wv        wv       NaN  39.5755
# 57977                 NaN        NaN        wv       NaN       NaN  38.9079
# 57978                 NaN        NaN        wv       NaN       NaN  39.4217
# 57979            wolf pen        NaN        wv        wv       NaN  37.6033
# 57980                 NaN        NaN        wy       NaN       NaN  41.1095
# 57981                 NaN        NaN        wy       NaN       NaN  41.6327
# 57982                bill        NaN        wy        wy       NaN  42.8942
# 57983             carlile        NaN        wy        wy       NaN  44.5259
# 57984                 NaN        NaN        wy       NaN       NaN  44.5887
# 57985       hamilton dome        NaN        wy        wy       NaN  43.7698
# 57986                 NaN        NaN        wy       NaN       NaN  42.8391
# 57987                 NaN        NaN        wy       NaN       NaN  42.7478
# 57988                 NaN        NaN        wy       NaN       NaN  42.0508
#
#          Lat_non  Lon_free   Lon_geo     Lon_non
# 0      40.999040    -74.03  -74.0041  -74.032910
# 1      40.999040    -74.03  -74.0041  -74.032910
# 2      40.999040    -74.03  -74.0041  -74.032910
# 3      40.999040    -74.03  -74.0041  -74.032910
# 4      41.025101    -74.05  -74.0603  -74.059762
# 5      41.025101    -74.05  -74.0603  -74.059762
# 6      41.025101    -74.05  -74.0603  -74.059762
# 7      40.913298    -74.58  -74.5863  -74.582460
# 8      40.821482    -74.41  -74.4200  -74.426480
# 9      40.867331    -74.41  -74.5783  -74.578269
# 10     40.619412    -74.76  -74.7406  -74.740597
# 11     40.612851    -74.76  -74.7724  -74.766820
# 12     40.612851    -74.76  -74.7724  -74.766820
# 13     40.557104    -74.28  -74.2845  -74.283160
# 14     40.998583    -74.16  -74.1660  -74.167100
# 15     40.819729    -73.87  -73.9217  -73.922300
# 16     40.838745    -73.87  -73.9216  -73.922340
# 17     40.853017    -73.87  -73.9129  -73.912140
# 18     40.805968    -73.87  -73.9198  -73.916280
# 19     40.815559    -73.87  -73.9072  -73.907710
# 20     40.829676    -73.87  -73.9099  -73.908560
# 21     40.846745    -73.87  -73.8999  -73.898610
# 22     40.864166    -73.87  -73.8895  -73.888810
# 23     40.825432    -73.87  -73.8940  -73.893270
# 24     40.840950    -73.87  -73.8794  -73.880360
# 25     40.842917    -73.87  -73.8410  -73.838190
# 26     40.842173    -73.87  -73.8602  -73.858620
# 27     40.881086    -73.87  -73.9067  -73.907490
# 28     40.857017    -73.87  -73.7874  -73.789030
# 29     40.825727    -73.87  -73.8196  -73.817520
# ...          ...       ...       ...         ...
# 57959  37.723290       NaN  -81.1788  -81.174440
# 57960  37.653792       NaN  -81.1906  -81.188330
# 57961  37.848955       NaN  -81.0937  -81.093678
# 57962  39.288336       NaN  -81.0847  -80.968967
# 57963        NaN       NaN  -80.9806         NaN
# 57964  39.198501       NaN  -81.0689  -81.068913
# 57965  38.731737       NaN  -81.3146  -81.314633
# 57966        NaN       NaN  -81.5076         NaN
# 57967  38.731737       NaN  -81.3146  -81.314633
# 57968  38.682668       NaN  -81.3146  -81.188460
# 57969  37.620418       NaN  -80.8900  -80.716360
# 57970        NaN       NaN  -80.8451         NaN
# 57971  37.648541       NaN  -80.8774  -80.877395
# 57972        NaN       NaN  -79.7024         NaN
# 57973  39.450612       NaN  -80.8701  -80.870081
# 57974  38.132114       NaN  -82.4183  -82.418277
# 57975        NaN       NaN  -80.6074         NaN
# 57976  39.619007       NaN  -80.6667  -80.612250
# 57977        NaN       NaN  -80.9027         NaN
# 57978        NaN       NaN  -80.9680         NaN
# 57979  37.603344       NaN  -81.5400  -81.539980
# 57980        NaN       NaN -106.2190         NaN
# 57981        NaN       NaN -106.1379         NaN
# 57982  42.894249       NaN -105.4852 -105.485243
# 57983  44.525891       NaN -104.7678 -104.767846
# 57984        NaN       NaN -104.9832         NaN
# 57985  43.769760       NaN -108.4541 -108.454106
# 57986        NaN       NaN -104.7203         NaN
# 57987        NaN       NaN -104.2963         NaN
# 57988        NaN       NaN -109.4363         NaN
#
# [57989 rows x 15 columns]

# %%
# Get a Primary City/State based on dataset agreement. Default to noncensus as "most trusted"
def get_primary(r):
    cities = filter(lambda x: isinstance(x, str),
                    [r['City_free'], r['City_geo'], r['City_non']])
    states = filter(lambda x: isinstance(x, str),
                    [r['State_free'], r['State_geo'], r['State_non']])
    
    def get_most_common(lst):
        cet = set(lst)
        write_val = None
        if len(cet) == 1:
            # If they all agree, use that value
            write_val = cet.pop()
        elif len(cet) == 2:
            # If 2/3 agree, go with it
            write_val = max(cet, key=lst.count)
        else:
            # Default to noncensus for now
            write_val = r['City_non']
        return write_val
    
    r['Primary_City'] = get_most_common(cities)
    r['Primary_State'] = get_most_common(states)
    return r
master_zips = master_zips.apply(get_primary, axis=1)
master_zips.head()
# Out:
#   Zip_free Zip_geo Zip_non       City_free        City_geo        City_non  \
# 0    07675   07675   07675        westwood        westwood        westwood
# 1    07675   07675   07675      old tappan        westwood        westwood
# 2    07675   07675   07675      river vale        westwood        westwood
# 3    07675   07675   07675       rivervale        westwood        westwood
# 4    07677   07677   07677  woodcliff lake  woodcliff lake  woodcliff lake
#
#   State_free State_geo State_non  Lat_free  Lat_geo    Lat_non  Lon_free  \
# 0         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 1         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 2         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 3         nj        nj        nj     40.98  41.0092  40.999040    -74.03
# 4         nj        nj        nj     41.02  41.0234  41.025101    -74.05
#
#    Lon_geo    Lon_non    Primary_City Primary_State
# 0 -74.0041 -74.032910        westwood            nj
# 1 -74.0041 -74.032910        westwood            nj
# 2 -74.0041 -74.032910        westwood            nj
# 3 -74.0041 -74.032910        westwood            nj
# 4 -74.0603 -74.059762  woodcliff lake            nj

# %%
# Using the TwoFishes geocoder (http://twofishes.net/), try to get better geo accuracy
# In related news, this is a nice way to stress test a geocoder
def get_twofishes(row):
    twofishes_url = 'http://localhost:8081/search/geocode'
    city, state = row['Primary_City'], row['Primary_State']
    if city and state:
        query = '{{"query": "{}, {}"}}'.format(city, state)
        tf_resp = requests.get(twofishes_url, params={'json': query})
        jsond = tf_resp.json()
        if not jsond['interpretations']:
            center = {'lat': np.nan, 'lng': np.nan}
        else:
            center = jsond['interpretations'][0]['feature']['geometry']['center']
        row['Lat_TwoFishes'] = center['lat']
        row['Lon_TwoFishes'] = center['lng']
    else:
        row['Lat_TwoFishes'] = np.nan
        row['Lon_TwoFishes'] = np.nan
    return row

master_zips = master_zips.apply(get_twofishes, axis=1)

# %%
master_zips.head(20)
# Out:
#    Zip_free Zip_geo Zip_non           City_free            City_geo  \
# 0     07675   07675   07675            westwood            westwood
# 1     07675   07675   07675          old tappan            westwood
# 2     07675   07675   07675          river vale            westwood
# 3     07675   07675   07675           rivervale            westwood
# 4     07677   07677   07677      woodcliff lake      woodcliff lake
# 5     07677   07677   07677            westwood      woodcliff lake
# 6     07677   07677   07677        woodcliff lk      woodcliff lake
# 7     07885   07885   07885             wharton             wharton
# 8     07981   07981   07981            whippany            whippany
# 9     07999   07999   07999            whippany            whippany
# 10    08888   08888   08888          whitehouse          whitehouse
# 11    08889   08889   08889  whitehouse station  whitehouse station
# 12    08889   08889   08889       white hse sta  whitehouse station
# 13    07095   07095   07095          woodbridge          woodbridge
# 14    07481   07481   07481             wyckoff             wyckoff
# 15    10451   10451   10451               bronx               bronx
# 16    10452   10452   10452               bronx               bronx
# 17    10453   10453   10453               bronx               bronx
# 18    10454   10454   10454               bronx               bronx
# 19    10455   10455   10455               bronx               bronx
#
#               City_non State_free State_geo State_non  Lat_free  Lat_geo  \
# 0             westwood         nj        nj        nj     40.98  41.0092
# 1             westwood         nj        nj        nj     40.98  41.0092
# 2             westwood         nj        nj        nj     40.98  41.0092
# 3             westwood         nj        nj        nj     40.98  41.0092
# 4       woodcliff lake         nj        nj        nj     41.02  41.0234
# 5       woodcliff lake         nj        nj        nj     41.02  41.0234
# 6       woodcliff lake         nj        nj        nj     41.02  41.0234
# 7              wharton         nj        nj        nj     40.89  40.9139
# 8             whippany         nj        nj        nj     40.82  40.8219
# 9             whippany         nj        nj        nj     40.82  40.8673
# 10          whitehouse         nj        nj        nj     40.62  40.6194
# 11  whitehouse station         nj        nj        nj     40.60  40.6156
# 12  whitehouse station         nj        nj        nj     40.60  40.6156
# 13          woodbridge         nj        nj        nj     40.55  40.5560
# 14             wyckoff         nj        nj        nj     40.99  40.9978
# 15               bronx         ny        ny        ny     40.84  40.8222
# 16               bronx         ny        ny        ny     40.84  40.8376
# 17               bronx         ny        ny        ny     40.84  40.8520
# 18               bronx         ny        ny        ny     40.84  40.8085
# 19               bronx         ny        ny        ny     40.84  40.8153
#
#       Lat_non  Lon_free  Lon_geo    Lon_non        Primary_City Primary_State  \
# 0   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 1   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 2   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 3   40.999040    -74.03 -74.0041 -74.032910            westwood            nj
# 4   41.025101    -74.05 -74.0603 -74.059762      woodcliff lake            nj
# 5   41.025101    -74.05 -74.0603 -74.059762      woodcliff lake            nj
# 6   41.025101    -74.05 -74.0603 -74.059762      woodcliff lake            nj
# 7   40.913298    -74.58 -74.5863 -74.582460             wharton            nj
# 8   40.821482    -74.41 -74.4200 -74.426480            whippany            nj
# 9   40.867331    -74.41 -74.5783 -74.578269            whippany            nj
# 10  40.619412    -74.76 -74.7406 -74.740597          whitehouse            nj
# 11  40.612851    -74.76 -74.7724 -74.766820  whitehouse station            nj
# 12  40.612851    -74.76 -74.7724 -74.766820  whitehouse station            nj
# 13  40.557104    -74.28 -74.2845 -74.283160          woodbridge            nj
# 14  40.998583    -74.16 -74.1660 -74.167100             wyckoff            nj
# 15  40.819729    -73.87 -73.9217 -73.922300               bronx            ny
# 16  40.838745    -73.87 -73.9216 -73.922340               bronx            ny
# 17  40.853017    -73.87 -73.9129 -73.912140               bronx            ny
# 18  40.805968    -73.87 -73.9198 -73.916280               bronx            ny
# 19  40.815559    -73.87 -73.9072 -73.907710               bronx            ny
#
#     Lat_TwoFishes  Lon_TwoFishes
# 0        40.99121      -74.03264
# 1        40.99121      -74.03264
# 2        40.99121      -74.03264
# 3        40.99121      -74.03264
# 4        41.02343      -74.06653
# 5        41.02343      -74.06653
# 6        41.02343      -74.06653
# 7        40.89315      -74.58183
# 8        40.82454      -74.41710
# 9        40.82454      -74.41710
# 10       40.61844      -74.74433
# 11       40.61538      -74.77044
# 12       40.61538      -74.77044
# 13       40.55760      -74.28459
# 14       41.00954      -74.17292
# 15       40.84985      -73.86641
# 16       40.84985      -73.86641
# 17       40.84985      -73.86641
# 18       40.84985      -73.86641
# 19       40.84985      -73.86641

# %%
# Let's check the max Haversine distance between points
def check_haversine(row):
    """
    Great circle distance between our Lat/Lon points (dec degrees)
    """
    # Ranking in order of "most trusted" to "least trusted"
    ranks = {1: "TwoFishes", 2: "non", 3: "geo", 4: "free"}
    
    # Convert to Radians   
                           
    rad_lat_1, rad_lon_1 = map(radians, [row['Lat_TwoFishes'], row['Lon_TwoFishes']])
    rad_lat_2, rad_lon_2 = map(radians, [row['Lat_non'], row['Lon_non']])
    rad_lat_3, rad_lon_3 = map(radians, [row['Lat_geo'], row['Lon_geo']])
    rad_lat_4, rad_lon_4 = map(radians, [row['Lat_free'], row['Lon_free']])
    
    
    # 1 vs 2, 1 vs 3, 1 vs 4, 2 vs 3, 2 vs 4, 3 vs 4
    pairs = [{'Pair': 'TwoFishes vs Non',
              'Ranks': [1, 2],
              'Data': (rad_lat_1, rad_lon_1, rad_lat_2, rad_lon_2)},
             {'Pair': 'TwoFishes vs Geo', 
              'Ranks': [1, 3],
              'Data': (rad_lat_1, rad_lon_1, rad_lat_3, rad_lon_3)},
             {'Pair': 'TwoFishes vs. Free',
              'Ranks': [1, 4],
              'Data': (rad_lat_1, rad_lon_1, rad_lat_4, rad_lon_4)},
             {'Pair': 'Non vs. Geo', 
              'Ranks': [2, 3],
              'Data': (rad_lat_2, rad_lon_2, rad_lat_3, rad_lon_3)},
             {'Pair': 'Non vs Free',
              'Ranks': [2, 4],
              'Data': (rad_lat_2, rad_lon_2, rad_lat_4, rad_lon_4)},
             {'Pair': 'Geo vs Free', 
              'Ranks': [3, 4],
              'Data': (rad_lat_3, rad_lon_3, rad_lat_4, rad_lon_4)}]
    
    # Only get pairs that don't have nan vals
    filtered_pairs = filter(lambda x: not any(map(np.isnan, x['Data'])), pairs)

    def get_dist(lat_1, lon_1, lat_2, lon_2):
        under_root = (sin((lat_2 - lat_1)/2)**2 + 
                      cos(lat_1) * cos(lat_2) * sin((lon_2 - lon_1)/2)**2)
        # 6367 = Earth radius in kilometers
        return 6367 * 2 * asin(sqrt(under_root)) 
        
    distanced_pairs = [{'Pair': p['Pair'],
                        'Best_Rank': min(p['Ranks']),
                        'Dist': get_dist(*p['Data'])} for p in filtered_pairs]
    
    # What if we have zero pairs?
    if not distanced_pairs:
        max_dist = {'Dist': np.nan, 'Pair': 'No Pair Found'}
        min_dist = {'Dist': np.nan, 'Pair': 'No Pair Found'}
    else:
        max_dist = max(distanced_pairs, key=lambda x: x['Dist'])
        min_dist = min(distanced_pairs, key=lambda x: x['Dist'])
    
    row['Max_Haversine_Dist'] = max_dist['Dist']
    row['Max_Dist_Pair'] = max_dist['Pair']
    
    row['Min_Haversine_Dist'] = min_dist['Dist']
    row['Min_Dist_Pair'] = min_dist['Pair']
    # If TwoFishes and Non agree closely, go with that data point
    # Otherwise, given the minimum distance set of points, which one of the two points is most trusted?
    fish_non = filter(lambda x: x['Pair'] == 'TwoFishes vs Non', distanced_pairs)
    if fish_non and fish_non[0]['Dist'] < 1.0:
        chosen = fish_non[0]
    else:
        chosen = min_dist
    trusted = ranks[chosen['Best_Rank']]
    trust_lat_nm, trust_lon_nm = 'Lat_' + trusted, 'Lon_' + trusted
    row['Primary_Geo_Source'] = trusted.capitalize()
    row['Lat_primary'] = row[trust_lat_nm]
    row['Lon_primary'] = row[trust_lon_nm]
    return row

master_zips = master_zips.apply(check_haversine, axis=1)

# %%
# What are our worst-case distance errors?
master_zips.sort('Min_Haversine_Dist', ascending=False)
# Out:
#       Zip_free Zip_geo Zip_non         City_free          City_geo  \
# 29798    99557   99557   99557       chuathbaluk             aniak
# 29799    99557   99557   99557       stony river             aniak
# 29797    99557   99557   99557             aniak             aniak
# 31165    92328   92328   92328      death valley      death valley
# 28220    97721   97721   97721         princeton         princeton
# 27060    86044   86044   86044           tonalea           tonalea
# 23750    69340   69340   69340         ellsworth         ellsworth
# 25870    84533   84533   84533        halls xing       lake powell
# 25867    84533   84533   84533       lake powell       lake powell
# 25869    84533   84533   84533    halls crossing       lake powell
# 25868    84533   84533   84533          bullfrog       lake powell
# 25871    84533   84533   84533              hite       lake powell
# 25872    84533   84533   84533           ticaboo       lake powell
# 29907    99586   99586   99586        miers lake            gakona
# 29908    99586   99586   99586             slana            gakona
# 29906    99586   99586   99586            gakona            gakona
# 30050    99653   99653   99653     port alsworth     port alsworth
# 27579    87357   87357   87357             ramah          pinehill
# 27578    87357   87357   87357          pinehill          pinehill
# 27642    87508   87508   87508          santa fe          santa fe
# 29849    99573   99573   99573     copper center     copper center
# 29838    99566   99566   99566           chitina           chitina
# 26721    86445   86445   86445           kingman      willow beach
# 26720    86445   86445   86445      willow beach      willow beach
# 26722    86445   86445   86445       white hills      willow beach
# 26023    84741   84741   84741      canyon point             kanab
# 26022    84741   84741   84741         big water             kanab
# 26021    84741   84741   84741             kanab             kanab
# 27272    87412   87412   87412            blanco            blanco
# 38367    39148   39148   39148       piney woods       piney woods
# ...        ...     ...     ...               ...               ...
# 26518    85118   85118   85118  superstition mtn       gold canyon
# 26519    85118   85118   85118     suprstitn mtn       gold canyon
# 26520    85119   85119   85119   apache junction   apache junction
# 26522    85120   85120   85120   apache junction   apache junction
# 26513    85118   85118   85118       gold canyon       gold canyon
# 26523    85120   85120   85120        apache jct   apache junction
# 26524    85178     NaN   85178   apache junction               NaN
# 26525    85178     NaN   85178        apache jct               NaN
# 26526    85190     NaN   85190     tortilla flat               NaN
# 26532    85392   85392   85392          avondale          avondale
# 53812    28759   28759   28759       mills river       mills river
# 26514    85118   85118   85118        apache jct       gold canyon
# 26512    85117     NaN   85117        apache jct               NaN
# 26043    84045   84045   84045     saratoga spgs  saratoga springs
# 48916    60682   60682   60682           chicago           chicago
# 48919    60686   60686   60686           chicago           chicago
# 26207    84096   84096   84096          herriman          herriman
# 26208    84096   84096   84096          riverton          herriman
# 26336    84129   84129   84129    salt lake city    salt lake city
# 26337    84129   84129   84129     salt lake cty    salt lake city
# 26338    84129   84129   84129      taylorsville    salt lake city
# 48880    60642   60642   60642           chicago           chicago
# 26511    85117     NaN   85117   apache junction               NaN
# 48827    60399   60399   60399       bensenville         wood dale
# 26498    84081   84081   84081       west jordan       west jordan
# 26499    84081   84081   84081     w valley city       west jordan
# 26500    84081   84081   84081       west valley       west jordan
# 26501    84081   84081   84081  west valley city       west jordan
# 26507    83414   83414   83414              alta              alta
# 55982    97475   97475   97475       springfield       springfield
#
#                City_non State_free State_geo State_non  Lat_free     ...       \
# 29798             aniak         ak        ak        ak     61.20     ...
# 29799             aniak         ak        ak        ak     61.20     ...
# 29797             aniak         ak        ak        ak     61.20     ...
# 31165      death valley         ca        ca        ca     36.29     ...
# 28220         princeton         or        or        or     42.86     ...
# 27060           tonalea         az        az        az     36.91     ...
# 23750         ellsworth         ne        ne        ne     42.06     ...
# 25870       lake powell         ut        ut        ut     37.57     ...
# 25867       lake powell         ut        ut        ut     37.57     ...
# 25869       lake powell         ut        ut        ut     37.57     ...
# 25868       lake powell         ut        ut        ut     37.57     ...
# 25871       lake powell         ut        ut        ut     37.57     ...
# 25872       lake powell         ut        ut        ut     37.57     ...
# 29907            gakona         ak        ak        ak     62.41     ...
# 29908            gakona         ak        ak        ak     62.41     ...
# 29906            gakona         ak        ak        ak     62.41     ...
# 30050     port alsworth         ak        ak        ak     60.46     ...
# 27579          pinehill         nm        nm        nm     34.81     ...
# 27578          pinehill         nm        nm        nm     34.81     ...
# 27642          santa fe         nm        nm        nm     35.57     ...
# 29849     copper center         ak        ak        ak     61.68     ...
# 29838           chitina         ak        ak        ak     61.45     ...
# 26721      willow beach         az        az        az     35.90     ...
# 26720      willow beach         az        az        az     35.90     ...
# 26722      willow beach         az        az        az     35.90     ...
# 26023             kanab         ut        ut        ut     37.27     ...
# 26022             kanab         ut        ut        ut     37.27     ...
# 26021             kanab         ut        ut        ut     37.27     ...
# 27272            blanco         nm        nm        nm     36.61     ...
# 38367       piney woods         ms        ms        ms     32.12     ...
# ...                 ...        ...       ...       ...       ...     ...
# 26518       gold canyon         az        az        az     33.34     ...
# 26519       gold canyon         az        az        az     33.34     ...
# 26520   apache junction         az        az        az     33.38     ...
# 26522   apache junction         az        az        az     33.40     ...
# 26513       gold canyon         az        az        az     33.34     ...
# 26523   apache junction         az        az        az     33.40     ...
# 26524   apache junction         az       NaN        az     33.42     ...
# 26525   apache junction         az       NaN        az     33.42     ...
# 26526     tortilla flat         az       NaN        az     33.52     ...
# 26532          avondale         az        az        az     33.47     ...
# 53812       mills river         nc        nc        nc     35.39     ...
# 26514       gold canyon         az        az        az     33.34     ...
# 26512   apache junction         az       NaN        az     33.42     ...
# 26043  saratoga springs         ut        ut        ut     40.28     ...
# 48916           chicago         il        il        il     41.86     ...
# 48919           chicago         il        il        il     41.85     ...
# 26207          herriman         ut        ut        ut     40.48     ...
# 26208          herriman         ut        ut        ut     40.48     ...
# 26336    salt lake city         ut        ut        ut     40.66     ...
# 26337    salt lake city         ut        ut        ut     40.66     ...
# 26338    salt lake city         ut        ut        ut     40.66     ...
# 48880           chicago         il        il        il     41.90     ...
# 26511   apache junction         az       NaN        az     33.42     ...
# 48827         wood dale         il        il        il     41.96     ...
# 26498       west jordan         ut        ut        ut     40.59     ...
# 26499       west jordan         ut        ut        ut     40.59     ...
# 26500       west jordan         ut        ut        ut     40.59     ...
# 26501       west jordan         ut        ut        ut     40.59     ...
# 26507              alta         wy        wy        wy     43.75     ...
# 55982       springfield         or        or        or     44.05     ...
#
#        Primary_State  Lat_TwoFishes  Lon_TwoFishes  Max_Haversine_Dist  \
# 29798             ak       61.57833     -159.52222          267.901140
# 29799             ak       61.57833     -159.52222          267.901140
# 29797             ak       61.57833     -159.52222          267.901140
# 31165             ca       36.24662     -116.81700           77.671735
# 28220             or       44.00013     -120.50139          210.382953
# 27060             az       36.32249     -110.96348           65.817370
# 23750             ne       42.30639      -98.00954          360.852678
# 25870             ut       37.03654     -111.35330          135.044254
# 25867             ut       37.03654     -111.35330          135.044254
# 25869             ut       37.03654     -111.35330          135.044254
# 25868             ut       37.03654     -111.35330          135.044254
# 25871             ut       37.03654     -111.35330          135.044254
# 25872             ut       37.03654     -111.35330          135.044254
# 29907             ak       62.30194     -145.30194           98.280164
# 29908             ak       62.30194     -145.30194           98.280164
# 29906             ak       62.30194     -145.30194           98.280164
# 30050             ak       60.20250     -154.31278          280.448546
# 27579             nm       34.99920     -108.41118           39.694763
# 27578             nm       34.99920     -108.41118           39.694763
# 27642             nm       35.68698     -105.93780           34.025988
# 29849             ak       61.97696     -145.32973           58.984510
# 29838             ak       61.51583     -144.43694           97.766304
# 26721             az       40.50000       47.50000        11329.170493
# 26720             az       40.50000       47.50000        11329.170493
# 26722             az       40.50000       47.50000        11329.170493
# 26023             ut       37.04749     -112.52631           78.158140
# 26022             ut       37.04749     -112.52631           78.158140
# 26021             ut       37.04749     -112.52631           78.158140
# 27272             nm       36.72417     -107.82534           51.987506
# 38367             ms       33.80095      -89.72008          195.332668
# ...              ...            ...            ...                 ...
# 26518             az       33.37145     -111.43691            9.363306
# 26519             az       33.37145     -111.43691            9.363306
# 26520             az       33.41505     -111.54958            5.352982
# 26522             az       33.41505     -111.54958            3.510850
# 26513             az       33.37145     -111.43691            9.363306
# 26523             az       33.41505     -111.54958            3.510850
# 26524             az       33.41505     -111.54958            1.045062
# 26525             az       33.41505     -111.54958            1.045062
# 26526             az       33.52644     -111.38985            1.159667
# 26532             az       33.43560     -112.34960            6.719259
# 53812             nc       35.38845      -82.56679            0.337987
# 26514             az       33.37145     -111.43691            9.363306
# 26512             az       33.41505     -111.54958            1.045062
# 26043             ut       40.34912     -111.90466            7.992952
# 48916             il       41.85003      -87.65005           13.285328
# 48919             il       41.85003      -87.65005            3.018665
# 26207             ut       40.51411     -112.03299            4.965373
# 26208             ut       40.51411     -112.03299            4.965373
# 26336             ut       40.76078     -111.89105           13.584920
# 26337             ut       40.76078     -111.89105           13.584920
# 26338             ut       40.76078     -111.89105           13.584920
# 48880             il       41.85003      -87.65005            5.646409
# 26511             az       33.41505     -111.54958            1.045062
# 48827             il       41.96336      -87.97896            3.548844
# 26498             ut       40.60967     -111.93910            8.630833
# 26499             ut       40.60967     -111.93910            8.630833
# 26500             ut       40.60967     -111.93910            8.630833
# 26501             ut       40.60967     -111.93910            8.630833
# 26507             wy       43.75381     -111.03689           17.035926
# 55982             or       44.04624     -123.02203            3.783093
#
#             Max_Dist_Pair Min_Haversine_Dist       Min_Dist_Pair  \
# 29798         Non vs. Geo          33.943132    TwoFishes vs Non
# 29799         Non vs. Geo          33.943132    TwoFishes vs Non
# 29797         Non vs. Geo          33.943132    TwoFishes vs Non
# 31165         Non vs Free          25.454930    TwoFishes vs Geo
# 28220  TwoFishes vs. Free          25.420655         Non vs Free
# 27060  TwoFishes vs. Free          22.265978    TwoFishes vs Non
# 23750    TwoFishes vs Geo          20.318648         Non vs Free
# 25870    TwoFishes vs Non          19.609828         Non vs. Geo
# 25867    TwoFishes vs Non          19.609828         Non vs. Geo
# 25869    TwoFishes vs Non          19.609828         Non vs. Geo
# 25868    TwoFishes vs Non          19.609828         Non vs. Geo
# 25871    TwoFishes vs Non          19.609828         Non vs. Geo
# 25872    TwoFishes vs Non          19.609828         Non vs. Geo
# 29907  TwoFishes vs. Free          19.393350         Non vs. Geo
# 29908  TwoFishes vs. Free          19.393350         Non vs. Geo
# 29906  TwoFishes vs. Free          19.393350         Non vs. Geo
# 30050         Geo vs Free          17.506037    TwoFishes vs Non
# 27579         Geo vs Free          17.182057    TwoFishes vs Non
# 27578         Geo vs Free          17.182057    TwoFishes vs Non
# 27642         Non vs Free          17.051076         Non vs. Geo
# 29849    TwoFishes vs Geo          16.883538    TwoFishes vs Non
# 29838         Geo vs Free          16.220374    TwoFishes vs Non
# 26721    TwoFishes vs Geo          15.992857         Geo vs Free
# 26720    TwoFishes vs Geo          15.992857         Geo vs Free
# 26722    TwoFishes vs Geo          15.992857         Geo vs Free
# 26023    TwoFishes vs Geo          15.756176         Non vs Free
# 26022    TwoFishes vs Geo          15.756176         Non vs Free
# 26021    TwoFishes vs Geo          15.756176         Non vs Free
# 27272         Non vs. Geo          15.270328  TwoFishes vs. Free
# 38367    TwoFishes vs Non          14.777114         Non vs Free
# ...                   ...                ...                 ...
# 26518    TwoFishes vs Geo           0.000000         Non vs Free
# 26519    TwoFishes vs Geo           0.000000         Non vs Free
# 26520    TwoFishes vs Non           0.000000         Non vs Free
# 26522    TwoFishes vs Geo           0.000000         Non vs Free
# 26513    TwoFishes vs Geo           0.000000         Non vs Free
# 26523    TwoFishes vs Geo           0.000000         Non vs Free
# 26524    TwoFishes vs Non           0.000000         Non vs Free
# 26525    TwoFishes vs Non           0.000000         Non vs Free
# 26526    TwoFishes vs Non           0.000000         Non vs Free
# 26532    TwoFishes vs Non           0.000000         Non vs Free
# 53812    TwoFishes vs Non           0.000000         Non vs Free
# 26514    TwoFishes vs Geo           0.000000         Non vs Free
# 26512    TwoFishes vs Non           0.000000         Non vs Free
# 26043         Non vs. Geo           0.000000         Non vs Free
# 48916    TwoFishes vs Non           0.000000         Non vs Free
# 48919         Non vs. Geo           0.000000         Non vs Free
# 26207         Non vs. Geo           0.000000         Non vs Free
# 26208         Non vs. Geo           0.000000         Non vs Free
# 26336    TwoFishes vs Geo           0.000000         Non vs Free
# 26337    TwoFishes vs Geo           0.000000         Non vs Free
# 26338    TwoFishes vs Geo           0.000000         Non vs Free
# 48880    TwoFishes vs Geo           0.000000         Non vs Free
# 26511    TwoFishes vs Non           0.000000         Non vs Free
# 48827    TwoFishes vs Geo           0.000000         Non vs Free
# 26498    TwoFishes vs Geo           0.000000         Non vs Free
# 26499    TwoFishes vs Geo           0.000000         Non vs Free
# 26500    TwoFishes vs Geo           0.000000         Non vs Free
# 26501    TwoFishes vs Geo           0.000000         Non vs Free
# 26507         Non vs. Geo           0.000000         Non vs Free
# 55982    TwoFishes vs Geo           0.000000         Non vs Free
#
#        Min_Dist_Source  Lat_primary  Lon_primary
# 29798        Twofishes    61.578330  -159.522220
# 29799        Twofishes    61.578330  -159.522220
# 29797        Twofishes    61.578330  -159.522220
# 31165        Twofishes    36.246620  -116.817000
# 28220              Non    43.036496  -118.618820
# 27060        Twofishes    36.322490  -110.963480
# 23750              Non    42.232420  -102.197920
# 25870              Non    37.655431  -110.037720
# 25867              Non    37.655431  -110.037720
# 25869              Non    37.655431  -110.037720
# 25868              Non    37.655431  -110.037720
# 25871              Non    37.655431  -110.037720
# 25872              Non    37.655431  -110.037720
# 29907              Non    62.667589  -144.490590
# 29908              Non    62.667589  -144.490590
# 29906              Non    62.667589  -144.490590
# 30050        Twofishes    60.202500  -154.312780
# 27579        Twofishes    34.999200  -108.411180
# 27578        Twofishes    34.999200  -108.411180
# 27642              Non    35.469938  -105.754453
# 29849        Twofishes    61.976960  -145.329730
# 29838        Twofishes    61.515830  -144.436940
# 26721              Geo    35.775900  -114.500100
# 26720              Geo    35.775900  -114.500100
# 26722              Geo    35.775900  -114.500100
# 26023              Non    37.162224  -112.114310
# 26022              Non    37.162224  -112.114310
# 26021              Non    37.162224  -112.114310
# 27272        Twofishes    36.724170  -107.825340
# 38367              Non    32.057964   -89.991170
# ...                ...          ...          ...
# 26518              Non    33.340000  -111.420000
# 26519              Non    33.340000  -111.420000
# 26520              Non    33.380000  -111.510000
# 26522              Non    33.400000  -111.560000
# 26513              Non    33.340000  -111.420000
# 26523              Non    33.400000  -111.560000
# 26524              Non    33.420000  -111.540000
# 26525              Non    33.420000  -111.540000
# 26526              Non    33.520000  -111.380000
# 26532              Non    33.470000  -112.290000
# 53812        Twofishes    35.388450   -82.566790
# 26514              Non    33.340000  -111.420000
# 26512              Non    33.420000  -111.540000
# 26043              Non    40.280000  -111.880000
# 48916              Non    41.860000   -87.810000
# 48919        Twofishes    41.850030   -87.650050
# 26207              Non    40.480000  -112.070000
# 26208              Non    40.480000  -112.070000
# 26336              Non    40.660000  -111.930000
# 26337              Non    40.660000  -111.930000
# 26338              Non    40.660000  -111.930000
# 48880              Non    41.900000   -87.650000
# 26511              Non    33.420000  -111.540000
# 48827              Non    41.960000   -87.940000
# 26498              Non    40.590000  -112.030000
# 26499              Non    40.590000  -112.030000
# 26500              Non    40.590000  -112.030000
# 26501              Non    40.590000  -112.030000
# 26507        Twofishes    43.753810  -111.036890
# 55982        Twofishes    44.046240  -123.022030
#
# [55983 rows x 26 columns]

# %%
len(master_zips[master_zips['Min_Haversine_Dist'] > 5])
# Out:
# 474

# %%
final_cols = master_zips[['Zip_free', 'Primary_City', 'Primary_State',
                          'Lat_primary', 'Lon_primary']]

# %%
final_zips = final_cols.drop_duplicates()
final_zips = final_zips.rename(columns={'Zip_free': 'Zipcode',
                                        'Primary_City': 'City',
                                        'Primary_State': 'State',
                                        'Lat_primary': 'Latitude',
                                        'Lon_primary': 'Longitude'})
final_zips
# Out:
#       Zipcode                City State   Latitude   Longitude
# 0       00705            aibonito    pr  18.139960  -66.266000
# 1       00610              anasco    pr  18.282730  -67.139620
# 2       00611             angeles    pr  18.284950  -66.799340
# 3       00612             arecibo    pr  18.472440  -66.715730
# 4       00601            adjuntas    pr  18.163790  -66.723690
# 5       00631            castaner    pr  18.180510  -66.832120
# 7       00602              aguada    pr  18.379390  -67.188240
# 8       00603           aguadilla    pr  18.427450  -67.154070
# 10      00604           aguadilla    pr  18.427450  -67.154070
# 12      00605           aguadilla    pr  18.427450  -67.154070
# 13      00703        aguas buenas    pr  18.256900  -66.102940
# 14      00704             aguirre    pr  17.970112  -66.222910
# 15      07675            westwood    nj  40.991210  -74.032640
# 19      07677      woodcliff lake    nj  41.023430  -74.066530
# 22      07885             wharton    nj  40.913298  -74.582460
# 23      07981            whippany    nj  40.824540  -74.417100
# 24      07999            whippany    nj  40.867331  -74.578269
# 25      08888          whitehouse    nj  40.618440  -74.744330
# 26      08889  whitehouse station    nj  40.615380  -74.770440
# 28      07095          woodbridge    nj  40.557600  -74.284590
# 29      07481             wyckoff    nj  40.998583  -74.167100
# 30      10451               bronx    ny  40.819729  -73.922300
# 31      10452               bronx    ny  40.838745  -73.922340
# 32      10453               bronx    ny  40.853017  -73.912140
# 33      10454               bronx    ny  40.805968  -73.916280
# 34      10455               bronx    ny  40.815559  -73.907710
# 35      10456               bronx    ny  40.829676  -73.908560
# 36      10457               bronx    ny  40.846745  -73.898610
# 37      10458               bronx    ny  40.864166  -73.888810
# 38      10459               bronx    ny  40.825432  -73.893270
# ...       ...                 ...   ...        ...         ...
# 55946   97251            portland    or  45.580557 -122.374776
# 55947   97253            portland    or  45.580557 -122.374776
# 55948   97254            portland    or  45.596678 -122.594180
# 55949   97255            portland    or  45.580557 -122.374776
# 55950   97259            portland    or  45.580557 -122.374776
# 55951   97271            portland    or  45.580557 -122.374776
# 55952   97272            portland    or  45.580557 -122.374776
# 55953   97299            portland    or  45.580557 -122.374776
# 55954   97313               salem    or  44.984941 -122.998756
# 55955   97372          rose lodge    or  44.659979 -123.892016
# 55957   97425       crescent lake    or  43.472276 -121.927680
# 55959   97427          culp creek    or  43.685176 -122.798270
# 55960   97428              curtin    or  43.745797 -123.181910
# 55961   97472             saginaw    or  43.863845 -122.998790
# 55963   97482            thurston    or  43.863845 -122.998790
# 55965   98054             redondo    wa  47.432251 -121.803388
# 55966   98151             seattle    wa  47.432251 -121.803388
# 55968   98171             seattle    wa  47.432251 -121.803388
# 55969   98184             seattle    wa  47.432251 -121.803388
# 55970   98442              tacoma    wa  47.308061 -122.418495
# 55971   98450              tacoma    wa  47.066193 -122.113223
# 55972   98455              tacoma    wa  47.066193 -122.113223
# 55973   98460              tacoma    wa  47.066193 -122.113223
# 55974   98477              tacoma    wa  47.066193 -122.113223
# 55975   98492            lakewood    wa  47.066193 -122.113223
# 55977   98667           vancouver    wa  45.801586 -122.520347
# 55978   98929       goose prairie    wa  46.915735 -121.241591
# 55980   99165             pullman    wa  46.838747 -117.644337
# 55981   99779              tetlin    ak  63.135050 -142.523880
# 55982   97475         springfield    or  44.046240 -123.022030
#
# [41857 rows x 5 columns]

# %%
# How many unique zip codes as compared to our original sets?
len(set(final_zips['Zip_free']))
# Out:
# 41719

# %%
from math import radians, cos, sin, asin, sqrt
import pandas as pd
import numpy as np

# Import, lowercase city/state name to attempt join later

# Geonames is ~1:1 City/Place names to Zip Codes
# Schema: http://download.geonames.org/export/zip/readme.txt
col_names = ['country_code',
             'postal_code',
             'place_name',
             'admin_name1',
             'admin_code1',
             'admin_name2',
             'admin_code2',
             'admin_name3',
             'admin_code3',
             'latitude',
             'longitude',
             'accuracy']
geonames = pd.read_table('GeoNamesZip.txt', header=None, names=col_names, dtype={'postal_code': str})
geonames['place_name'] = geonames['place_name'].str.lower()
geonames['admin_code1'] = geonames['admin_code1'].str.lower()
geonames_set = set(geonames['postal_code'])

# Free-zip 1 is 1:1 City to Zip Code
free_zip_db = pd.read_csv('free-zipcode-database-Primary.csv', dtype={'Zipcode': str})
free_zip_db['City'] = free_zip_db['City'].str.lower()
free_zip_db['State'] = free_zip_db['State'].str.lower()
freezip_set = set(free_zip_db['Zipcode'])

# Free-zip all is Many:1 City to Zip Code
free_zip_all = pd.read_csv('free-zipcode-database-all-places.csv', dtype={'Zipcode': str})
# We only want Primary/Acceptable locs. There is some junk here.
free_zip_all = free_zip_all[free_zip_all['LocationType'].isin(['ACCEPTABLE', 'PRIMARY'])]
free_zip_all['City'] = free_zip_all['City'].str.lower()
free_zip_all['State'] = free_zip_all['State'].str.lower()
freezip_all_set = set(free_zip_all['Zipcode'])

#
noncensus = pd.read_csv('noncensus_zip.csv', dtype={'zip': str})
noncensus['city'] = noncensus['city'].str.lower()
noncensus['state'] = noncensus['state'].str.lower()
noncensus_set = set(noncensus['zip'])

set_lengths = {
    'noncensus_set': len(noncensus_set),
    'free_zip_set': len(freezip_set),
    'free_zip_all_set': len(freezip_all_set),
    'geonames_set': len(geonames_set)
    }
set_lengths
# Out:
# {'free_zip_all_set': 42522,
#  'free_zip_set': 42522,
#  'geonames_set': 43586,
#  'noncensus_set': 43524}

# %%
len(geonames), len(free_zip_db), len(free_zip_all), len(noncensus)
# Out:
# (43629, 42522, 56725, 43524)

# %%
# Columns of interest, rename for specificity
geo_zip_place_loc = geonames[['postal_code', 'place_name', 'admin_code1',
                              'latitude', 'longitude']]
geo_zip_place_loc = geo_zip_place_loc.rename(columns={'postal_code': 'Zip_geo',
                                                      'latitude': 'Lat_geo', 
                                                      'longitude': 'Lon_geo',
                                                      'place_name': 'City_geo',
                                                      'admin_code1': 'State_geo'})

free_zip_all_place_loc = free_zip_all[['Zipcode', 'City', 'State', 'Lat', 'Long']]
free_zip_all_place_loc = free_zip_all_place_loc.rename(columns={'Zipcode': 'Zip_free',
                                                                'Lat': 'Lat_free',
                                                                'Long': 'Lon_free',
                                                                'City': 'City_free',
                                                                'State': 'State_free'})
noncensus_place_loc = noncensus[['zip', 'city', 'state', 'latitude', 'longitude']]
noncensus_place_loc = noncensus_place_loc.rename(columns={'zip': 'Zip_non',
                                                          'latitude': 'Lat_non', 
                                                          'longitude': 'Lon_non',
                                                          'city': 'City_non',
                                                          'state': 'State_non'})

# %%
# free-zip vs geonames
merged_zip = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                      left_on='Zip_free', right_on='Zip_geo')
merged_zip_city = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                           left_on=['Zip_free', 'City_free'], 
                           right_on=['Zip_geo', 'City_geo'])
merged_zip_state = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                            left_on=['Zip_free', 'State_free'], 
                            right_on=['Zip_geo', 'State_geo'])
merged_zip_city_state = pd.merge(free_zip_all_place_loc, geo_zip_place_loc, 
                                 left_on=['Zip_free', 'City_free', 'State_free'], 
                                 right_on=['Zip_geo', 'City_geo', 'State_geo'])
lengths_free_geo = {
    'merged_zip': len(merged_zip),
    'merged_zip_city': len(merged_zip_city),
    'merged_zip_state': len(merged_zip_state),
    'merged_zip_city_state': len(merged_zip_city_state)
}
lengths_free_geo
# Out:
# {'merged_zip': 55777,
#  'merged_zip_city': 41386,
#  'merged_zip_city_state': 41386,
#  'merged_zip_state': 55777}

# %%
merged_zip
# Out:
#       Zip_free            City_free State_free  Lat_free  Lon_free Zip_geo  \
# 0        07675             westwood         nj     40.98    -74.03   07675
# 1        07675           old tappan         nj     40.98    -74.03   07675
# 2        07675           river vale         nj     40.98    -74.03   07675
# 3        07675            rivervale         nj     40.98    -74.03   07675
# 4        07677       woodcliff lake         nj     41.02    -74.05   07677
# 5        07677             westwood         nj     41.02    -74.05   07677
# 6        07677         woodcliff lk         nj     41.02    -74.05   07677
# 7        07885              wharton         nj     40.89    -74.58   07885
# 8        07981             whippany         nj     40.82    -74.41   07981
# 9        07999             whippany         nj     40.82    -74.41   07999
# 10       08888           whitehouse         nj     40.62    -74.76   08888
# 11       08889   whitehouse station         nj     40.60    -74.76   08889
# 12       08889        white hse sta         nj     40.60    -74.76   08889
# 13       07095           woodbridge         nj     40.55    -74.28   07095
# 14       07481              wyckoff         nj     40.99    -74.16   07481
# 15       10451                bronx         ny     40.84    -73.87   10451
# 16       10452                bronx         ny     40.84    -73.87   10452
# 17       10453                bronx         ny     40.84    -73.87   10453
# 18       10454                bronx         ny     40.84    -73.87   10454
# 19       10455                bronx         ny     40.84    -73.87   10455
# 20       10456                bronx         ny     40.84    -73.87   10456
# 21       10457                bronx         ny     40.84    -73.87   10457
# 22       10458                bronx         ny     40.84    -73.87   10458
# 23       10459                bronx         ny     40.84    -73.87   10459
# 24       10460                bronx         ny     40.84    -73.87   10460
# 25       10461                bronx         ny     40.84    -73.87   10461
# 26       10462                bronx         ny     40.84    -73.87   10462
# 27       10463                bronx         ny     40.84    -73.87   10463
# 28       10464                bronx         ny     40.84    -73.87   10464
# 29       10465                bronx         ny     40.84    -73.87   10465
# ...        ...                  ...        ...       ...       ...     ...
# 55747    97299             portland         or     45.54   -122.61   97299
# 55748    97313                salem         or     45.03   -123.02   97313
# 55749    97372         lincoln city         or     45.01   -123.87   97372
# 55750    97372           rose lodge         or     45.01   -123.87   97372
# 55751    97425       cascade summit         or     43.47   -121.92   97425
# 55752    97425        crescent lake         or     43.47   -121.92   97425
# 55753    97427           culp creek         or     43.68   -122.79   97427
# 55754    97428               curtin         or     43.74   -123.18   97428
# 55755    97472              saginaw         or     43.79   -123.06   97472
# 55756    97472        cottage grove         or     43.79   -123.06   97472
# 55757    97482             thurston         or     44.05   -122.91   97482
# 55758    97482          springfield         or     44.05   -122.91   97482
# 55759    98054              redondo         wa     47.34   -122.32   98054
# 55760    98151  goodwill games 1990         wa     47.60   -122.33   98151
# 55761    98151              seattle         wa     47.60   -122.33   98151
# 55762    98171              seattle         wa     47.60   -122.33   98171
# 55763    98184              seattle         wa     47.60   -122.33   98184
# 55764    98442               tacoma         wa     47.14   -122.43   98442
# 55765    98450               tacoma         wa     47.25   -122.44   98450
# 55766    98455               tacoma         wa     47.25   -122.44   98455
# 55767    98460               tacoma         wa     47.25   -122.44   98460
# 55768    98477               tacoma         wa     47.25   -122.44   98477
# 55769    98492             lakewood         wa     47.12   -122.55   98492
# 55770    98492               tacoma         wa     47.12   -122.55   98492
# 55771    98667            vancouver         wa     45.63   -122.66   98667
# 55772    98929        goose prairie         wa     46.74   -121.14   98929
# 55773    98929               naches         wa     46.74   -121.14   98929
# 55774    99165              pullman         wa     46.73   -117.17   99165
# 55775    99779                  tok         ak     63.13   -142.53   99779
# 55776    97475          springfield         or     44.05   -123.02   97475
#
#                  City_geo State_geo  Lat_geo   Lon_geo
# 0                westwood        nj  41.0092  -74.0041
# 1                westwood        nj  41.0092  -74.0041
# 2                westwood        nj  41.0092  -74.0041
# 3                westwood        nj  41.0092  -74.0041
# 4          woodcliff lake        nj  41.0234  -74.0603
# 5          woodcliff lake        nj  41.0234  -74.0603
# 6          woodcliff lake        nj  41.0234  -74.0603
# 7                 wharton        nj  40.9139  -74.5863
# 8                whippany        nj  40.8219  -74.4200
# 9                whippany        nj  40.8673  -74.5783
# 10             whitehouse        nj  40.6194  -74.7406
# 11     whitehouse station        nj  40.6156  -74.7724
# 12     whitehouse station        nj  40.6156  -74.7724
# 13             woodbridge        nj  40.5560  -74.2845
# 14                wyckoff        nj  40.9978  -74.1660
# 15                  bronx        ny  40.8222  -73.9217
# 16                  bronx        ny  40.8376  -73.9216
# 17                  bronx        ny  40.8520  -73.9129
# 18                  bronx        ny  40.8085  -73.9198
# 19                  bronx        ny  40.8153  -73.9072
# 20                  bronx        ny  40.8316  -73.9099
# 21                  bronx        ny  40.8486  -73.8999
# 22                  bronx        ny  40.8633  -73.8895
# 23                  bronx        ny  40.8247  -73.8940
# 24                  bronx        ny  40.8409  -73.8794
# 25                  bronx        ny  40.8465  -73.8410
# 26                  bronx        ny  40.8434  -73.8602
# 27                  bronx        ny  40.8798  -73.9067
# 28                  bronx        ny  40.8469  -73.7874
# 29                  bronx        ny  40.8261  -73.8196
# ...                   ...       ...      ...       ...
# 55747            portland        or  45.5806 -122.3748
# 55748               salem        or  44.9849 -122.9988
# 55749          rose lodge        or  44.6600 -123.8920
# 55750          rose lodge        or  44.6600 -123.8920
# 55751       crescent lake        or  43.5180 -121.9495
# 55752       crescent lake        or  43.5180 -121.9495
# 55753          culp creek        or  43.6579 -122.7871
# 55754              curtin        or  43.7476 -123.1962
# 55755             saginaw        or  43.8638 -122.9988
# 55756             saginaw        or  43.8638 -122.9988
# 55757            thurston        or  43.8638 -122.9988
# 55758            thurston        or  43.8638 -122.9988
# 55759             redondo        wa  47.4323 -121.8034
# 55760             seattle        wa  47.4323 -121.8034
# 55761             seattle        wa  47.4323 -121.8034
# 55762             seattle        wa  47.4323 -121.8034
# 55763             seattle        wa  47.4323 -121.8034
# 55764              tacoma        wa  47.3081 -122.4185
# 55765              tacoma        wa  47.0662 -122.1132
# 55766              tacoma        wa  47.0662 -122.1132
# 55767              tacoma        wa  47.0662 -122.1132
# 55768              tacoma        wa  47.0662 -122.1132
# 55769            lakewood        wa  47.0662 -122.1132
# 55770            lakewood        wa  47.0662 -122.1132
# 55771           vancouver        wa  45.8016 -122.5203
# 55772       goose prairie        wa  46.9157 -121.2416
# 55773       goose prairie        wa  46.9157 -121.2416
# 55774             pullman        wa  46.8387 -117.6443
# 55775              tetlin        ak  63.8706 -144.0026
# 55776         springfield        or  44.0437 -122.9748
#
# [55777 rows x 10 columns]

# %%
# noncensus vs free zip
merged_non_free_zip = pd.merge(free_zip_all_place_loc, noncensus_place_loc,
                               left_on=['Zip_free'], right_on=['Zip_non'])
merged_non_free_zip_city = pd.merge(free_zip_all_place_loc, noncensus_place_loc,
                                    left_on=['Zip_free', 'City_free'], right_on=['Zip_non', 'City_non'])
merged_non_free_zip_state = pd.merge(free_zip_all_place_loc, noncensus_place_loc,
                                     left_on=['Zip_free', 'State_free'], right_on=['Zip_non', 'State_non'])
merged_non_free_zip_city_state = pd.merge(free_zip_all_place_loc, noncensus_place_loc,
                                          left_on=['Zip_free', 'City_free', 'State_free'], 
                                          right_on=['Zip_non', 'City_non', 'State_non'])
lengths_noncensus_free = {
    'merged_zip': len(merged_non_free_zip),
    'merged_zip_city': len(merged_non_free_zip_city),
    'merged_zip_state': len(merged_non_free_zip_state),
    'merged_zip_city_state': len(merged_non_free_zip_city_state)
}
lengths_noncensus_free
# Out:
# {'merged_zip': 55867,
#  'merged_zip_city': 41461,
#  'merged_zip_city_state': 41435,
#  'merged_zip_state': 55829}

# %%
merged_non_free_zip
# Out:
#       Zip_free            City_free State_free  Lat_free  Lon_free Zip_non  \
# 0        00705             aibonito         pr     18.14    -66.26   00705
# 1        00610               anasco         pr     18.28    -67.14   00610
# 2        00611              angeles         pr     18.28    -66.79   00611
# 3        00612              arecibo         pr     18.45    -66.73   00612
# 4        00601             adjuntas         pr     18.16    -66.72   00601
# 5        00631             castaner         pr     18.19    -66.82   00631
# 6        00631             adjuntas         pr     18.19    -66.82   00631
# 7        00602               aguada         pr     18.38    -67.18   00602
# 8        00603            aguadilla         pr     18.43    -67.15   00603
# 9        00603                ramey         pr     18.43    -67.15   00603
# 10       00604            aguadilla         pr     18.43    -67.15   00604
# 11       00604                ramey         pr     18.43    -67.15   00604
# 12       00605            aguadilla         pr     18.43    -67.15   00605
# 13       00703         aguas buenas         pr     18.25    -66.10   00703
# 14       00704              aguirre         pr     17.96    -66.22   00704
# 15       07675             westwood         nj     40.98    -74.03   07675
# 16       07675           old tappan         nj     40.98    -74.03   07675
# 17       07675           river vale         nj     40.98    -74.03   07675
# 18       07675            rivervale         nj     40.98    -74.03   07675
# 19       07677       woodcliff lake         nj     41.02    -74.05   07677
# 20       07677             westwood         nj     41.02    -74.05   07677
# 21       07677         woodcliff lk         nj     41.02    -74.05   07677
# 22       07885              wharton         nj     40.89    -74.58   07885
# 23       07981             whippany         nj     40.82    -74.41   07981
# 24       07999             whippany         nj     40.82    -74.41   07999
# 25       08888           whitehouse         nj     40.62    -74.76   08888
# 26       08889   whitehouse station         nj     40.60    -74.76   08889
# 27       08889        white hse sta         nj     40.60    -74.76   08889
# 28       07095           woodbridge         nj     40.55    -74.28   07095
# 29       07481              wyckoff         nj     40.99    -74.16   07481
# ...        ...                  ...        ...       ...       ...     ...
# 55837    97299             portland         or     45.54   -122.61   97299
# 55838    97313                salem         or     45.03   -123.02   97313
# 55839    97372         lincoln city         or     45.01   -123.87   97372
# 55840    97372           rose lodge         or     45.01   -123.87   97372
# 55841    97425       cascade summit         or     43.47   -121.92   97425
# 55842    97425        crescent lake         or     43.47   -121.92   97425
# 55843    97427           culp creek         or     43.68   -122.79   97427
# 55844    97428               curtin         or     43.74   -123.18   97428
# 55845    97472              saginaw         or     43.79   -123.06   97472
# 55846    97472        cottage grove         or     43.79   -123.06   97472
# 55847    97482             thurston         or     44.05   -122.91   97482
# 55848    97482          springfield         or     44.05   -122.91   97482
# 55849    98054              redondo         wa     47.34   -122.32   98054
# 55850    98151  goodwill games 1990         wa     47.60   -122.33   98151
# 55851    98151              seattle         wa     47.60   -122.33   98151
# 55852    98171              seattle         wa     47.60   -122.33   98171
# 55853    98184              seattle         wa     47.60   -122.33   98184
# 55854    98442               tacoma         wa     47.14   -122.43   98442
# 55855    98450               tacoma         wa     47.25   -122.44   98450
# 55856    98455               tacoma         wa     47.25   -122.44   98455
# 55857    98460               tacoma         wa     47.25   -122.44   98460
# 55858    98477               tacoma         wa     47.25   -122.44   98477
# 55859    98492             lakewood         wa     47.12   -122.55   98492
# 55860    98492               tacoma         wa     47.12   -122.55   98492
# 55861    98667            vancouver         wa     45.63   -122.66   98667
# 55862    98929        goose prairie         wa     46.74   -121.14   98929
# 55863    98929               naches         wa     46.74   -121.14   98929
# 55864    99165              pullman         wa     46.73   -117.17   99165
# 55865    99779                  tok         ak     63.13   -142.53   99779
# 55866    97475          springfield         or     44.05   -123.02   97475
#
#                  City_non State_non    Lat_non     Lon_non
# 0                aibonito        pr  18.129420  -66.265410
# 1                  anasco        pr  18.288319  -67.136040
# 2                 angeles        pr  18.279531  -66.802170
# 3                 arecibo        pr  18.449732  -66.698790
# 4                adjuntas        pr  18.180103  -66.749470
# 5                castaner        pr  18.186739  -66.851740
# 6                castaner        pr  18.186739  -66.851740
# 7                  aguada        pr  18.363285  -67.180240
# 8               aguadilla        pr  18.448619  -67.134220
# 9               aguadilla        pr  18.448619  -67.134220
# 10              aguadilla        pr  18.498987  -67.136990
# 11              aguadilla        pr  18.498987  -67.136990
# 12              aguadilla        pr  18.465162  -67.141486
# 13           aguas buenas        pr  18.246205  -66.128270
# 14                aguirre        pr  17.970112  -66.222910
# 15               westwood        nj  40.999040  -74.032910
# 16               westwood        nj  40.999040  -74.032910
# 17               westwood        nj  40.999040  -74.032910
# 18               westwood        nj  40.999040  -74.032910
# 19         woodcliff lake        nj  41.025101  -74.059762
# 20         woodcliff lake        nj  41.025101  -74.059762
# 21         woodcliff lake        nj  41.025101  -74.059762
# 22                wharton        nj  40.913298  -74.582460
# 23               whippany        nj  40.821482  -74.426480
# 24               whippany        nj  40.867331  -74.578269
# 25             whitehouse        nj  40.619412  -74.740597
# 26     whitehouse station        nj  40.612851  -74.766820
# 27     whitehouse station        nj  40.612851  -74.766820
# 28             woodbridge        nj  40.557104  -74.283160
# 29                wyckoff        nj  40.998583  -74.167100
# ...                   ...       ...        ...         ...
# 55837            portland        or  45.580557 -122.374776
# 55838               salem        or  44.984941 -122.998756
# 55839          rose lodge        or  44.659979 -123.892016
# 55840          rose lodge        or  44.659979 -123.892016
# 55841       crescent lake        or  43.472276 -121.927680
# 55842       crescent lake        or  43.472276 -121.927680
# 55843          culp creek        or  43.685176 -122.798270
# 55844              curtin        or  43.745797 -123.181910
# 55845             saginaw        or  43.863845 -122.998790
# 55846             saginaw        or  43.863845 -122.998790
# 55847            thurston        or  43.863845 -122.998790
# 55848            thurston        or  43.863845 -122.998790
# 55849             redondo        wa  47.432251 -121.803388
# 55850             seattle        wa  47.432251 -121.803388
# 55851             seattle        wa  47.432251 -121.803388
# 55852             seattle        wa  47.432251 -121.803388
# 55853             seattle        wa  47.432251 -121.803388
# 55854              tacoma        wa  47.308061 -122.418495
# 55855              tacoma        wa  47.066193 -122.113223
# 55856              tacoma        wa  47.066193 -122.113223
# 55857              tacoma        wa  47.066193 -122.113223
# 55858              tacoma        wa  47.066193 -122.113223
# 55859            lakewood        wa  47.066193 -122.113223
# 55860            lakewood        wa  47.066193 -122.113223
# 55861           vancouver        wa  45.801586 -122.520347
# 55862       goose prairie        wa  46.915735 -121.241591
# 55863       goose prairie        wa  46.915735 -121.241591
# 55864             pullman        wa  46.838747 -117.644337
# 55865              tetlin        ak  63.135294 -142.532300
# 55866         springfield        or  44.050000 -123.020000
#
# [55867 rows x 10 columns]

# %%
# What are our state conflicts?
merged_non_free_zip[~merged_non_free_zip['Zip_free'].isin(merged_non_free_zip_state['Zip_free'])]
# Out:
#       Zip_free        City_free State_free  Lat_free  Lon_free Zip_non  \
# 60       10004         new york         ny     40.71    -73.99   10004
# 61       10004    bowling green         ny     40.71    -73.99   10004
# 12741    38041          henning         tn     35.67    -89.57   38041
# 12742    38041      fort pillow         tn     35.67    -89.57   38041
# 13161    38063           ripley         tn     35.74    -89.53   38063
# 13274    38079      tiptonville         tn     36.37    -89.47   38079
# 18012    52761        muscatine         ia     41.41    -91.07   52761
# 18629    56129        ellsworth         mn     43.52    -96.01   56129
# 18630    56027           elmore         mn     43.50    -94.08   56027
# 18890    55954            mabel         mn     43.52    -91.76   55954
# 21286    57638           lemmon         sd     45.93   -102.15   57638
# 21287    57638        shadehill         sd     45.93   -102.15   57638
# 21288    57638     thunder hawk         sd     45.93   -102.15   57638
# 22544    65733           protem         mo     36.52    -92.85   65733
# 22695    65761        theodosia         mo     36.57    -92.66   65761
# 22696    65761     dugginsville         mo     36.57    -92.66   65761
# 25319    83120          freedom         wy     42.98   -111.04   83120
# 25381    82063             jelm         wy     41.05   -106.00   82063
# 25382    82063          laramie         wy     41.05   -106.00   82063
# 25434    82082      pine bluffs         wy     41.18   -104.06   82082
# 25852    84536  monument valley         ut     37.08   -110.25   84536
# 25853    84536     monument vly         ut     37.08   -110.25   84536
# 27380    87328           navajo         nm     35.89   -109.03   87328
# 28003    89024         mesquite         nv     36.77   -113.99   89024
# 28106    89439            verdi         nv     39.51   -119.99   89439
# 28364    97910    jordan valley         or     42.96   -117.36   97910
# 28365    97910   south mountain         or     42.96   -117.36   97910
# 28366    97910        south mtn         or     42.96   -117.36   97910
# 28450    97635   new pine creek         or     41.96   -120.20   97635
# 28451    97635     new pine crk         or     41.96   -120.20   97635
# 28460    97913            nyssa         or     43.73   -117.15   97913
# 29067    99128       farmington         wa     47.11   -117.07   99128
# 29687    99362      walla walla         wa     46.11   -118.30   99362
# 34450    31788         moultrie         ga     31.12    -83.68   31788
# 38082    38852             iuka         ms     34.80    -88.19   38852
# 42396    79051          kerrick         tx     36.45   -102.24   79051
# 43488    79922          el paso         tx     31.84   -106.43   79922
# 55116    96373              fpo         ap       NaN       NaN   96373
#
#                   City_non State_non    Lat_non     Lon_non
# 60                new york        nj  40.699226  -74.041180
# 61                new york        nj  40.699226  -74.041180
# 12741              henning        ar  35.629555  -89.869450
# 12742              henning        ar  35.629555  -89.869450
# 13161               ripley        ar  35.637993  -89.868590
# 13274          tiptonville        ky  36.513386  -89.504720
# 18012            muscatine        il  41.413372  -91.006120
# 18629            ellsworth        ia  43.495384  -95.906910
# 18630               elmore        ia  43.482104  -94.098370
# 18890                mabel        ia  43.498082  -91.894290
# 21286               lemmon        nd  46.034096 -102.114760
# 21287               lemmon        nd  46.034096 -102.114760
# 21288               lemmon        nd  46.034096 -102.114760
# 22544               protem        ar  36.483329  -92.814490
# 22695            theodosia        ar  36.489216  -92.693010
# 22696            theodosia        ar  36.489216  -92.693010
# 25319              freedom        id  43.001889 -111.093200
# 25381                 jelm        co  40.932966 -105.877050
# 25382                 jelm        co  40.932966 -105.877050
# 25434          pine bluffs        ne  41.181106 -104.000780
# 25852      monument valley        az  36.990184 -110.212300
# 25853      monument valley        az  36.990184 -110.212300
# 27380               navajo        az  35.923348 -109.082960
# 28003             mesquite        az  36.789432 -114.010420
# 28106                verdi        ca  39.523693 -120.030120
# 28364        jordan valley        id  42.749306 -116.886300
# 28365        jordan valley        id  42.749306 -116.886300
# 28366        jordan valley        id  42.749306 -116.886300
# 28450       new pine creek        ca  41.924974 -120.289890
# 28451       new pine creek        ca  41.924974 -120.289890
# 28460                nyssa        id  43.909576 -116.971030
# 29067           farmington        id  47.091551 -116.991580
# 29687          walla walla        or  45.986775 -118.079190
# 34450          white house        tn  31.138011  -83.716729
# 38082                 iuka        al  34.803864  -88.102050
# 42396              kerrick        ok  36.531076 -102.331980
# 43488              el paso        nm  31.789109 -106.542910
# 55116  hawaiian ocean view        hi  19.112099 -155.798594

# %%
# Merge all the things
merged_all = pd.merge(merged_non_free_zip, merged_zip,
                      how='left',
                      left_on=['Zip_free', 'City_free', 'State_free'], 
                      right_on=['Zip_free', 'City_free', 'State_free'])
merged_all
# Out:
#       Zip_free            City_free State_free  Lat_free_x  Lon_free_x  \
# 0        00705             aibonito         pr       18.14      -66.26
# 1        00610               anasco         pr       18.28      -67.14
# 2        00611              angeles         pr       18.28      -66.79
# 3        00612              arecibo         pr       18.45      -66.73
# 4        00601             adjuntas         pr       18.16      -66.72
# 5        00631             castaner         pr       18.19      -66.82
# 6        00631             adjuntas         pr       18.19      -66.82
# 7        00602               aguada         pr       18.38      -67.18
# 8        00603            aguadilla         pr       18.43      -67.15
# 9        00603                ramey         pr       18.43      -67.15
# 10       00604            aguadilla         pr       18.43      -67.15
# 11       00604                ramey         pr       18.43      -67.15
# 12       00605            aguadilla         pr       18.43      -67.15
# 13       00703         aguas buenas         pr       18.25      -66.10
# 14       00704              aguirre         pr       17.96      -66.22
# 15       07675             westwood         nj       40.98      -74.03
# 16       07675           old tappan         nj       40.98      -74.03
# 17       07675           river vale         nj       40.98      -74.03
# 18       07675            rivervale         nj       40.98      -74.03
# 19       07677       woodcliff lake         nj       41.02      -74.05
# 20       07677             westwood         nj       41.02      -74.05
# 21       07677         woodcliff lk         nj       41.02      -74.05
# 22       07885              wharton         nj       40.89      -74.58
# 23       07981             whippany         nj       40.82      -74.41
# 24       07999             whippany         nj       40.82      -74.41
# 25       08888           whitehouse         nj       40.62      -74.76
# 26       08889   whitehouse station         nj       40.60      -74.76
# 27       08889        white hse sta         nj       40.60      -74.76
# 28       07095           woodbridge         nj       40.55      -74.28
# 29       07481              wyckoff         nj       40.99      -74.16
# ...        ...                  ...        ...         ...         ...
# 55953    97299             portland         or       45.54     -122.61
# 55954    97313                salem         or       45.03     -123.02
# 55955    97372         lincoln city         or       45.01     -123.87
# 55956    97372           rose lodge         or       45.01     -123.87
# 55957    97425       cascade summit         or       43.47     -121.92
# 55958    97425        crescent lake         or       43.47     -121.92
# 55959    97427           culp creek         or       43.68     -122.79
# 55960    97428               curtin         or       43.74     -123.18
# 55961    97472              saginaw         or       43.79     -123.06
# 55962    97472        cottage grove         or       43.79     -123.06
# 55963    97482             thurston         or       44.05     -122.91
# 55964    97482          springfield         or       44.05     -122.91
# 55965    98054              redondo         wa       47.34     -122.32
# 55966    98151  goodwill games 1990         wa       47.60     -122.33
# 55967    98151              seattle         wa       47.60     -122.33
# 55968    98171              seattle         wa       47.60     -122.33
# 55969    98184              seattle         wa       47.60     -122.33
# 55970    98442               tacoma         wa       47.14     -122.43
# 55971    98450               tacoma         wa       47.25     -122.44
# 55972    98455               tacoma         wa       47.25     -122.44
# 55973    98460               tacoma         wa       47.25     -122.44
# 55974    98477               tacoma         wa       47.25     -122.44
# 55975    98492             lakewood         wa       47.12     -122.55
# 55976    98492               tacoma         wa       47.12     -122.55
# 55977    98667            vancouver         wa       45.63     -122.66
# 55978    98929        goose prairie         wa       46.74     -121.14
# 55979    98929               naches         wa       46.74     -121.14
# 55980    99165              pullman         wa       46.73     -117.17
# 55981    99779                  tok         ak       63.13     -142.53
# 55982    97475          springfield         or       44.05     -123.02
#
#       Zip_non            City_non State_non    Lat_non     Lon_non  \
# 0       00705            aibonito        pr  18.129420  -66.265410
# 1       00610              anasco        pr  18.288319  -67.136040
# 2       00611             angeles        pr  18.279531  -66.802170
# 3       00612             arecibo        pr  18.449732  -66.698790
# 4       00601            adjuntas        pr  18.180103  -66.749470
# 5       00631            castaner        pr  18.186739  -66.851740
# 6       00631            castaner        pr  18.186739  -66.851740
# 7       00602              aguada        pr  18.363285  -67.180240
# 8       00603           aguadilla        pr  18.448619  -67.134220
# 9       00603           aguadilla        pr  18.448619  -67.134220
# 10      00604           aguadilla        pr  18.498987  -67.136990
# 11      00604           aguadilla        pr  18.498987  -67.136990
# 12      00605           aguadilla        pr  18.465162  -67.141486
# 13      00703        aguas buenas        pr  18.246205  -66.128270
# 14      00704             aguirre        pr  17.970112  -66.222910
# 15      07675            westwood        nj  40.999040  -74.032910
# 16      07675            westwood        nj  40.999040  -74.032910
# 17      07675            westwood        nj  40.999040  -74.032910
# 18      07675            westwood        nj  40.999040  -74.032910
# 19      07677      woodcliff lake        nj  41.025101  -74.059762
# 20      07677      woodcliff lake        nj  41.025101  -74.059762
# 21      07677      woodcliff lake        nj  41.025101  -74.059762
# 22      07885             wharton        nj  40.913298  -74.582460
# 23      07981            whippany        nj  40.821482  -74.426480
# 24      07999            whippany        nj  40.867331  -74.578269
# 25      08888          whitehouse        nj  40.619412  -74.740597
# 26      08889  whitehouse station        nj  40.612851  -74.766820
# 27      08889  whitehouse station        nj  40.612851  -74.766820
# 28      07095          woodbridge        nj  40.557104  -74.283160
# 29      07481             wyckoff        nj  40.998583  -74.167100
# ...       ...                 ...       ...        ...         ...
# 55953   97299            portland        or  45.580557 -122.374776
# 55954   97313               salem        or  44.984941 -122.998756
# 55955   97372          rose lodge        or  44.659979 -123.892016
# 55956   97372          rose lodge        or  44.659979 -123.892016
# 55957   97425       crescent lake        or  43.472276 -121.927680
# 55958   97425       crescent lake        or  43.472276 -121.927680
# 55959   97427          culp creek        or  43.685176 -122.798270
# 55960   97428              curtin        or  43.745797 -123.181910
# 55961   97472             saginaw        or  43.863845 -122.998790
# 55962   97472             saginaw        or  43.863845 -122.998790
# 55963   97482            thurston        or  43.863845 -122.998790
# 55964   97482            thurston        or  43.863845 -122.998790
# 55965   98054             redondo        wa  47.432251 -121.803388
# 55966   98151             seattle        wa  47.432251 -121.803388
# 55967   98151             seattle        wa  47.432251 -121.803388
# 55968   98171             seattle        wa  47.432251 -121.803388
# 55969   98184             seattle        wa  47.432251 -121.803388
# 55970   98442              tacoma        wa  47.308061 -122.418495
# 55971   98450              tacoma        wa  47.066193 -122.113223
# 55972   98455              tacoma        wa  47.066193 -122.113223
# 55973   98460              tacoma        wa  47.066193 -122.113223
# 55974   98477              tacoma        wa  47.066193 -122.113223
# 55975   98492            lakewood        wa  47.066193 -122.113223
# 55976   98492            lakewood        wa  47.066193 -122.113223
# 55977   98667           vancouver        wa  45.801586 -122.520347
# 55978   98929       goose prairie        wa  46.915735 -121.241591
# 55979   98929       goose prairie        wa  46.915735 -121.241591
# 55980   99165             pullman        wa  46.838747 -117.644337
# 55981   99779              tetlin        ak  63.135294 -142.532300
# 55982   97475         springfield        or  44.050000 -123.020000
#
#        Lat_free_y  Lon_free_y Zip_geo            City_geo State_geo  Lat_geo  \
# 0             NaN         NaN     NaN                 NaN       NaN      NaN
# 1             NaN         NaN     NaN                 NaN       NaN      NaN
# 2             NaN         NaN     NaN                 NaN       NaN      NaN
# 3             NaN         NaN     NaN                 NaN       NaN      NaN
# 4             NaN         NaN     NaN                 NaN       NaN      NaN
# 5             NaN         NaN     NaN                 NaN       NaN      NaN
# 6             NaN         NaN     NaN                 NaN       NaN      NaN
# 7             NaN         NaN     NaN                 NaN       NaN      NaN
# 8             NaN         NaN     NaN                 NaN       NaN      NaN
# 9             NaN         NaN     NaN                 NaN       NaN      NaN
# 10            NaN         NaN     NaN                 NaN       NaN      NaN
# 11            NaN         NaN     NaN                 NaN       NaN      NaN
# 12            NaN         NaN     NaN                 NaN       NaN      NaN
# 13            NaN         NaN     NaN                 NaN       NaN      NaN
# 14            NaN         NaN     NaN                 NaN       NaN      NaN
# 15          40.98      -74.03   07675            westwood        nj  41.0092
# 16          40.98      -74.03   07675            westwood        nj  41.0092
# 17          40.98      -74.03   07675            westwood        nj  41.0092
# 18          40.98      -74.03   07675            westwood        nj  41.0092
# 19          41.02      -74.05   07677      woodcliff lake        nj  41.0234
# 20          41.02      -74.05   07677      woodcliff lake        nj  41.0234
# 21          41.02      -74.05   07677      woodcliff lake        nj  41.0234
# 22          40.89      -74.58   07885             wharton        nj  40.9139
# 23          40.82      -74.41   07981            whippany        nj  40.8219
# 24          40.82      -74.41   07999            whippany        nj  40.8673
# 25          40.62      -74.76   08888          whitehouse        nj  40.6194
# 26          40.60      -74.76   08889  whitehouse station        nj  40.6156
# 27          40.60      -74.76   08889  whitehouse station        nj  40.6156
# 28          40.55      -74.28   07095          woodbridge        nj  40.5560
# 29          40.99      -74.16   07481             wyckoff        nj  40.9978
# ...           ...         ...     ...                 ...       ...      ...
# 55953       45.54     -122.61   97299            portland        or  45.5806
# 55954       45.03     -123.02   97313               salem        or  44.9849
# 55955       45.01     -123.87   97372          rose lodge        or  44.6600
# 55956       45.01     -123.87   97372          rose lodge        or  44.6600
# 55957       43.47     -121.92   97425       crescent lake        or  43.5180
# 55958       43.47     -121.92   97425       crescent lake        or  43.5180
# 55959       43.68     -122.79   97427          culp creek        or  43.6579
# 55960       43.74     -123.18   97428              curtin        or  43.7476
# 55961       43.79     -123.06   97472             saginaw        or  43.8638
# 55962       43.79     -123.06   97472             saginaw        or  43.8638
# 55963       44.05     -122.91   97482            thurston        or  43.8638
# 55964       44.05     -122.91   97482            thurston        or  43.8638
# 55965       47.34     -122.32   98054             redondo        wa  47.4323
# 55966       47.60     -122.33   98151             seattle        wa  47.4323
# 55967       47.60     -122.33   98151             seattle        wa  47.4323
# 55968       47.60     -122.33   98171             seattle        wa  47.4323
# 55969       47.60     -122.33   98184             seattle        wa  47.4323
# 55970       47.14     -122.43   98442              tacoma        wa  47.3081
# 55971       47.25     -122.44   98450              tacoma        wa  47.0662
# 55972       47.25     -122.44   98455              tacoma        wa  47.0662
# 55973       47.25     -122.44   98460              tacoma        wa  47.0662
# 55974       47.25     -122.44   98477              tacoma        wa  47.0662
# 55975       47.12     -122.55   98492            lakewood        wa  47.0662
# 55976       47.12     -122.55   98492            lakewood        wa  47.0662
# 55977       45.63     -122.66   98667           vancouver        wa  45.8016
# 55978       46.74     -121.14   98929       goose prairie        wa  46.9157
# 55979       46.74     -121.14   98929       goose prairie        wa  46.9157
# 55980       46.73     -117.17   99165             pullman        wa  46.8387
# 55981       63.13     -142.53   99779              tetlin        ak  63.8706
# 55982       44.05     -123.02   97475         springfield        or  44.0437
#
#         Lon_geo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15     -74.0041
# 16     -74.0041
# 17     -74.0041
# 18     -74.0041
# 19     -74.0603
# 20     -74.0603
# 21     -74.0603
# 22     -74.5863
# 23     -74.4200
# 24     -74.5783
# 25     -74.7406
# 26     -74.7724
# 27     -74.7724
# 28     -74.2845
# 29     -74.1660
# ...         ...
# 55953 -122.3748
# 55954 -122.9988
# 55955 -123.8920
# 55956 -123.8920
# 55957 -121.9495
# 55958 -121.9495
# 55959 -122.7871
# 55960 -123.1962
# 55961 -122.9988
# 55962 -122.9988
# 55963 -122.9988
# 55964 -122.9988
# 55965 -121.8034
# 55966 -121.8034
# 55967 -121.8034
# 55968 -121.8034
# 55969 -121.8034
# 55970 -122.4185
# 55971 -122.1132
# 55972 -122.1132
# 55973 -122.1132
# 55974 -122.1132
# 55975 -122.1132
# 55976 -122.1132
# 55977 -122.5203
# 55978 -121.2416
# 55979 -121.2416
# 55980 -117.6443
# 55981 -144.0026
# 55982 -122.9748
#
# [55983 rows x 17 columns]

# %%
master_zips = merged_all[['Zip_free', 'Zip_geo', 'Zip_non',
                          'City_free', 'City_geo', 'City_non',
                          'State_free', 'State_geo', 'State_non',
                          'Lat_free_x', 'Lat_geo', 'Lat_non',
                          'Lon_free_x', 'Lon_geo', 'Lon_non']]
master_zips = master_zips.rename(columns={'Lon_free_x': 'Lon_free', 
                                          'Lat_free_x': 'Lat_free'})

# %%
# Let's check the max Haversine distance between points
def check_haversine(row):
    """
    Great circle distance between our Lat/Lon points (dec degrees)
    """
    # Convert to Radians
    rad_lat_1, rad_lon_1 = map(radians, [row['Lat_free'], row['Lon_free']])
    rad_lat_2, rad_lon_2 = map(radians, [row['Lat_geo'], row['Lon_geo']])
    rad_lat_3, rad_lon_3 = map(radians, [row['Lat_non'], row['Lon_non']])
    
    # 1 vs 2, 1 vs 3, 2 vs 3
    pairs = [(rad_lat_1, rad_lon_1, rad_lat_2, rad_lon_2),
             (rad_lat_1, rad_lon_1, rad_lat_3, rad_lon_3),
             (rad_lat_2, rad_lon_2, rad_lat_3, rad_lon_3)]
    
    # Only get pairs that don't have nan vals
    filtered_pairs = filter(lambda x: not any(map(np.isnan, x)), pairs)

    def get_dist(lat_1, lon_1, lat_2, lon_2):
        under_root = (sin((lat_2 - lat_1)/2)**2 + 
                      cos(lat_1) * cos(lat_2) * sin((lon_2 - lon_1)/2)**2)
        # 6367 = Earth radius in kilometers
        return 6367 * 2 * asin(sqrt(under_root)) 
                      
    row['Max_Haversine_Dist'] = max([get_dist(*pair) for pair in filtered_pairs])
    row['Min_Haversine_Dist'] = min([get_dist(*pair) for pair in filtered_pairs])
    return row

master_zips = master_zips.apply(check_haversine, axis=1)

# %%
master_zips.sort(['Min_Haversine_Dist', 'Max_Haversine_Dist'], ascending=False)
# Out:
#       Zip_free Zip_geo Zip_non              City_free            City_geo  \
# 141      00785     NaN   00785                guayama                 NaN
# 338      00765     NaN   00765                vieques                 NaN
# 29824    99726   99726   99726          bettles field       bettles field
# 29994    99754   99754   99754                koyukuk             koyukuk
# 29874    99666   99666   99666             nunam iqua       sheldon point
# 29838    99566   99566   99566                chitina             chitina
# 27538    87018   87018   87018              counselor           counselor
# 30050    99653   99653   99653          port alsworth       port alsworth
# 31165    92328   92328   92328           death valley        death valley
# 29797    99557   99557   99557                  aniak               aniak
# 29798    99557   99557   99557            chuathbaluk               aniak
# 29799    99557   99557   99557            stony river               aniak
# 29866    99738   99738   99738                  eagle               eagle
# 30100    99780   99780   99780                    tok                 tok
# 30101    99780   99780   99780          mentasta lake                 tok
# 30109    99686   99686   99686                 valdez              valdez
# 29992    99752   99752   99752               kotzebue            kotzebue
# 30008    99756   99756   99756     manley hot springs  manley hot springs
# 30009    99756   99756   99756            manley spgs  manley hot springs
# 26979    85266   85266   85266             scottsdale          scottsdale
# 30006    99691   99691   99691                nikolai             nikolai
# 30007    99691   99691   99691               mc grath             nikolai
# 55745    85240     NaN   85240            queen creek                 NaN
# 29811    99724   99724   99724                 beaver              beaver
# 29832    99732   99732   99732                chicken             chicken
# 29973    99950   99950   99950              ketchikan           ketchikan
# 29974    99950   99950   99950               edna bay           ketchikan
# 29975    99950   99950   99950                 kasaan           ketchikan
# 27696    88351   88351   88351                 tinnie              tinnie
# 27697    88351   88351   88351                arabela              tinnie
# ...        ...     ...     ...                    ...                 ...
# 51057    20598     NaN   20598            springfield                 NaN
# 51058    20598     NaN   20598               sterling                 NaN
# 54972    31169     NaN   31169         peachtree city                 NaN
# 54973    31169     NaN   31169          peachtree cty                 NaN
# 55030    31144     NaN   31144               kennesaw                 NaN
# 55235    56902     NaN   56902  parcel return service                 NaN
# 55236    56902     NaN   56902                    prs                 NaN
# 55237    56904     NaN   56904  parcel return service                 NaN
# 55238    56904     NaN   56904                    prs                 NaN
# 55247    56945     NaN   56945  parcel return service                 NaN
# 55248    56945     NaN   56945                    prs                 NaN
# 55249    56950     NaN   56950  parcel return service                 NaN
# 55250    56950     NaN   56950                    prs                 NaN
# 55251    56965     NaN   56965  parcel return service                 NaN
# 55354    15273     NaN   15273             pittsburgh                 NaN
# 55356    15288     NaN   15288               carnegie                 NaN
# 55357    15288     NaN   15288             pittsburgh                 NaN
# 55383    21261     NaN   21261                  essex                 NaN
# 55384    21261     NaN   21261              baltimore                 NaN
# 55525    45400     NaN   45400                 dayton                 NaN
# 55613    70500     NaN   70500              lafayette                 NaN
# 55633    73451     NaN   73451                ardmore                 NaN
# 55634    73454     NaN   73454                ardmore                 NaN
# 55712    85096     NaN   85096                phoenix                 NaN
# 55742    85238     NaN   85238               maricopa                 NaN
# 55750    85243     NaN   85243            queen creek                 NaN
# 55884    85293     NaN   85293            casa grande                 NaN
# 55885    85294     NaN   85294            casa grande                 NaN
# 55891    86555     NaN   86555                douglas                 NaN
# 55892    87165     NaN   87165            albuquerque                 NaN
#
#                     City_non State_free State_geo State_non  Lat_free  \
# 141                  guayama         pr       NaN        pr     17.97
# 338                  vieques         pr       NaN        pr     18.42
# 29824          bettles field         ak        ak        ak     67.24
# 29994                koyukuk         ak        ak        ak     65.04
# 29874          sheldon point         ak        ak        ak     62.09
# 29838                chitina         ak        ak        ak     61.45
# 27538              counselor         nm        nm        nm     36.13
# 30050          port alsworth         ak        ak        ak     60.46
# 31165           death valley         ca        ca        ca     36.29
# 29797                  aniak         ak        ak        ak     61.20
# 29798                  aniak         ak        ak        ak     61.20
# 29799                  aniak         ak        ak        ak     61.20
# 29866                  eagle         ak        ak        ak     64.43
# 30100                    tok         ak        ak        ak     63.66
# 30101                    tok         ak        ak        ak     63.66
# 30109                 valdez         ak        ak        ak     61.40
# 29992               kotzebue         ak        ak        ak     67.24
# 30008     manley hot springs         ak        ak        ak     64.65
# 30009     manley hot springs         ak        ak        ak     64.65
# 26979             scottsdale         az        az        az     33.48
# 30006                nikolai         ak        ak        ak     62.87
# 30007                nikolai         ak        ak        ak     62.87
# 55745               chandler         az       NaN        az     33.22
# 29811                 beaver         ak        ak        ak     66.32
# 29832                chicken         ak        ak        ak     63.86
# 29973              ketchikan         ak        ak        ak     55.34
# 29974              ketchikan         ak        ak        ak     55.34
# 29975              ketchikan         ak        ak        ak     55.34
# 27696                 tinnie         nm        nm        nm     33.27
# 27697                 tinnie         nm        nm        nm     33.27
# ...                      ...        ...       ...       ...       ...
# 51057                    dhs         va       NaN        va     38.86
# 51058                    dhs         va       NaN        va     38.86
# 54972         peachtree city         ga       NaN        ga     33.38
# 54973         peachtree city         ga       NaN        ga     33.38
# 55030               kennesaw         ga       NaN        ga     34.02
# 55235  parcel return service         dc       NaN        dc     38.89
# 55236  parcel return service         dc       NaN        dc     38.89
# 55237  parcel return service         dc       NaN        dc     38.89
# 55238  parcel return service         dc       NaN        dc     38.89
# 55247  parcel return service         dc       NaN        dc     38.89
# 55248  parcel return service         dc       NaN        dc     38.89
# 55249  parcel return service         dc       NaN        dc     38.89
# 55250  parcel return service         dc       NaN        dc     38.89
# 55251  parcel return service         dc       NaN        dc     38.89
# 55354             pittsburgh         pa       NaN        pa     40.37
# 55356             pittsburgh         pa       NaN        pa     40.44
# 55357             pittsburgh         pa       NaN        pa     40.44
# 55383              baltimore         md       NaN        md     39.30
# 55384              baltimore         md       NaN        md     39.30
# 55525                 dayton         oh       NaN        oh     39.76
# 55613              lafayette         la       NaN        la     30.22
# 55633                ardmore         ok       NaN        ok     34.17
# 55634                ardmore         ok       NaN        ok     34.17
# 55712                phoenix         az       NaN        az     33.44
# 55742               maricopa         az       NaN        az     33.00
# 55750            queen creek         az       NaN        az     33.15
# 55884            casa grande         az       NaN        az     32.85
# 55885            casa grande         az       NaN        az     32.92
# 55891                douglas         az       NaN        az     31.38
# 55892            albuquerque         nm       NaN        nm     35.08
#
#        Lat_geo    Lat_non  Lon_free   Lon_geo     Lon_non  Max_Haversine_Dist  \
# 141        NaN  18.018822    -66.11       NaN  -66.795603           72.663892
# 338        NaN  18.125664    -65.83       NaN  -65.456030           51.254825
# 29824  65.2264  66.917381   -152.27 -151.0251 -151.505080          230.591072
# 29994  65.2264  64.881745   -158.66 -151.0251 -157.704390          357.154565
# 29874  62.1172  62.495675   -165.18 -163.2376 -164.971880          101.031829
# 29838  61.4710  61.555701   -143.15 -144.9910 -144.142330           97.766304
# 27538  35.7174  36.203634   -106.93 -106.9358 -107.494410           73.784099
# 30050  58.2687  60.102331   -154.19 -156.6484 -154.557080          280.448546
# 31165  36.4672  35.945641   -116.45 -116.8937 -117.202960           77.671735
# 29797  60.3147  61.570981   -158.60 -163.1189 -158.880720          267.901140
# 29798  60.3147  61.570981   -158.60 -163.1189 -158.880720          267.901140
# 29799  60.3147  61.570981   -158.60 -163.1189 -158.880720          267.901140
# 29866  63.8706  64.778099   -141.22 -144.0026 -141.192570          168.721156
# 30100  63.8706  63.341767   -143.19 -144.0026 -142.937040           78.892039
# 30101  63.8706  63.341767   -143.19 -144.0026 -142.937040           78.892039
# 30109  61.1010  61.128176   -145.66 -146.9000 -146.235700           74.137544
# 29992  66.8653  66.897192   -161.19 -161.7808 -162.585440           71.423533
# 30008  65.2264  65.021337   -150.90 -151.0251 -150.503180           64.322604
# 30009  65.2264  65.021337   -150.90 -151.0251 -150.503180           64.322604
# 26979  33.7669  33.276539   -111.92 -111.9182 -112.187170           59.918394
# 30006  65.2264  62.999213   -153.87 -151.0251 -154.419570          297.193718
# 30007  65.2264  62.999213   -153.87 -151.0251 -154.419570          297.193718
# 55745      NaN  33.222982   -111.53       NaN -111.858805           30.568384
# 29811  66.9297  66.359719   -146.77 -149.1930 -147.397430          126.488238
# 29832  63.8706  64.070738   -142.12 -144.0026 -141.874890          106.109548
# 29973  55.5420  55.875767   -131.64 -131.4327 -131.466330           60.526881
# 29974  55.5420  55.875767   -131.64 -131.4327 -131.466330           60.526881
# 29975  55.5420  55.875767   -131.64 -131.4327 -131.466330           60.526881
# 27696  33.7397  33.480197   -105.13 -105.6294 -105.017550           69.754403
# 27697  33.7397  33.480197   -105.13 -105.6294 -105.017550           69.754403
# ...        ...        ...       ...       ...         ...                 ...
# 51057      NaN  38.860000    -77.05       NaN  -77.050000            0.000000
# 51058      NaN  38.860000    -77.05       NaN  -77.050000            0.000000
# 54972      NaN  33.380000    -84.79       NaN  -84.790000            0.000000
# 54973      NaN  33.380000    -84.79       NaN  -84.790000            0.000000
# 55030      NaN  34.020000    -84.61       NaN  -84.610000            0.000000
# 55235      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55236      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55237      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55238      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55247      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55248      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55249      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55250      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55251      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55354      NaN  40.370000    -79.90       NaN  -79.900000            0.000000
# 55356      NaN  40.440000    -79.94       NaN  -79.940000            0.000000
# 55357      NaN  40.440000    -79.94       NaN  -79.940000            0.000000
# 55383      NaN  39.300000    -76.45       NaN  -76.450000            0.000000
# 55384      NaN  39.300000    -76.45       NaN  -76.450000            0.000000
# 55525      NaN  39.760000    -84.19       NaN  -84.190000            0.000000
# 55613      NaN  30.220000    -92.01       NaN  -92.010000            0.000000
# 55633      NaN  34.170000    -97.14       NaN  -97.140000            0.000000
# 55634      NaN  34.170000    -97.14       NaN  -97.140000            0.000000
# 55712      NaN  33.440000   -112.09       NaN -112.090000            0.000000
# 55742      NaN  33.000000   -111.93       NaN -111.930000            0.000000
# 55750      NaN  33.150000   -111.54       NaN -111.540000            0.000000
# 55884      NaN  32.850000   -111.79       NaN -111.790000            0.000000
# 55885      NaN  32.920000   -111.61       NaN -111.610000            0.000000
# 55891      NaN  31.380000   -109.55       NaN -109.550000            0.000000
# 55892      NaN  35.080000   -106.64       NaN -106.640000            0.000000
#
#        Min_Haversine_Dist
# 141             72.663892
# 338             51.254825
# 29824           48.797534
# 29994           48.262018
# 29874           46.345352
# 29838           45.954722
# 27538           45.853192
# 30050           44.594529
# 31165           44.312650
# 29797           43.848750
# 29798           43.848750
# 29799           43.848750
# 29866           38.704623
# 30100           37.521916
# 30101           37.521916
# 30109           35.787140
# 29992           35.286193
# 30008           33.384155
# 30009           33.384155
# 26979           31.882230
# 30006           31.278202
# 30007           31.278202
# 55745           30.568384
# 29811           28.326535
# 29832           26.293306
# 29973           25.973753
# 29974           25.973753
# 29975           25.973753
# 27696           25.583165
# 27697           25.583165
# ...                   ...
# 51057            0.000000
# 51058            0.000000
# 54972            0.000000
# 54973            0.000000
# 55030            0.000000
# 55235            0.000000
# 55236            0.000000
# 55237            0.000000
# 55238            0.000000
# 55247            0.000000
# 55248            0.000000
# 55249            0.000000
# 55250            0.000000
# 55251            0.000000
# 55354            0.000000
# 55356            0.000000
# 55357            0.000000
# 55383            0.000000
# 55384            0.000000
# 55525            0.000000
# 55613            0.000000
# 55633            0.000000
# 55634            0.000000
# 55712            0.000000
# 55742            0.000000
# 55750            0.000000
# 55884            0.000000
# 55885            0.000000
# 55891            0.000000
# 55892            0.000000
#
# [55983 rows x 17 columns]

# %%
# Get Primary City and State based on agreement
def get_primary(r):
    cities = [r['City_free'], r['City_geo'], r['City_non']]
    states = [r['State_free'], r['State_geo'], r['State_non']]
    
    def get_most_common(lst):
        cet = set(lst)
        write_val = None
        if len(cet) == 1:
            # If they all agree, use that value
            write_val = cet.pop()
        elif len(cet) == 2:
            # If 2/3 agree, go with it
            write_val = max(cet, key=lst.count)
        else:
            # If None agree, good to know
            write_val = None
        return write_val
    
    r['Primary_City'] = get_most_common(cities)
    r['Primary_State'] = get_most_common(states)
    return r
master_zips = master_zips.apply(get_primary, axis=1)

# %%
master_zips[master_zips['Primary_City'].isin([None])]
# Out:
#       Zip_free Zip_geo Zip_non                 City_free         City_geo  \
# 6        00631     NaN   00631                  adjuntas              NaN
# 9        00603     NaN   00603                     ramey              NaN
# 11       00604     NaN   00604                     ramey              NaN
# 58       10002   10002   10002             knickerbocker    new york city
# 61       10004   10004   10004             bowling green    new york city
# 63       10005   10005   10005               wall street    new york city
# 65       10006   10006   10006                   trinity    new york city
# 72       10012   10012   10012                    prince    new york city
# 74       10013   10013   10013              canal street    new york city
# 75       10013   10013   10013                 chinatown    new york city
# 121      00735     NaN   00735             roosevelt rds              NaN
# 122      00735     NaN   00735           roosevelt roads              NaN
# 124      00742     NaN   00742                     ceiba              NaN
# 125      00742     NaN   00742             roosevelt rds              NaN
# 132      00780     NaN   00780                     ponce              NaN
# 172      00715     NaN   00715                     ponce              NaN
# 181      00716     NaN   00716                 mercedita              NaN
# 191      00741     NaN   00741                punta stgo              NaN
# 196      00721     NaN   00721                rio grande              NaN
# 205      00901     NaN   00901              old san juan              NaN
# 206      00901     NaN   00901            viejo san juan              NaN
# 207      00901     NaN   00901             viejo sn juan              NaN
# 209      00902     NaN   00902              old san juan              NaN
# 210      00902     NaN   00902            viejo san juan              NaN
# 211      00902     NaN   00902             viejo sn juan              NaN
# 213      00906     NaN   00906             pta de tierra              NaN
# 214      00906     NaN   00906          puerta de tierra              NaN
# 216      00907     NaN   00907                   condado              NaN
# 217      00907     NaN   00907                   miramar              NaN
# 218      00907     NaN   00907                  santurce              NaN
# ...        ...     ...     ...                       ...              ...
# 55236    56902     NaN   56902                       prs              NaN
# 55238    56904     NaN   56904                       prs              NaN
# 55240    56915   56915   56915                       prs       washington
# 55242    56920   56920   56920                       prs       washington
# 55244    56933   56933   56933                       prs       washington
# 55246    56944   56944   56944                       prs       washington
# 55248    56945     NaN   56945                       prs              NaN
# 55250    56950     NaN   56950                       prs              NaN
# 55253    56972   56972   56972                       prs       washington
# 55292    10048   10048   10048                 manhattan    new york city
# 55293    10048   10048   10048           world trade ctr    new york city
# 55294    10048   10048   10048                       nyc    new york city
# 55296    10072   10072   10072             philip morris    new york city
# 55300    10082   10082   10082            capitol cities    new york city
# 55356    15288     NaN   15288                  carnegie              NaN
# 55383    21261     NaN   21261                     essex              NaN
# 55717    85218   85218   85218              suprston mtn  apache junction
# 55718    85218   85218   85218          superstition mtn  apache junction
# 55719    85218   85218   85218               gold canyon  apache junction
# 55720    85218   85218   85218                apache jct  apache junction
# 55721    85218   85218   85218              queen valley  apache junction
# 55729    85222     NaN   85222               eleven mile              NaN
# 55730    85222     NaN   85222        eleven mile corner              NaN
# 55738    85231     NaN   85231                    toltec              NaN
# 55744    85239     NaN   85239                    mobile              NaN
# 55745    85240     NaN   85240               queen creek              NaN
# 55747    85242     NaN   85242              chandler hts              NaN
# 55749    85242     NaN   85242          chandler heights              NaN
# 55857    60597     NaN   60597  rates and classification              NaN
# 55882    85292     NaN   85292               dudleyville              NaN
#
#                     City_non State_free State_geo State_non  Lat_free  \
# 6                   castaner         pr       NaN        pr     18.19
# 9                  aguadilla         pr       NaN        pr     18.43
# 11                 aguadilla         pr       NaN        pr     18.43
# 58                  new york         ny        ny        ny     40.71
# 61                  new york         ny        ny        nj     40.71
# 63                  new york         ny        ny        ny     40.71
# 65                  new york         ny        ny        ny     40.71
# 72                  new york         ny        ny        ny     40.71
# 74                  new york         ny        ny        ny     40.71
# 75                  new york         ny        ny        ny     40.71
# 121                    ceiba         pr       NaN        pr     18.26
# 122                    ceiba         pr       NaN        pr     18.26
# 124          roosevelt roads         pr       NaN        pr     18.27
# 125          roosevelt roads         pr       NaN        pr     18.27
# 132              coto laurel         pr       NaN        pr     18.09
# 172                mercedita         pr       NaN        pr     18.00
# 181                    ponce         pr       NaN        pr     17.98
# 191           punta santiago         pr       NaN        pr     18.15
# 196                   palmer         pr       NaN        pr     18.37
# 205                 san juan         pr       NaN        pr     18.40
# 206                 san juan         pr       NaN        pr     18.40
# 207                 san juan         pr       NaN        pr     18.40
# 209                 san juan         pr       NaN        pr     18.40
# 210                 san juan         pr       NaN        pr     18.40
# 211                 san juan         pr       NaN        pr     18.40
# 213                 san juan         pr       NaN        pr     18.40
# 214                 san juan         pr       NaN        pr     18.40
# 216                 san juan         pr       NaN        pr     18.40
# 217                 san juan         pr       NaN        pr     18.40
# 218                 san juan         pr       NaN        pr     18.40
# ...                      ...        ...       ...       ...       ...
# 55236  parcel return service         dc       NaN        dc     38.89
# 55238  parcel return service         dc       NaN        dc     38.89
# 55240  parcel return service         dc        dc        dc     38.92
# 55242  parcel return service         dc        dc        dc     38.90
# 55244  parcel return service         dc        dc        dc     38.86
# 55246  parcel return service         dc        dc        dc     38.86
# 55248  parcel return service         dc       NaN        dc     38.89
# 55250  parcel return service         dc       NaN        dc     38.89
# 55253  parcel return service         dc        dc        dc     38.86
# 55292               new york         ny        ny        ny     40.71
# 55293               new york         ny        ny        ny     40.71
# 55294               new york         ny        ny        ny     40.71
# 55296               new york         ny        ny        ny     40.75
# 55300               new york         ny        ny        ny     40.77
# 55356             pittsburgh         pa       NaN        pa     40.44
# 55383              baltimore         md       NaN        md     39.30
# 55717              gold camp         az        az        az     33.35
# 55718              gold camp         az        az        az     33.35
# 55719              gold camp         az        az        az     33.35
# 55720              gold camp         az        az        az     33.35
# 55721              gold camp         az        az        az     33.35
# 55729            casa grande         az       NaN        az     32.87
# 55730            casa grande         az       NaN        az     32.87
# 55738                   eloy         az       NaN        az     32.71
# 55744               maricopa         az       NaN        az     33.02
# 55745               chandler         az       NaN        az     33.22
# 55747            queen creek         az       NaN        az     33.22
# 55749            queen creek         az       NaN        az     33.22
# 55857             fox valley         il       NaN        il     41.76
# 55882              winkelman         az       NaN        az     32.94
#
#        Lat_geo    Lat_non  Lon_free   Lon_geo     Lon_non  Max_Haversine_Dist  \
# 6          NaN  18.186739    -66.82       NaN  -66.851740            3.370418
# 9          NaN  18.448619    -67.15       NaN  -67.134220            2.654852
# 11         NaN  18.498987    -67.15       NaN  -67.136990            7.787871
# 58     40.7152  40.717040    -73.99  -73.9877  -73.987000            0.822119
# 61     40.6964  40.699226    -73.99  -74.0253  -74.041180            4.474649
# 63     40.7056  40.706019    -73.99  -74.0083  -74.008580            1.626455
# 65     40.7085  40.707904    -73.99  -74.0135  -74.013420            1.986553
# 72     40.7255  40.725960    -73.99  -73.9983  -73.998340            1.907596
# 74     40.7185  40.720666    -73.99  -74.0025  -74.005260            1.748400
# 75     40.7185  40.720666    -73.99  -74.0025  -74.005260            1.748400
# 121        NaN  18.258444    -65.64       NaN  -65.659870            2.103995
# 122        NaN  18.258444    -65.64       NaN  -65.659870            2.103995
# 124        NaN  18.264872    -65.65       NaN  -65.594769            5.856034
# 125        NaN  18.264872    -65.65       NaN  -65.594769            5.856034
# 132        NaN  18.068538    -66.57       NaN  -66.559390            2.635208
# 172        NaN  18.003492    -66.56       NaN  -66.558680            0.412363
# 181        NaN  17.999066    -66.60       NaN  -66.599650            2.119034
# 191        NaN  18.160755    -65.76       NaN  -65.757650            1.220639
# 196        NaN  18.364161    -65.77       NaN  -65.778288            1.088598
# 205        NaN  18.465426    -66.06       NaN  -66.107860            8.849730
# 206        NaN  18.465426    -66.06       NaN  -66.107860            8.849730
# 207        NaN  18.465426    -66.06       NaN  -66.107860            8.849730
# 209        NaN  18.410462    -66.06       NaN  -66.060533            1.163949
# 210        NaN  18.410462    -66.06       NaN  -66.060533            1.163949
# 211        NaN  18.410462    -66.06       NaN  -66.060533            1.163949
# 213        NaN  18.464540    -66.06       NaN  -66.100790            8.362414
# 214        NaN  18.464540    -66.06       NaN  -66.100790            8.362414
# 216        NaN  18.451131    -66.06       NaN  -66.077980            5.989802
# 217        NaN  18.451131    -66.06       NaN  -66.077980            5.989802
# 218        NaN  18.451131    -66.06       NaN  -66.077980            5.989802
# ...        ...        ...       ...       ...         ...                 ...
# 55236      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55238      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55240  38.8952  38.920000    -76.99  -77.0365  -76.990000            4.874775
# 55242  38.8952  38.900000    -77.04  -77.0365  -77.040000            0.613305
# 55244  38.8952  38.860000    -76.99  -77.0365  -76.990000            5.610948
# 55246  38.8952  38.860000    -76.99  -77.0365  -76.990000            5.610948
# 55248      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55250      NaN  38.890000    -77.03       NaN  -77.030000            0.000000
# 55253  38.9164  38.860000    -76.99  -76.9948  -76.990000            6.281193
# 55292  40.7125  40.712086    -74.01  -74.0133  -74.012270            0.392998
# 55293  40.7125  40.712086    -74.01  -74.0133  -74.012270            0.392998
# 55294  40.7125  40.712086    -74.01  -74.0133  -74.012270            0.392998
# 55296  40.7808  40.780751    -73.99  -73.9772  -73.977182            3.588197
# 55300  40.7808  40.780751    -73.98  -73.9772  -73.977182            1.223063
# 55356      NaN  40.440000    -79.94       NaN  -79.940000            0.000000
# 55383      NaN  39.300000    -76.45       NaN  -76.450000            0.000000
# 55717  33.3656  33.349996   -111.41 -111.4487 -111.418233            3.988478
# 55718  33.3656  33.349996   -111.41 -111.4487 -111.418233            3.988478
# 55719  33.3656  33.349996   -111.41 -111.4487 -111.418233            3.988478
# 55720  33.3656  33.349996   -111.41 -111.4487 -111.418233            3.988478
# 55721  33.3656  33.349996   -111.41 -111.4487 -111.418233            3.988478
# 55729      NaN  32.878138   -111.73       NaN -111.734990            1.017210
# 55730      NaN  32.878138   -111.73       NaN -111.734990            1.017210
# 55738      NaN  32.712323   -111.57       NaN -111.576730            0.680155
# 55744      NaN  32.989261   -112.04       NaN -112.115050            7.783673
# 55745      NaN  33.222982   -111.53       NaN -111.858805           30.568384
# 55747      NaN  33.227266   -111.61       NaN -111.610870            0.811475
# 55749      NaN  33.227266   -111.61       NaN -111.610870            0.811475
# 55857      NaN  41.839679    -88.22       NaN  -88.088716           14.024297
# 55882      NaN  32.945838   -110.72       NaN -110.721980            0.674515
#
#        Min_Haversine_Dist Primary_City Primary_State
# 6                3.370418         None            pr
# 9                2.654852         None            pr
# 11               7.787871         None            pr
# 58               0.212801         None            ny
# 61               1.374261         None            ny
# 63               0.052195         None            ny
# 65               0.066573         None            ny
# 72               0.051228         None            ny
# 74               0.334620         None            ny
# 75               0.334620         None            ny
# 121              2.103995         None            pr
# 122              2.103995         None            pr
# 124              5.856034         None            pr
# 125              5.856034         None            pr
# 132              2.635208         None            pr
# 172              0.412363         None            pr
# 181              2.119034         None            pr
# 191              1.220639         None            pr
# 196              1.088598         None            pr
# 205              8.849730         None            pr
# 206              8.849730         None            pr
# 207              8.849730         None            pr
# 209              1.163949         None            pr
# 210              1.163949         None            pr
# 211              1.163949         None            pr
# 213              8.362414         None            pr
# 214              8.362414         None            pr
# 216              5.989802         None            pr
# 217              5.989802         None            pr
# 218              5.989802         None            pr
# ...                   ...          ...           ...
# 55236            0.000000         None            dc
# 55238            0.000000         None            dc
# 55240            0.000000         None            dc
# 55242            0.000000         None            dc
# 55244            0.000000         None            dc
# 55246            0.000000         None            dc
# 55248            0.000000         None            dc
# 55250            0.000000         None            dc
# 55253            0.000000         None            dc
# 55292            0.098202         None            ny
# 55293            0.098202         None            ny
# 55294            0.098202         None            ny
# 55296            0.005652         None            ny
# 55300            0.005652         None            ny
# 55356            0.000000         None            pa
# 55383            0.000000         None            md
# 55717            0.764236         None            az
# 55718            0.764236         None            az
# 55719            0.764236         None            az
# 55720            0.764236         None            az
# 55721            0.764236         None            az
# 55729            1.017210         None            az
# 55730            1.017210         None            az
# 55738            0.680155         None            az
# 55744            7.783673         None            az
# 55745           30.568384         None            az
# 55747            0.811475         None            az
# 55749            0.811475         None            az
# 55857           14.024297         None            il
# 55882            0.674515         None            az
#
# [303 rows x 19 columns]

# %%
# Let's see if we can get better geo accuracy. Using TwoFishes geocoder and DataScienceToolkit
def get_forward(row):
    twofishes_url = 'http://localhost:8081/search/geocode'
    datasci_url = 'http://www.datasciencetoolkit.org/maps/api/geocode/json'
    
    tf_resp = requests.get(twofishes_url, params={'query': '{},+{}

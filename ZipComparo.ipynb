# %%
import pandas as pd

# Import, lowercase city/state name to attempt join later

# Geonames is ~1:1 City/Place names to Zip Codes
# Schema: http://download.geonames.org/export/zip/readme.txt
col_names = ['country_code',
             'postal_code',
             'place_name',
             'admin_name1',
             'admin_code1',
             'admin_name2',
             'admin_code2',
             'admin_name3',
             'admin_code3',
             'latitude',
             'longitude',
             'accuracy']
geonames = pd.read_table('GeoNamesZip.txt', header=None, names=col_names, dtype={'postal_code': str})
geonames['place_name'] = geonames['place_name'].str.lower()
geonames['admin_code1'] = geonames['admin_code1'].str.lower()
geonames_set = set(geonames['postal_code'])

# Free-zip 1 is 1:1 City to Zip Code
free_zip_db = pd.read_csv('free-zipcode-database-Primary.csv', dtype={'Zipcode': str})
free_zip_db['City'] = free_zip_db['City'].str.lower()
free_zip_db['State'] = free_zip_db['State'].str.lower()
freezip_set = set(free_zip_db['Zipcode'])

# Free-zip all is Many:1 City to Zip Code
free_zip_all = pd.read_csv('free-zipcode-database-all-places.csv', dtype={'Zipcode': str})
free_zip_all['City'] = free_zip_all['City'].str.lower()
free_zip_all['State'] = free_zip_all['State'].str.lower()
freezip_all_set = set(free_zip_all['Zipcode'])

#
noncensus = pd.read_csv('noncensus_zip.csv', dtype={'zip': str})
noncensus['city'] = noncensus['city'].str.lower()
noncensus['state'] = noncensus['state'].str.lower()
noncensus_set = set(noncensus['zip'])

set_lengths = {
    'noncensus_set': len(noncensus_set),
    'free_zip_set': len(freezip_set),
    'free_zip_all_set': len(freezip_all_set),
    'geonames_set': len(geonames_set)
    }
set_lengths
# Out:
# {'free_zip_all_set': 42522,
#  'free_zip_set': 42522,
#  'geonames_set': 43586,
#  'noncensus_set': 43524,
#  'simple_set': 28737}

# %%
len(geonames), len(free_zip_db), len(free_zip_all), len(noncensus)
# Out:
# (43629, 42522, 81831, 43524, 71815)

# %%
# Columns of interest
geo_zip_city_state = geonames[['postal_code', 'place_name', 'admin_code1']]
free_zip_city_state = free_zip_db[['Zipcode', 'City', 'State']]
free_zip_all_city_state = free_zip_all[['Zipcode', 'City', 'State']]
noncensus_city_state = noncensus[['zip', 'city', 'state']]

# %%
# free-zip vs geonames
merged_zip = pd.merge(free_zip_all_city_state, geo_zip_city_state, 
                      left_on='Zipcode', right_on='postal_code')
merged_zip_city = pd.merge(free_zip_all_city_state, geo_zip_city_state, 
                           left_on=['Zipcode', 'City'], 
                           right_on=['postal_code', 'place_name'])
merged_zip_state = pd.merge(free_zip_all_city_state, geo_zip_city_state, 
                            left_on=['Zipcode', 'State'], 
                            right_on=['postal_code', 'admin_code1'])
merged_zip_city_state = pd.merge(free_zip_all_city_state, geo_zip_city_state, 
                                 left_on=['Zipcode', 'City', 'State'], 
                                 right_on=['postal_code', 'place_name', 'admin_code1'])
lengths_free_geo = {
    'merged_zip': len(merged_zip),
    'merged_zip_city': len(merged_zip_city),
    'merged_zip_state': len(merged_zip_state),
    'merged_zip_city_state': len(merged_zip_city_state)
}
lengths_free_geo
# Out:
# {'merged_zip': 78300,
#  'merged_zip_city': 41404,
#  'merged_zip_city_state': 41404,
#  'merged_zip_state': 78300}

# %%
merged_zip
# Out:
#       Zipcode                 City State postal_code          place_name  \
# 0       07093              monitor    nj       07093       west new york
# 1       07093               taurus    nj       07093       west new york
# 2       07093        west new york    nj       07093       west new york
# 3       07093           guttenberg    nj       07093       west new york
# 4       07675             westwood    nj       07675            westwood
# 5       07675           old tappan    nj       07675            westwood
# 6       07675           river vale    nj       07675            westwood
# 7       07675            rivervale    nj       07675            westwood
# 8       07677       woodcliff lake    nj       07677      woodcliff lake
# 9       07677             westwood    nj       07677      woodcliff lake
# 10      07677         woodcliff lk    nj       07677      woodcliff lake
# 11      07885              wharton    nj       07885             wharton
# 12      07981             whippany    nj       07981            whippany
# 13      07999             whippany    nj       07999            whippany
# 14      08888           whitehouse    nj       08888          whitehouse
# 15      08889   whitehouse station    nj       08889  whitehouse station
# 16      08889        white hse sta    nj       08889  whitehouse station
# 17      08889  white house station    nj       08889  whitehouse station
# 18      07095           woodbridge    nj       07095          woodbridge
# 19      07481              wyckoff    nj       07481             wyckoff
# 20      10451                bronx    ny       10451               bronx
# 21      10452                bronx    ny       10452               bronx
# 22      10452           highbridge    ny       10452               bronx
# 23      10452              stadium    ny       10452               bronx
# 24      10452   university heights    ny       10452               bronx
# 25      10453                bronx    ny       10453               bronx
# 26      10454                bronx    ny       10454               bronx
# 27      10454           mott haven    ny       10454               bronx
# 28      10455                bronx    ny       10455               bronx
# 29      10455                  hub    ny       10455               bronx
# ...       ...                  ...   ...         ...                 ...
# 78270   97427           culp creek    or       97427          culp creek
# 78271   97428               curtin    or       97428              curtin
# 78272   97472              saginaw    or       97472             saginaw
# 78273   97472        cottage grove    or       97472             saginaw
# 78274   97482             thurston    or       97482            thurston
# 78275   97482          springfield    or       97482            thurston
# 78276   98054              redondo    wa       98054             redondo
# 78277   98151  goodwill games 1990    wa       98151             seattle
# 78278   98151              seattle    wa       98151             seattle
# 78279   98171              seattle    wa       98171             seattle
# 78280   98184      bank of america    wa       98184             seattle
# 78281   98184              seattle    wa       98184             seattle
# 78282   98442               tacoma    wa       98442              tacoma
# 78283   98450     wa state lottery    wa       98450              tacoma
# 78284   98450               tacoma    wa       98450              tacoma
# 78285   98455               tacoma    wa       98455              tacoma
# 78286   98455     wa state lottery    wa       98455              tacoma
# 78287   98460               tacoma    wa       98460              tacoma
# 78288   98460     wa state lottery    wa       98460              tacoma
# 78289   98477      weyerhaeuser co    wa       98477              tacoma
# 78290   98477               tacoma    wa       98477              tacoma
# 78291   98492             lakewood    wa       98492            lakewood
# 78292   98492               tacoma    wa       98492            lakewood
# 78293   98667                abmps    wa       98667           vancouver
# 78294   98667            vancouver    wa       98667           vancouver
# 78295   98929        goose prairie    wa       98929       goose prairie
# 78296   98929               naches    wa       98929       goose prairie
# 78297   99165              pullman    wa       99165             pullman
# 78298   99779                  tok    ak       99779              tetlin
# 78299   97475          springfield    or       97475         springfield
#
#       admin_code1
# 0              nj
# 1              nj
# 2              nj
# 3              nj
# 4              nj
# 5              nj
# 6              nj
# 7              nj
# 8              nj
# 9              nj
# 10             nj
# 11             nj
# 12             nj
# 13             nj
# 14             nj
# 15             nj
# 16             nj
# 17             nj
# 18             nj
# 19             nj
# 20             ny
# 21             ny
# 22             ny
# 23             ny
# 24             ny
# 25             ny
# 26             ny
# 27             ny
# 28             ny
# 29             ny
# ...           ...
# 78270          or
# 78271          or
# 78272          or
# 78273          or
# 78274          or
# 78275          or
# 78276          wa
# 78277          wa
# 78278          wa
# 78279          wa
# 78280          wa
# 78281          wa
# 78282          wa
# 78283          wa
# 78284          wa
# 78285          wa
# 78286          wa
# 78287          wa
# 78288          wa
# 78289          wa
# 78290          wa
# 78291          wa
# 78292          wa
# 78293          wa
# 78294          wa
# 78295          wa
# 78296          wa
# 78297          wa
# 78298          ak
# 78299          or
#
# [78300 rows x 6 columns]

# %%
# noncensus vs free zip
merged_non_free_zip = pd.merge(free_zip_all_city_state, noncensus_city_state,
                               right_on=['zip'], left_on=['Zipcode'])
merged_non_free_zip_city = pd.merge(free_zip_all_city_state, noncensus_city_state,
                                    right_on=['zip', 'city'], left_on=['Zipcode', 'City'])
merged_non_free_zip_state = pd.merge(free_zip_all_city_state, noncensus_city_state,
                                    right_on=['zip', 'state'], left_on=['Zipcode', 'State'])
merged_non_free_zip_city_state = pd.merge(free_zip_all_city_state, noncensus_city_state,
                                          right_on=['zip', 'city', 'state'], left_on=['Zipcode', 'City', 'State'])
lengths_noncensus_free = {
    'merged_zip': len(merged_non_free_zip),
    'merged_zip_city': len(merged_non_free_zip_city),
    'merged_zip_state': len(merged_non_free_zip_state),
    'merged_zip_city_state': len(merged_non_free_zip_city_state)
}
lengths_noncensus_free
# Out:
# {'merged_zip': 80852,
#  'merged_zip_city': 41553,
#  'merged_zip_city_state': 41527,
#  'merged_zip_state': 80798}

# %%
merged_non_free_zip
# Out:
#       Zipcode                      City State    zip           city state
# 0       00704               parc parque    pr  00704        aguirre    pr
# 1       00704       paseo costa del sur    pr  00704        aguirre    pr
# 2       00704             sect lanausse    pr  00704        aguirre    pr
# 3       00704           urb eugene rice    pr  00704        aguirre    pr
# 4       00704              urb gonzalez    pr  00704        aguirre    pr
# 5       00704            urb la fabrica    pr  00704        aguirre    pr
# 6       00704         urb monte soria 2    pr  00704        aguirre    pr
# 7       00704          villas del coqui    pr  00704        aguirre    pr
# 8       00704                   aguirre    pr  00704        aguirre    pr
# 9       00704         est de trinitaria    pr  00704        aguirre    pr
# 10      00704              ext el coqui    pr  00704        aguirre    pr
# 11      00704               parc cabasa    pr  00704        aguirre    pr
# 12      00705                  aibonito    pr  00705       aibonito    pr
# 13      00705              bda san luis    pr  00705       aibonito    pr
# 14      00705                 bo llanos    pr  00705       aibonito    pr
# 15      00705        brisas de aibonito    pr  00705       aibonito    pr
# 16      00705  colinas de san francisco    pr  00705       aibonito    pr
# 17      00705             est del llano    pr  00705       aibonito    pr
# 18      00705           ext bella vista    pr  00705       aibonito    pr
# 19      00705              ext san luis    pr  00705       aibonito    pr
# 20      00705         ext villa rosales    pr  00705       aibonito    pr
# 21      00705              repto robles    pr  00705       aibonito    pr
# 22      00705           urb bella vista    pr  00705       aibonito    pr
# 23      00705           urb buena vista    pr  00705       aibonito    pr
# 24      00705         urb golden vlg iv    pr  00705       aibonito    pr
# 25      00705        urb la providencia    pr  00705       aibonito    pr
# 26      00705          villa de la rosa    pr  00705       aibonito    pr
# 27      00705             villa rosales    pr  00705       aibonito    pr
# 28      00705          villas del coqui    pr  00705       aibonito    pr
# 29      00610                    anasco    pr  00610         anasco    pr
# ...       ...                       ...   ...    ...            ...   ...
# 80822   97427                culp creek    or  97427     culp creek    or
# 80823   97428                    curtin    or  97428         curtin    or
# 80824   97472                   saginaw    or  97472        saginaw    or
# 80825   97472             cottage grove    or  97472        saginaw    or
# 80826   97482                  thurston    or  97482       thurston    or
# 80827   97482               springfield    or  97482       thurston    or
# 80828   98054                   redondo    wa  98054        redondo    wa
# 80829   98151       goodwill games 1990    wa  98151        seattle    wa
# 80830   98151                   seattle    wa  98151        seattle    wa
# 80831   98171                   seattle    wa  98171        seattle    wa
# 80832   98184           bank of america    wa  98184        seattle    wa
# 80833   98184                   seattle    wa  98184        seattle    wa
# 80834   98442                    tacoma    wa  98442         tacoma    wa
# 80835   98450          wa state lottery    wa  98450         tacoma    wa
# 80836   98450                    tacoma    wa  98450         tacoma    wa
# 80837   98455                    tacoma    wa  98455         tacoma    wa
# 80838   98455          wa state lottery    wa  98455         tacoma    wa
# 80839   98460                    tacoma    wa  98460         tacoma    wa
# 80840   98460          wa state lottery    wa  98460         tacoma    wa
# 80841   98477           weyerhaeuser co    wa  98477         tacoma    wa
# 80842   98477                    tacoma    wa  98477         tacoma    wa
# 80843   98492                  lakewood    wa  98492       lakewood    wa
# 80844   98492                    tacoma    wa  98492       lakewood    wa
# 80845   98667                     abmps    wa  98667      vancouver    wa
# 80846   98667                 vancouver    wa  98667      vancouver    wa
# 80847   98929             goose prairie    wa  98929  goose prairie    wa
# 80848   98929                    naches    wa  98929  goose prairie    wa
# 80849   99165                   pullman    wa  99165        pullman    wa
# 80850   99779                       tok    ak  99779         tetlin    ak
# 80851   97475               springfield    or  97475    springfield    or
#
# [80852 rows x 6 columns]

# %%
# What are our state conflicts?
merged_non_free_zip[~merged_non_free_zip['Zipcode'].isin(merged_non_free_zip_state['Zipcode'])]
# Out:
#       Zipcode              City State    zip                 city state
# 247     10004          new york    ny  10004             new york    nj
# 248     10004     bowling green    ny  10004             new york    nj
# 20960   38041           henning    tn  38041              henning    ar
# 20961   38041       fort pillow    tn  38041              henning    ar
# 21583   38063            ripley    tn  38063               ripley    ar
# 21708   38079       tiptonville    tn  38079          tiptonville    ky
# 28034   52761         muscatine    ia  52761            muscatine    il
# 28946   56129         ellsworth    mn  56129            ellsworth    ia
# 28947   56027            elmore    mn  56027               elmore    ia
# 29297   55954             mabel    mn  55954                mabel    ia
# 32503   57638            lemmon    sd  57638               lemmon    nd
# 32504   57638         shadehill    sd  57638               lemmon    nd
# 32505   57638      thunder hawk    sd  57638               lemmon    nd
# 32506   57638       white butte    sd  57638               lemmon    nd
# 34232   65733            protem    mo  65733               protem    ar
# 34427   65761         theodosia    mo  65761            theodosia    ar
# 34428   65761      dugginsville    mo  65761            theodosia    ar
# 34429   65761           longrun    mo  65761            theodosia    ar
# 34430   65761              ocie    mo  65761            theodosia    ar
# 37834   83120           freedom    wy  83120              freedom    id
# 37899   82063              jelm    wy  82063                 jelm    co
# 37900   82063           laramie    wy  82063                 jelm    co
# 37901   82063     woods landing    wy  82063                 jelm    co
# 37957   82082       pine bluffs    wy  82082          pine bluffs    ne
# 38597   84536   monument valley    ut  84536      monument valley    az
# 38598   84536      monument vly    ut  84536      monument valley    az
# 40666   87328            navajo    nm  87328               navajo    az
# 40667   87328           crystal    nm  87328               navajo    az
# 41643   89024          mesquite    nv  89024             mesquite    az
# 41812   89439             verdi    nv  89439                verdi    ca
# 42157   97910     jordan valley    or  97910        jordan valley    id
# 42158   97910    south mountain    or  97910        jordan valley    id
# 42159   97910         south mtn    or  97910        jordan valley    id
# 42160   97910    burns junction    or  97910        jordan valley    id
# 42161   97910            danner    or  97910        jordan valley    id
# 42162   97910              rome    or  97910        jordan valley    id
# 42271   97635    new pine creek    or  97635       new pine creek    ca
# 42272   97635      new pine crk    or  97635       new pine creek    ca
# 42283   97913             nyssa    or  97913                nyssa    id
# 42284   97913           arcadia    or  97913                nyssa    id
# 42285   97913    owyhee corners    or  97913                nyssa    id
# 43118   99128        farmington    wa  99128           farmington    id
# 44149   99362       walla walla    wa  99362          walla walla    or
# 50009   31788          moultrie    ga  31788          white house    tn
# 54879   38852              iuka    ms  38852                 iuka    al
# 54880   38852          eastport    ms  38852                 iuka    al
# 54881   38852     gravel siding    ms  38852                 iuka    al
# 54882   38852            holcut    ms  38852                 iuka    al
# 54883   38852            midway    ms  38852                 iuka    al
# 54884   38852  north crossroads    ms  38852                 iuka    al
# 54885   38852            oldham    ms  38852                 iuka    al
# 61497   79051           kerrick    tx  79051              kerrick    ok
# 62955   79922           el paso    tx  79922              el paso    nm
# 79798   96373               fpo    ap  96373  hawaiian ocean view    hi

# %%
# Merge all the things
merged_all = pd.merge(merged_non_free_zip, merged_zip,
                      how='left',
                      left_on=['Zipcode', 'City', 'State'], 
                      right_on=['Zipcode', 'City', 'State'])

# %%
merged_all
# Out:
#       Zipcode                      City State    zip           city state  \
# 0       00704               parc parque    pr  00704        aguirre    pr
# 1       00704       paseo costa del sur    pr  00704        aguirre    pr
# 2       00704             sect lanausse    pr  00704        aguirre    pr
# 3       00704           urb eugene rice    pr  00704        aguirre    pr
# 4       00704              urb gonzalez    pr  00704        aguirre    pr
# 5       00704            urb la fabrica    pr  00704        aguirre    pr
# 6       00704         urb monte soria 2    pr  00704        aguirre    pr
# 7       00704          villas del coqui    pr  00704        aguirre    pr
# 8       00704                   aguirre    pr  00704        aguirre    pr
# 9       00704         est de trinitaria    pr  00704        aguirre    pr
# 10      00704              ext el coqui    pr  00704        aguirre    pr
# 11      00704               parc cabasa    pr  00704        aguirre    pr
# 12      00705                  aibonito    pr  00705       aibonito    pr
# 13      00705              bda san luis    pr  00705       aibonito    pr
# 14      00705                 bo llanos    pr  00705       aibonito    pr
# 15      00705        brisas de aibonito    pr  00705       aibonito    pr
# 16      00705  colinas de san francisco    pr  00705       aibonito    pr
# 17      00705             est del llano    pr  00705       aibonito    pr
# 18      00705           ext bella vista    pr  00705       aibonito    pr
# 19      00705              ext san luis    pr  00705       aibonito    pr
# 20      00705         ext villa rosales    pr  00705       aibonito    pr
# 21      00705              repto robles    pr  00705       aibonito    pr
# 22      00705           urb bella vista    pr  00705       aibonito    pr
# 23      00705           urb buena vista    pr  00705       aibonito    pr
# 24      00705         urb golden vlg iv    pr  00705       aibonito    pr
# 25      00705        urb la providencia    pr  00705       aibonito    pr
# 26      00705          villa de la rosa    pr  00705       aibonito    pr
# 27      00705             villa rosales    pr  00705       aibonito    pr
# 28      00705          villas del coqui    pr  00705       aibonito    pr
# 29      00610                    anasco    pr  00610         anasco    pr
# ...       ...                       ...   ...    ...            ...   ...
# 80966   97427                culp creek    or  97427     culp creek    or
# 80967   97428                    curtin    or  97428         curtin    or
# 80968   97472                   saginaw    or  97472        saginaw    or
# 80969   97472             cottage grove    or  97472        saginaw    or
# 80970   97482                  thurston    or  97482       thurston    or
# 80971   97482               springfield    or  97482       thurston    or
# 80972   98054                   redondo    wa  98054        redondo    wa
# 80973   98151       goodwill games 1990    wa  98151        seattle    wa
# 80974   98151                   seattle    wa  98151        seattle    wa
# 80975   98171                   seattle    wa  98171        seattle    wa
# 80976   98184           bank of america    wa  98184        seattle    wa
# 80977   98184                   seattle    wa  98184        seattle    wa
# 80978   98442                    tacoma    wa  98442         tacoma    wa
# 80979   98450          wa state lottery    wa  98450         tacoma    wa
# 80980   98450                    tacoma    wa  98450         tacoma    wa
# 80981   98455                    tacoma    wa  98455         tacoma    wa
# 80982   98455          wa state lottery    wa  98455         tacoma    wa
# 80983   98460                    tacoma    wa  98460         tacoma    wa
# 80984   98460          wa state lottery    wa  98460         tacoma    wa
# 80985   98477           weyerhaeuser co    wa  98477         tacoma    wa
# 80986   98477                    tacoma    wa  98477         tacoma    wa
# 80987   98492                  lakewood    wa  98492       lakewood    wa
# 80988   98492                    tacoma    wa  98492       lakewood    wa
# 80989   98667                     abmps    wa  98667      vancouver    wa
# 80990   98667                 vancouver    wa  98667      vancouver    wa
# 80991   98929             goose prairie    wa  98929  goose prairie    wa
# 80992   98929                    naches    wa  98929  goose prairie    wa
# 80993   99165                   pullman    wa  99165        pullman    wa
# 80994   99779                       tok    ak  99779         tetlin    ak
# 80995   97475               springfield    or  97475    springfield    or
#
#       postal_code     place_name admin_code1
# 0             NaN            NaN         NaN
# 1             NaN            NaN         NaN
# 2             NaN            NaN         NaN
# 3             NaN            NaN         NaN
# 4             NaN            NaN         NaN
# 5             NaN            NaN         NaN
# 6             NaN            NaN         NaN
# 7             NaN            NaN         NaN
# 8             NaN            NaN         NaN
# 9             NaN            NaN         NaN
# 10            NaN            NaN         NaN
# 11            NaN            NaN         NaN
# 12            NaN            NaN         NaN
# 13            NaN            NaN         NaN
# 14            NaN            NaN         NaN
# 15            NaN            NaN         NaN
# 16            NaN            NaN         NaN
# 17            NaN            NaN         NaN
# 18            NaN            NaN         NaN
# 19            NaN            NaN         NaN
# 20            NaN            NaN         NaN
# 21            NaN            NaN         NaN
# 22            NaN            NaN         NaN
# 23            NaN            NaN         NaN
# 24            NaN            NaN         NaN
# 25            NaN            NaN         NaN
# 26            NaN            NaN         NaN
# 27            NaN            NaN         NaN
# 28            NaN            NaN         NaN
# 29            NaN            NaN         NaN
# ...           ...            ...         ...
# 80966       97427     culp creek          or
# 80967       97428         curtin          or
# 80968       97472        saginaw          or
# 80969       97472        saginaw          or
# 80970       97482       thurston          or
# 80971       97482       thurston          or
# 80972       98054        redondo          wa
# 80973       98151        seattle          wa
# 80974       98151        seattle          wa
# 80975       98171        seattle          wa
# 80976       98184        seattle          wa
# 80977       98184        seattle          wa
# 80978       98442         tacoma          wa
# 80979       98450         tacoma          wa
# 80980       98450         tacoma          wa
# 80981       98455         tacoma          wa
# 80982       98455         tacoma          wa
# 80983       98460         tacoma          wa
# 80984       98460         tacoma          wa
# 80985       98477         tacoma          wa
# 80986       98477         tacoma          wa
# 80987       98492       lakewood          wa
# 80988       98492       lakewood          wa
# 80989       98667      vancouver          wa
# 80990       98667      vancouver          wa
# 80991       98929  goose prairie          wa
# 80992       98929  goose prairie          wa
# 80993       99165        pullman          wa
# 80994       99779         tetlin          ak
# 80995       97475    springfield          or
#
# [80996 rows x 9 columns]

# %%
len(merged_all)
# Out:
# 80996

# %%
# Some renaming
one_zip_col = merged_all[['Zipcode', 'City', 'city', 'place_name', 
                          'State', 'state', 'admin_code1']]
master_zips = one_zip_col.rename(columns={'City': 'City_1', 
                                          'city': 'City_2', 
                                          'place_name': 'City_3',
                                          'State': 'State_1',
                                          'state': 'State_2', 
                                          'admin_code1': 'State_3'})

# %%
# Designate rows with matching cities as primary
master_zips['Primary'] = False
def flag_primary(row):
    if row['City_1'] == row['City_2'] == row['City_3']:
        row['Primary'] = True
    return row
mask = master_zips.apply(flag_primary, axis=1)['Primary']
primary_zips = master_zips[mask]

# %%
len(primary_zips)
# Out:
# 41015
